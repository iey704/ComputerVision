# %% [markdown]
# <a href="https://colab.research.google.com/github/iey704/ComputerVision/blob/main/CV_AL2_EfficientNet(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * AdamP
# * EfficientNet
# * MultiStepLR(scheduler 추가)
# * Batch = 8
# * lr = 0.0001

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=66d8ed803e772c7f46006c83c3827c577d3bf4300088b4c2ab031bfdfa987ad5
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=3bedc9d2a03070f359a2f2426f478376ad5b7ab399531593a97d06910f04cba4
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageEnhance

from efficientnet_pytorch import EfficientNet

from torch.utils.data import ConcatDataset
from collections import Counter

import numpy as np

from adamp import AdamP

import cv2 as cv
from torch.optim.lr_scheduler import MultiStepLR

# 랜덤 시드 설정 공통
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)


### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
# Create DataLoader
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.mode = mode
    self.transform = transform

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/drive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/drive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/drive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/drive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)

    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# %% [markdown]
# https://deep-learning-study.tistory.com/240

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
### Model / Optimizer ###
EPOCH = 10
lr = 0.0001
weight_decay = 0.0005

model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=50)

### Tranfer Learning ###
'''
num_features = model.classifier.in_features
model.fc = nn.Linear(num_features,50)
'''
model.to(DEVICE)

optimizer = AdamP(model.parameters(),lr=lr, weight_decay=weight_decay)

scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones = [20, 40, 45], gamma = 0.5)

print("Created a learning model and optimizer")
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 236MB/s]
# Loaded pretrained weights for efficientnet-b0
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

# 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/590]	loss: 3.932957
# Train Epoch: 0 [10/590]	loss: 3.888487
# Train Epoch: 0 [20/590]	loss: 3.952116
# Train Epoch: 0 [30/590]	loss: 3.915794
# Train Epoch: 0 [40/590]	loss: 3.842070
# Train Epoch: 0 [50/590]	loss: 3.863724
# Train Epoch: 0 [60/590]	loss: 3.844807
# Train Epoch: 0 [70/590]	loss: 3.803196
# Train Epoch: 0 [80/590]	loss: 3.911685
# Train Epoch: 0 [90/590]	loss: 3.878001
# Train Epoch: 0 [100/590]	loss: 3.839707
# Train Epoch: 0 [110/590]	loss: 3.871340
# Train Epoch: 0 [120/590]	loss: 3.801399
# Train Epoch: 0 [130/590]	loss: 3.760497
# Train Epoch: 0 [140/590]	loss: 3.702885
# Train Epoch: 0 [150/590]	loss: 3.654478
# Train Epoch: 0 [160/590]	loss: 3.824992
# Train Epoch: 0 [170/590]	loss: 3.728153
# Train Epoch: 0 [180/590]	loss: 3.599128
# Train Epoch: 0 [190/590]	loss: 3.551137
# Train Epoch: 0 [200/590]	loss: 3.514711
# Train Epoch: 0 [210/590]	loss: 3.618164
# Train Epoch: 0 [220/590]	loss: 3.399522
# Train Epoch: 0 [230/590]	loss: 3.442871
# Train Epoch: 0 [240/590]	loss: 3.357020
# Train Epoch: 0 [250/590]	loss: 3.776252
# Train Epoch: 0 [260/590]	loss: 3.571054
# Train Epoch: 0 [270/590]	loss: 3.383463
# Train Epoch: 0 [280/590]	loss: 3.262762
# Train Epoch: 0 [290/590]	loss: 3.139864
# Train Epoch: 0 [300/590]	loss: 3.267799
# Train Epoch: 0 [310/590]	loss: 3.403838
# Train Epoch: 0 [320/590]	loss: 3.106711
# Train Epoch: 0 [330/590]	loss: 2.901614
# Train Epoch: 0 [340/590]	loss: 2.694319
# Train Epoch: 0 [350/590]	loss: 2.783389
# Train Epoch: 0 [360/590]	loss: 2.869534
# Train Epoch: 0 [370/590]	loss: 2.817430
# Train Epoch: 0 [380/590]	loss: 2.975916
# Train Epoch: 0 [390/590]	loss: 2.916341
# Train Epoch: 0 [400/590]	loss: 2.881916
# Train Epoch: 0 [410/590]	loss: 2.997380
# Train Epoch: 0 [420/590]	loss: 2.796350
# Train Epoch: 0 [430/590]	loss: 2.975072
# Train Epoch: 0 [440/590]	loss: 2.547423
# Train Epoch: 0 [450/590]	loss: 2.276015
# Train Epoch: 0 [460/590]	loss: 2.557433
# Train Epoch: 0 [470/590]	loss: 2.341566
# Train Epoch: 0 [480/590]	loss: 2.487820
# Train Epoch: 0 [490/590]	loss: 2.307267
# Train Epoch: 0 [500/590]	loss: 2.649837
# Train Epoch: 0 [510/590]	loss: 2.015349
# Train Epoch: 0 [520/590]	loss: 2.587448
# Train Epoch: 0 [530/590]	loss: 2.669224
# Train Epoch: 0 [540/590]	loss: 2.044795
# Train Epoch: 0 [550/590]	loss: 1.785788
# Train Epoch: 0 [560/590]	loss: 2.317131
# Train Epoch: 0 [570/590]	loss: 2.352027
# Train Epoch: 0 [580/590]	loss: 2.016566
# [0]Validation Loss: 1.4108,Accuracy: 70.9459%
# Train Epoch: 1 [0/590]	loss: 2.050303
# Train Epoch: 1 [10/590]	loss: 2.069624
# Train Epoch: 1 [20/590]	loss: 1.347423
# Train Epoch: 1 [30/590]	loss: 2.222989
# Train Epoch: 1 [40/590]	loss: 1.977739
# Train Epoch: 1 [50/590]	loss: 1.650147
# Train Epoch: 1 [60/590]	loss: 1.333298
# Train Epoch: 1 [70/590]	loss: 1.993212
# Train Epoch: 1 [80/590]	loss: 1.401424
# Train Epoch: 1 [90/590]	loss: 2.050802
# Train Epoch: 1 [100/590]	loss: 1.816838
# Train Epoch: 1 [110/590]	loss: 1.755521
# Train Epoch: 1 [120/590]	loss: 1.481744
# Train Epoch: 1 [130/590]	loss: 1.727022
# Train Epoch: 1 [140/590]	loss: 1.706188
# Train Epoch: 1 [150/590]	loss: 1.735594
# Train Epoch: 1 [160/590]	loss: 1.702815
# Train Epoch: 1 [170/590]	loss: 1.291628
# Train Epoch: 1 [180/590]	loss: 1.516457
# Train Epoch: 1 [190/590]	loss: 1.195155
# Train Epoch: 1 [200/590]	loss: 1.949822
# Train Epoch: 1 [210/590]	loss: 1.576486
# Train Epoch: 1 [220/590]	loss: 1.939365
# Train Epoch: 1 [230/590]	loss: 1.402846
# Train Epoch: 1 [240/590]	loss: 1.264968
# Train Epoch: 1 [250/590]	loss: 2.128324
# Train Epoch: 1 [260/590]	loss: 1.118427
# Train Epoch: 1 [270/590]	loss: 1.667380
# Train Epoch: 1 [280/590]	loss: 1.127418
# Train Epoch: 1 [290/590]	loss: 1.560789
# Train Epoch: 1 [300/590]	loss: 1.259456
# Train Epoch: 1 [310/590]	loss: 1.267465
# Train Epoch: 1 [320/590]	loss: 1.777820
# Train Epoch: 1 [330/590]	loss: 0.901721
# Train Epoch: 1 [340/590]	loss: 1.133666
# Train Epoch: 1 [350/590]	loss: 1.601270
# Train Epoch: 1 [360/590]	loss: 1.421337
# Train Epoch: 1 [370/590]	loss: 1.229315
# Train Epoch: 1 [380/590]	loss: 1.017353
# Train Epoch: 1 [390/590]	loss: 1.356127
# Train Epoch: 1 [400/590]	loss: 1.313293
# Train Epoch: 1 [410/590]	loss: 1.348239
# Train Epoch: 1 [420/590]	loss: 1.862118
# Train Epoch: 1 [430/590]	loss: 1.257915
# Train Epoch: 1 [440/590]	loss: 0.524234
# Train Epoch: 1 [450/590]	loss: 1.578545
# Train Epoch: 1 [460/590]	loss: 1.655339
# Train Epoch: 1 [470/590]	loss: 0.899423
# Train Epoch: 1 [480/590]	loss: 0.898924
# Train Epoch: 1 [490/590]	loss: 0.964203
# Train Epoch: 1 [500/590]	loss: 0.801614
# Train Epoch: 1 [510/590]	loss: 0.961602
# Train Epoch: 1 [520/590]	loss: 1.180826
# Train Epoch: 1 [530/590]	loss: 1.072298
# Train Epoch: 1 [540/590]	loss: 0.725150
# Train Epoch: 1 [550/590]	loss: 1.429712
# Train Epoch: 1 [560/590]	loss: 0.721536
# Train Epoch: 1 [570/590]	loss: 1.942643
# Train Epoch: 1 [580/590]	loss: 0.690147
# [1]Validation Loss: 0.5448,Accuracy: 85.8108%
# Train Epoch: 2 [0/590]	loss: 1.055799
# Train Epoch: 2 [10/590]	loss: 0.828058
# Train Epoch: 2 [20/590]	loss: 1.418954
# Train Epoch: 2 [30/590]	loss: 1.894892
# Train Epoch: 2 [40/590]	loss: 0.942858
# Train Epoch: 2 [50/590]	loss: 0.754281
# Train Epoch: 2 [60/590]	loss: 1.111236
# Train Epoch: 2 [70/590]	loss: 0.532992
# Train Epoch: 2 [80/590]	loss: 0.622988
# Train Epoch: 2 [90/590]	loss: 2.050956
# Train Epoch: 2 [100/590]	loss: 1.172178
# Train Epoch: 2 [110/590]	loss: 0.658054
# Train Epoch: 2 [120/590]	loss: 0.703932
# Train Epoch: 2 [130/590]	loss: 0.497213
# Train Epoch: 2 [140/590]	loss: 0.675602
# Train Epoch: 2 [150/590]	loss: 0.960358
# Train Epoch: 2 [160/590]	loss: 0.895198
# Train Epoch: 2 [170/590]	loss: 0.324918
# Train Epoch: 2 [180/590]	loss: 1.039298
# Train Epoch: 2 [190/590]	loss: 0.782030
# Train Epoch: 2 [200/590]	loss: 0.810000
# Train Epoch: 2 [210/590]	loss: 0.653710
# Train Epoch: 2 [220/590]	loss: 0.837058
# Train Epoch: 2 [230/590]	loss: 0.392500
# Train Epoch: 2 [240/590]	loss: 0.461004
# Train Epoch: 2 [250/590]	loss: 1.111945
# Train Epoch: 2 [260/590]	loss: 0.519860
# Train Epoch: 2 [270/590]	loss: 0.674712
# Train Epoch: 2 [280/590]	loss: 0.628954
# Train Epoch: 2 [290/590]	loss: 0.505467
# Train Epoch: 2 [300/590]	loss: 0.990916
# Train Epoch: 2 [310/590]	loss: 0.914984
# Train Epoch: 2 [320/590]	loss: 0.486129
# Train Epoch: 2 [330/590]	loss: 0.808260
# Train Epoch: 2 [340/590]	loss: 0.600277
# Train Epoch: 2 [350/590]	loss: 0.525725
# Train Epoch: 2 [360/590]	loss: 0.275472
# Train Epoch: 2 [370/590]	loss: 0.718844
# Train Epoch: 2 [380/590]	loss: 0.792784
# Train Epoch: 2 [390/590]	loss: 0.375842
# Train Epoch: 2 [400/590]	loss: 0.949943
# Train Epoch: 2 [410/590]	loss: 0.519609
# Train Epoch: 2 [420/590]	loss: 0.654074
# Train Epoch: 2 [430/590]	loss: 0.568415
# Train Epoch: 2 [440/590]	loss: 1.446328
# Train Epoch: 2 [450/590]	loss: 0.989657
# Train Epoch: 2 [460/590]	loss: 0.224860
# Train Epoch: 2 [470/590]	loss: 1.173810
# Train Epoch: 2 [480/590]	loss: 0.818533
# Train Epoch: 2 [490/590]	loss: 0.613910
# Train Epoch: 2 [500/590]	loss: 1.005863
# Train Epoch: 2 [510/590]	loss: 0.553144
# Train Epoch: 2 [520/590]	loss: 0.565296
# Train Epoch: 2 [530/590]	loss: 0.249007
# Train Epoch: 2 [540/590]	loss: 0.970421
# Train Epoch: 2 [550/590]	loss: 0.531083
# Train Epoch: 2 [560/590]	loss: 0.847963
# Train Epoch: 2 [570/590]	loss: 0.454679
# Train Epoch: 2 [580/590]	loss: 0.403365
# [2]Validation Loss: 0.3717,Accuracy: 86.8243%
# Train Epoch: 3 [0/590]	loss: 0.609331
# Train Epoch: 3 [10/590]	loss: 0.516274
# Train Epoch: 3 [20/590]	loss: 1.019649
# Train Epoch: 3 [30/590]	loss: 0.634779
# Train Epoch: 3 [40/590]	loss: 0.526907
# Train Epoch: 3 [50/590]	loss: 1.204367
# Train Epoch: 3 [60/590]	loss: 0.719729
# Train Epoch: 3 [70/590]	loss: 0.673355
# Train Epoch: 3 [80/590]	loss: 0.848031
# Train Epoch: 3 [90/590]	loss: 0.906826
# Train Epoch: 3 [100/590]	loss: 0.343466
# Train Epoch: 3 [110/590]	loss: 1.159457
# Train Epoch: 3 [120/590]	loss: 0.185051
# Train Epoch: 3 [130/590]	loss: 0.816726
# Train Epoch: 3 [140/590]	loss: 0.798734
# Train Epoch: 3 [150/590]	loss: 0.528759
# Train Epoch: 3 [160/590]	loss: 0.965677
# Train Epoch: 3 [170/590]	loss: 0.812741
# Train Epoch: 3 [180/590]	loss: 0.364743
# Train Epoch: 3 [190/590]	loss: 0.524146
# Train Epoch: 3 [200/590]	loss: 1.146010
# Train Epoch: 3 [210/590]	loss: 0.410645
# Train Epoch: 3 [220/590]	loss: 0.356610
# Train Epoch: 3 [230/590]	loss: 0.170709
# Train Epoch: 3 [240/590]	loss: 0.322229
# Train Epoch: 3 [250/590]	loss: 0.336750
# Train Epoch: 3 [260/590]	loss: 0.642365
# Train Epoch: 3 [270/590]	loss: 0.975702
# Train Epoch: 3 [280/590]	loss: 0.702900
# Train Epoch: 3 [290/590]	loss: 0.304248
# Train Epoch: 3 [300/590]	loss: 0.229794
# Train Epoch: 3 [310/590]	loss: 0.182193
# Train Epoch: 3 [320/590]	loss: 0.285829
# Train Epoch: 3 [330/590]	loss: 0.333740
# Train Epoch: 3 [340/590]	loss: 0.470044
# Train Epoch: 3 [350/590]	loss: 0.374824
# Train Epoch: 3 [360/590]	loss: 0.564759
# Train Epoch: 3 [370/590]	loss: 0.602505
# Train Epoch: 3 [380/590]	loss: 1.018480
# Train Epoch: 3 [390/590]	loss: 0.560787
# Train Epoch: 3 [400/590]	loss: 0.282654
# Train Epoch: 3 [410/590]	loss: 0.786345
# Train Epoch: 3 [420/590]	loss: 0.234049
# Train Epoch: 3 [430/590]	loss: 0.133219
# Train Epoch: 3 [440/590]	loss: 0.750871
# Train Epoch: 3 [450/590]	loss: 0.125724
# Train Epoch: 3 [460/590]	loss: 0.419985
# Train Epoch: 3 [470/590]	loss: 0.228819
# Train Epoch: 3 [480/590]	loss: 1.029255
# Train Epoch: 3 [490/590]	loss: 0.567968
# Train Epoch: 3 [500/590]	loss: 0.310326
# Train Epoch: 3 [510/590]	loss: 0.396343
# Train Epoch: 3 [520/590]	loss: 0.665837
# Train Epoch: 3 [530/590]	loss: 0.545467
# Train Epoch: 3 [540/590]	loss: 0.471294
# Train Epoch: 3 [550/590]	loss: 0.413427
# Train Epoch: 3 [560/590]	loss: 0.600266
# Train Epoch: 3 [570/590]	loss: 0.312424
# Train Epoch: 3 [580/590]	loss: 0.743871
# [3]Validation Loss: 0.2990,Accuracy: 89.5270%
# Train Epoch: 4 [0/590]	loss: 0.188598
# Train Epoch: 4 [10/590]	loss: 0.706602
# Train Epoch: 4 [20/590]	loss: 0.621327
# Train Epoch: 4 [30/590]	loss: 0.250620
# Train Epoch: 4 [40/590]	loss: 0.524937
# Train Epoch: 4 [50/590]	loss: 0.348438
# Train Epoch: 4 [60/590]	loss: 0.634988
# Train Epoch: 4 [70/590]	loss: 0.197215
# Train Epoch: 4 [80/590]	loss: 0.287258
# Train Epoch: 4 [90/590]	loss: 0.449523
# Train Epoch: 4 [100/590]	loss: 0.178793
# Train Epoch: 4 [110/590]	loss: 0.612301
# Train Epoch: 4 [120/590]	loss: 0.606131
# Train Epoch: 4 [130/590]	loss: 0.110262
# Train Epoch: 4 [140/590]	loss: 0.341678
# Train Epoch: 4 [150/590]	loss: 0.067554
# Train Epoch: 4 [160/590]	loss: 0.381249
# Train Epoch: 4 [170/590]	loss: 0.787740
# Train Epoch: 4 [180/590]	loss: 0.194192
# Train Epoch: 4 [190/590]	loss: 0.458402
# Train Epoch: 4 [200/590]	loss: 0.089272
# Train Epoch: 4 [210/590]	loss: 0.154879
# Train Epoch: 4 [220/590]	loss: 0.302381
# Train Epoch: 4 [230/590]	loss: 0.222357
# Train Epoch: 4 [240/590]	loss: 0.145522
# Train Epoch: 4 [250/590]	loss: 0.322256
# Train Epoch: 4 [260/590]	loss: 0.262942
# Train Epoch: 4 [270/590]	loss: 0.357983
# Train Epoch: 4 [280/590]	loss: 0.414181
# Train Epoch: 4 [290/590]	loss: 0.620552
# Train Epoch: 4 [300/590]	loss: 0.389504
# Train Epoch: 4 [310/590]	loss: 1.082443
# Train Epoch: 4 [320/590]	loss: 0.108387
# Train Epoch: 4 [330/590]	loss: 0.608625
# Train Epoch: 4 [340/590]	loss: 0.174966
# Train Epoch: 4 [350/590]	loss: 0.214876
# Train Epoch: 4 [360/590]	loss: 0.311134
# Train Epoch: 4 [370/590]	loss: 0.227336
# Train Epoch: 4 [380/590]	loss: 0.124975
# Train Epoch: 4 [390/590]	loss: 0.372139
# Train Epoch: 4 [400/590]	loss: 0.285275
# Train Epoch: 4 [410/590]	loss: 0.461439
# Train Epoch: 4 [420/590]	loss: 0.607066
# Train Epoch: 4 [430/590]	loss: 0.246533
# Train Epoch: 4 [440/590]	loss: 0.558130
# Train Epoch: 4 [450/590]	loss: 0.785985
# Train Epoch: 4 [460/590]	loss: 0.137236
# Train Epoch: 4 [470/590]	loss: 0.353655
# Train Epoch: 4 [480/590]	loss: 0.782007
# Train Epoch: 4 [490/590]	loss: 0.109286
# Train Epoch: 4 [500/590]	loss: 0.191246
# Train Epoch: 4 [510/590]	loss: 0.157439
# Train Epoch: 4 [520/590]	loss: 1.086322
# Train Epoch: 4 [530/590]	loss: 0.190277
# Train Epoch: 4 [540/590]	loss: 0.291290
# Train Epoch: 4 [550/590]	loss: 0.675982
# Train Epoch: 4 [560/590]	loss: 0.410994
# Train Epoch: 4 [570/590]	loss: 0.176206
# Train Epoch: 4 [580/590]	loss: 0.090098
# [4]Validation Loss: 0.2935,Accuracy: 91.8919%
# Train Epoch: 5 [0/590]	loss: 0.420587
# Train Epoch: 5 [10/590]	loss: 0.174310
# Train Epoch: 5 [20/590]	loss: 0.435793
# Train Epoch: 5 [30/590]	loss: 0.154809
# Train Epoch: 5 [40/590]	loss: 0.199243
# Train Epoch: 5 [50/590]	loss: 0.210657
# Train Epoch: 5 [60/590]	loss: 0.199687
# Train Epoch: 5 [70/590]	loss: 0.708750
# Train Epoch: 5 [80/590]	loss: 0.440012
# Train Epoch: 5 [90/590]	loss: 0.300864
# Train Epoch: 5 [100/590]	loss: 0.541069
# Train Epoch: 5 [110/590]	loss: 0.106531
# Train Epoch: 5 [120/590]	loss: 0.114090
# Train Epoch: 5 [130/590]	loss: 0.418404
# Train Epoch: 5 [140/590]	loss: 0.141542
# Train Epoch: 5 [150/590]	loss: 0.173793
# Train Epoch: 5 [160/590]	loss: 0.418192
# Train Epoch: 5 [170/590]	loss: 0.300249
# Train Epoch: 5 [180/590]	loss: 0.453908
# Train Epoch: 5 [190/590]	loss: 0.062261
# Train Epoch: 5 [200/590]	loss: 0.292949
# Train Epoch: 5 [210/590]	loss: 0.202346
# Train Epoch: 5 [220/590]	loss: 0.153904
# Train Epoch: 5 [230/590]	loss: 0.540053
# Train Epoch: 5 [240/590]	loss: 0.410311
# Train Epoch: 5 [250/590]	loss: 0.191052
# Train Epoch: 5 [260/590]	loss: 0.216263
# Train Epoch: 5 [270/590]	loss: 0.249312
# Train Epoch: 5 [280/590]	loss: 0.104946
# Train Epoch: 5 [290/590]	loss: 0.782379
# Train Epoch: 5 [300/590]	loss: 0.125463
# Train Epoch: 5 [310/590]	loss: 0.066763
# Train Epoch: 5 [320/590]	loss: 0.440372
# Train Epoch: 5 [330/590]	loss: 0.075356
# Train Epoch: 5 [340/590]	loss: 0.045501
# Train Epoch: 5 [350/590]	loss: 0.505712
# Train Epoch: 5 [360/590]	loss: 0.235798
# Train Epoch: 5 [370/590]	loss: 0.264143
# Train Epoch: 5 [380/590]	loss: 0.050939
# Train Epoch: 5 [390/590]	loss: 0.082151
# Train Epoch: 5 [400/590]	loss: 0.372741
# Train Epoch: 5 [410/590]	loss: 0.193323
# Train Epoch: 5 [420/590]	loss: 0.601778
# Train Epoch: 5 [430/590]	loss: 0.075907
# Train Epoch: 5 [440/590]	loss: 0.098201
# Train Epoch: 5 [450/590]	loss: 0.082332
# Train Epoch: 5 [460/590]	loss: 0.249948
# Train Epoch: 5 [470/590]	loss: 0.401372
# Train Epoch: 5 [480/590]	loss: 0.337782
# Train Epoch: 5 [490/590]	loss: 0.105544
# Train Epoch: 5 [500/590]	loss: 0.271206
# Train Epoch: 5 [510/590]	loss: 0.221068
# Train Epoch: 5 [520/590]	loss: 0.331601
# Train Epoch: 5 [530/590]	loss: 0.083712
# Train Epoch: 5 [540/590]	loss: 0.051644
# Train Epoch: 5 [550/590]	loss: 0.293444
# Train Epoch: 5 [560/590]	loss: 0.374494
# Train Epoch: 5 [570/590]	loss: 0.282499
# Train Epoch: 5 [580/590]	loss: 0.081498
# [5]Validation Loss: 0.2717,Accuracy: 92.2297%
# Train Epoch: 6 [0/590]	loss: 0.135273
# Train Epoch: 6 [10/590]	loss: 0.539493
# Train Epoch: 6 [20/590]	loss: 0.194444
# Train Epoch: 6 [30/590]	loss: 0.140799
# Train Epoch: 6 [40/590]	loss: 0.076401
# Train Epoch: 6 [50/590]	loss: 0.239597
# Train Epoch: 6 [60/590]	loss: 0.100251
# Train Epoch: 6 [70/590]	loss: 0.125155
# Train Epoch: 6 [80/590]	loss: 0.520391
# Train Epoch: 6 [90/590]	loss: 0.402910
# Train Epoch: 6 [100/590]	loss: 0.238998
# Train Epoch: 6 [110/590]	loss: 0.024896
# Train Epoch: 6 [120/590]	loss: 0.145369
# Train Epoch: 6 [130/590]	loss: 0.158859
# Train Epoch: 6 [140/590]	loss: 0.383344
# Train Epoch: 6 [150/590]	loss: 0.024262
# Train Epoch: 6 [160/590]	loss: 0.300751
# Train Epoch: 6 [170/590]	loss: 0.151490
# Train Epoch: 6 [180/590]	loss: 0.085061
# Train Epoch: 6 [190/590]	loss: 0.229545
# Train Epoch: 6 [200/590]	loss: 0.230328
# Train Epoch: 6 [210/590]	loss: 0.100623
# Train Epoch: 6 [220/590]	loss: 0.675757
# Train Epoch: 6 [230/590]	loss: 0.199949
# Train Epoch: 6 [240/590]	loss: 0.370501
# Train Epoch: 6 [250/590]	loss: 0.247616
# Train Epoch: 6 [260/590]	loss: 0.354002
# Train Epoch: 6 [270/590]	loss: 0.253378
# Train Epoch: 6 [280/590]	loss: 0.134237
# Train Epoch: 6 [290/590]	loss: 0.188379
# Train Epoch: 6 [300/590]	loss: 0.153479
# Train Epoch: 6 [310/590]	loss: 0.584746
# Train Epoch: 6 [320/590]	loss: 0.110265
# Train Epoch: 6 [330/590]	loss: 0.203618
# Train Epoch: 6 [340/590]	loss: 0.182598
# Train Epoch: 6 [350/590]	loss: 0.125288
# Train Epoch: 6 [360/590]	loss: 0.245868
# Train Epoch: 6 [370/590]	loss: 0.033154
# Train Epoch: 6 [380/590]	loss: 1.242234
# Train Epoch: 6 [390/590]	loss: 0.197800
# Train Epoch: 6 [400/590]	loss: 0.120767
# Train Epoch: 6 [410/590]	loss: 0.145612
# Train Epoch: 6 [420/590]	loss: 0.179927
# Train Epoch: 6 [430/590]	loss: 0.145893
# Train Epoch: 6 [440/590]	loss: 0.271898
# Train Epoch: 6 [450/590]	loss: 0.338516
# Train Epoch: 6 [460/590]	loss: 0.269990
# Train Epoch: 6 [470/590]	loss: 0.101756
# Train Epoch: 6 [480/590]	loss: 0.112491
# Train Epoch: 6 [490/590]	loss: 0.474438
# Train Epoch: 6 [500/590]	loss: 0.217129
# Train Epoch: 6 [510/590]	loss: 0.049086
# Train Epoch: 6 [520/590]	loss: 0.112187
# Train Epoch: 6 [530/590]	loss: 0.131632
# Train Epoch: 6 [540/590]	loss: 0.207806
# Train Epoch: 6 [550/590]	loss: 0.436516
# Train Epoch: 6 [560/590]	loss: 0.244520
# Train Epoch: 6 [570/590]	loss: 0.394769
# Train Epoch: 6 [580/590]	loss: 0.034907
# [6]Validation Loss: 0.2563,Accuracy: 93.2432%
# Train Epoch: 7 [0/590]	loss: 0.178071
# Train Epoch: 7 [10/590]	loss: 0.165493
# Train Epoch: 7 [20/590]	loss: 0.052932
# Train Epoch: 7 [30/590]	loss: 0.062415
# Train Epoch: 7 [40/590]	loss: 0.140113
# Train Epoch: 7 [50/590]	loss: 0.068664
# Train Epoch: 7 [60/590]	loss: 0.139230
# Train Epoch: 7 [70/590]	loss: 0.034720
# Train Epoch: 7 [80/590]	loss: 0.057665
# Train Epoch: 7 [90/590]	loss: 0.353126
# Train Epoch: 7 [100/590]	loss: 0.014301
# Train Epoch: 7 [110/590]	loss: 0.115507
# Train Epoch: 7 [120/590]	loss: 0.511065
# Train Epoch: 7 [130/590]	loss: 0.299821
# Train Epoch: 7 [140/590]	loss: 0.661054
# Train Epoch: 7 [150/590]	loss: 0.309733
# Train Epoch: 7 [160/590]	loss: 0.717171
# Train Epoch: 7 [170/590]	loss: 0.035203
# Train Epoch: 7 [180/590]	loss: 0.678816
# Train Epoch: 7 [190/590]	loss: 0.420538
# Train Epoch: 7 [200/590]	loss: 0.184167
# Train Epoch: 7 [210/590]	loss: 0.369949
# Train Epoch: 7 [220/590]	loss: 0.448517
# Train Epoch: 7 [230/590]	loss: 0.166576
# Train Epoch: 7 [240/590]	loss: 0.047073
# Train Epoch: 7 [250/590]	loss: 0.058124
# Train Epoch: 7 [260/590]	loss: 0.854563
# Train Epoch: 7 [270/590]	loss: 0.217675
# Train Epoch: 7 [280/590]	loss: 0.059987
# Train Epoch: 7 [290/590]	loss: 0.755566
# Train Epoch: 7 [300/590]	loss: 0.162998
# Train Epoch: 7 [310/590]	loss: 0.524286
# Train Epoch: 7 [320/590]	loss: 0.031892
# Train Epoch: 7 [330/590]	loss: 0.130090
# Train Epoch: 7 [340/590]	loss: 0.383338
# Train Epoch: 7 [350/590]	loss: 0.101509
# Train Epoch: 7 [360/590]	loss: 0.036479
# Train Epoch: 7 [370/590]	loss: 0.102379
# Train Epoch: 7 [380/590]	loss: 0.188240
# Train Epoch: 7 [390/590]	loss: 0.270532
# Train Epoch: 7 [400/590]	loss: 0.113651
# Train Epoch: 7 [410/590]	loss: 0.730411
# Train Epoch: 7 [420/590]	loss: 0.387279
# Train Epoch: 7 [430/590]	loss: 0.166821
# Train Epoch: 7 [440/590]	loss: 0.077718
# Train Epoch: 7 [450/590]	loss: 0.040427
# Train Epoch: 7 [460/590]	loss: 0.035094
# Train Epoch: 7 [470/590]	loss: 0.029043
# Train Epoch: 7 [480/590]	loss: 0.122868
# Train Epoch: 7 [490/590]	loss: 0.185266
# Train Epoch: 7 [500/590]	loss: 0.021610
# Train Epoch: 7 [510/590]	loss: 0.060279
# Train Epoch: 7 [520/590]	loss: 0.023409
# Train Epoch: 7 [530/590]	loss: 0.096244
# Train Epoch: 7 [540/590]	loss: 0.075367
# Train Epoch: 7 [550/590]	loss: 0.155240
# Train Epoch: 7 [560/590]	loss: 0.022777
# Train Epoch: 7 [570/590]	loss: 0.257010
# Train Epoch: 7 [580/590]	loss: 0.269527
# [7]Validation Loss: 0.3086,Accuracy: 92.5676%
# Train Epoch: 8 [0/590]	loss: 0.035303
# Train Epoch: 8 [10/590]	loss: 0.198516
# Train Epoch: 8 [20/590]	loss: 0.391601
# Train Epoch: 8 [30/590]	loss: 0.526145
# Train Epoch: 8 [40/590]	loss: 0.080493
# Train Epoch: 8 [50/590]	loss: 0.079175
# Train Epoch: 8 [60/590]	loss: 0.077360
# Train Epoch: 8 [70/590]	loss: 0.061352
# Train Epoch: 8 [80/590]	loss: 0.364078
# Train Epoch: 8 [90/590]	loss: 0.057149
# Train Epoch: 8 [100/590]	loss: 0.097378
# Train Epoch: 8 [110/590]	loss: 0.046512
# Train Epoch: 8 [120/590]	loss: 0.348139
# Train Epoch: 8 [130/590]	loss: 0.111459
# Train Epoch: 8 [140/590]	loss: 0.027863
# Train Epoch: 8 [150/590]	loss: 0.118889
# Train Epoch: 8 [160/590]	loss: 0.344185
# Train Epoch: 8 [170/590]	loss: 0.427824
# Train Epoch: 8 [180/590]	loss: 0.068132
# Train Epoch: 8 [190/590]	loss: 0.622263
# Train Epoch: 8 [200/590]	loss: 0.124998
# Train Epoch: 8 [210/590]	loss: 0.074612
# Train Epoch: 8 [220/590]	loss: 0.112022
# Train Epoch: 8 [230/590]	loss: 0.025950
# Train Epoch: 8 [240/590]	loss: 0.461857
# Train Epoch: 8 [250/590]	loss: 0.084832
# Train Epoch: 8 [260/590]	loss: 0.027990
# Train Epoch: 8 [270/590]	loss: 0.063681
# Train Epoch: 8 [280/590]	loss: 0.099877
# Train Epoch: 8 [290/590]	loss: 0.224440
# Train Epoch: 8 [300/590]	loss: 0.233112
# Train Epoch: 8 [310/590]	loss: 0.164107
# Train Epoch: 8 [320/590]	loss: 0.117306
# Train Epoch: 8 [330/590]	loss: 0.172554
# Train Epoch: 8 [340/590]	loss: 0.283914
# Train Epoch: 8 [350/590]	loss: 0.146204
# Train Epoch: 8 [360/590]	loss: 0.144429
# Train Epoch: 8 [370/590]	loss: 0.208607
# Train Epoch: 8 [380/590]	loss: 0.507524
# Train Epoch: 8 [390/590]	loss: 0.087645
# Train Epoch: 8 [400/590]	loss: 0.145985
# Train Epoch: 8 [410/590]	loss: 0.050975
# Train Epoch: 8 [420/590]	loss: 0.324730
# Train Epoch: 8 [430/590]	loss: 0.029870
# Train Epoch: 8 [440/590]	loss: 0.529581
# Train Epoch: 8 [450/590]	loss: 0.082244
# Train Epoch: 8 [460/590]	loss: 0.182126
# Train Epoch: 8 [470/590]	loss: 0.057943
# Train Epoch: 8 [480/590]	loss: 0.391948
# Train Epoch: 8 [490/590]	loss: 0.425796
# Train Epoch: 8 [500/590]	loss: 0.246631
# Train Epoch: 8 [510/590]	loss: 0.310168
# Train Epoch: 8 [520/590]	loss: 0.163295
# Train Epoch: 8 [530/590]	loss: 0.251979
# Train Epoch: 8 [540/590]	loss: 0.050074
# Train Epoch: 8 [550/590]	loss: 0.036814
# Train Epoch: 8 [560/590]	loss: 0.066453
# Train Epoch: 8 [570/590]	loss: 0.061117
# Train Epoch: 8 [580/590]	loss: 0.011568
# [8]Validation Loss: 0.2939,Accuracy: 91.8919%
# Train Epoch: 9 [0/590]	loss: 0.036608
# Train Epoch: 9 [10/590]	loss: 0.093344
# Train Epoch: 9 [20/590]	loss: 0.015864
# Train Epoch: 9 [30/590]	loss: 0.213103
# Train Epoch: 9 [40/590]	loss: 0.088950
# Train Epoch: 9 [50/590]	loss: 0.151179
# Train Epoch: 9 [60/590]	loss: 0.024123
# Train Epoch: 9 [70/590]	loss: 0.080199
# Train Epoch: 9 [80/590]	loss: 0.088769
# Train Epoch: 9 [90/590]	loss: 0.120270
# Train Epoch: 9 [100/590]	loss: 0.037985
# Train Epoch: 9 [110/590]	loss: 0.179051
# Train Epoch: 9 [120/590]	loss: 0.041156
# Train Epoch: 9 [130/590]	loss: 0.140672
# Train Epoch: 9 [140/590]	loss: 0.034446
# Train Epoch: 9 [150/590]	loss: 0.057833
# Train Epoch: 9 [160/590]	loss: 0.021480
# Train Epoch: 9 [170/590]	loss: 0.012641
# Train Epoch: 9 [180/590]	loss: 0.057049
# Train Epoch: 9 [190/590]	loss: 0.279953
# Train Epoch: 9 [200/590]	loss: 0.054537
# Train Epoch: 9 [210/590]	loss: 0.227546
# Train Epoch: 9 [220/590]	loss: 0.124640
# Train Epoch: 9 [230/590]	loss: 0.032870
# Train Epoch: 9 [240/590]	loss: 0.197163
# Train Epoch: 9 [250/590]	loss: 0.024154
# Train Epoch: 9 [260/590]	loss: 0.097223
# Train Epoch: 9 [270/590]	loss: 0.102653
# Train Epoch: 9 [280/590]	loss: 0.049979
# Train Epoch: 9 [290/590]	loss: 0.062656
# Train Epoch: 9 [300/590]	loss: 0.219256
# Train Epoch: 9 [310/590]	loss: 0.328764
# Train Epoch: 9 [320/590]	loss: 0.249881
# Train Epoch: 9 [330/590]	loss: 0.248876
# Train Epoch: 9 [340/590]	loss: 0.008980
# Train Epoch: 9 [350/590]	loss: 0.104654
# Train Epoch: 9 [360/590]	loss: 0.094517
# Train Epoch: 9 [370/590]	loss: 0.103274
# Train Epoch: 9 [380/590]	loss: 0.303974
# Train Epoch: 9 [390/590]	loss: 0.219248
# Train Epoch: 9 [400/590]	loss: 0.026777
# Train Epoch: 9 [410/590]	loss: 0.049071
# Train Epoch: 9 [420/590]	loss: 0.170203
# Train Epoch: 9 [430/590]	loss: 0.191030
# Train Epoch: 9 [440/590]	loss: 0.065487
# Train Epoch: 9 [450/590]	loss: 0.473513
# Train Epoch: 9 [460/590]	loss: 0.069323
# Train Epoch: 9 [470/590]	loss: 0.010996
# Train Epoch: 9 [480/590]	loss: 0.578913
# Train Epoch: 9 [490/590]	loss: 0.054368
# Train Epoch: 9 [500/590]	loss: 0.156451
# Train Epoch: 9 [510/590]	loss: 0.039985
# Train Epoch: 9 [520/590]	loss: 0.101012
# Train Epoch: 9 [530/590]	loss: 0.118147
# Train Epoch: 9 [540/590]	loss: 0.037448
# Train Epoch: 9 [550/590]	loss: 0.039796
# Train Epoch: 9 [560/590]	loss: 0.048742
# Train Epoch: 9 [570/590]	loss: 0.223505
# Train Epoch: 9 [580/590]	loss: 0.221518
# [9]Validation Loss: 0.3226,Accuracy: 90.5405%
# [FINAL] Test Loss: 0.3607,Accuracy: 90.9396%
# Best Accuracy:  93.24324324324324
# Elasped Time: 0h, 45m, 53s
# time: 0h, 45m, 53s

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

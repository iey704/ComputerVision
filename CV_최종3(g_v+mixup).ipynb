# %% [markdown]
# <a href="https://colab.research.google.com/github/iey704/ComputerVision/blob/main/CV_%EC%B5%9C%EC%A2%853(g_v%2Bmixup).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * AdamP
# * lr=0.0001
# * batch=32
# * epoch=20
# * Data Augmentation:Geomentric transform + Visual corruptions + Mixup

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5981 sha256=a71113339c45c3a11c01f6a7a01a3438883fe5ee847e078f005860c5be9e3f97
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
# !pip install randaugment
# Out:
# Collecting randaugment
#   Downloading randaugment-1.0.2-py3-none-any.whl (6.8 kB)
# Installing collected packages: randaugment
# Successfully installed randaugment-1.0.2

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor,Normalize, RandomHorizontalFlip, Resize
from torchvision.transforms import RandAugment
from torch.utils.data import Dataset, DataLoader

import torchvision.models as models

from adamp import AdamP
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageFilter,ImageEnhance

from torch.utils.data import ConcatDataset
from collections import Counter


# 랜덤 시드 설정 공통
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
# Create DataLoader
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.mode = mode
    self.transform = transform

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)

    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# MIX UP
def mixup_data(x, y, alpha=1.0):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size, device=x.device, dtype=torch.long)  # GPU에 있는 x.device를 사용하여 인덱스를 GPU로 전송

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# 2)Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 32 # or 64

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

# 데이터 증강을 위해 원래 데이터를 복사하고 추가
train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

train_loader_b = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# 3) Mixup된 이미지를 train_loader에 추가
train_set_mixup = []

for input, target in train_loader_b:
    mixed_input, target_a, target_b, lam = mixup_data(input, target, alpha=1.0)
    train_set_mixup.append((mixed_input, target_a, target_b, lam))

train_set_mixup = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

train_set_mixup = CUB2011(mode='train', transform=train_set_mixup)

#print('Num of each dataset: ',len(train_set_origin),len(replicated_data),
      #len(train_set_augmented),len(train_set_augmented2),len(train_set_mixup))

print('Num of each dataset: ',len(train_set_origin),len(train_set_augmented2),len(train_set_mixup))#,len(train_set_augmented)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2,train_set_mixup])#train_set_augmented

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  2360 2360 2360
# Num of each dataset:  7080 296 298
# Loaded dataloader

# %%
num_rows = 4  # You can change this to the desired number of rows
num_cols = 4  # You can change this to the desired number of columns

# Function to unnormalize and display a grid of images
def imshow_grid(images, num_rows, num_cols):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 10))
    fig.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots
    for i in range(num_rows):
        for j in range(num_cols):
            index = i * num_cols + j
            if index < len(images):
                img = images[index]
                npimg = img.numpy()
                ax = axes[i, j]
                ax.imshow(np.transpose(npimg, (1, 2, 0)))
                ax.axis('off')

    plt.show()

# Iterate through the train_loader
for batch_idx, (images, labels) in enumerate(train_loader):
    if batch_idx >= 3:
        break  # Stop after visualizing the specified number of batches

    print(f"Batch {batch_idx + 1}")
    imshow_grid(images, num_rows, num_cols)  # Display the grid of images
# Out:
# Batch 1
# Batch 2
# Batch 3

# %%
# 스케줄러 사용
from torch.optim.lr_scheduler import CosineAnnealingLR

### Model / Optimizer ###
EPOCH = 20
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
'''
model.fc = nn.Sequential(
    nn.Linear(num_features,256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, 50)  # 클래스 수에 맞게 조정
)#선택
'''
model.to(DEVICE)

optimizer = AdamP(model.parameters(),lr=lr)

# 스케줄러 초기화 (주기와 최소/최대 학습률 설정)
scheduler = CosineAnnealingLR(optimizer, T_max=10, eta_min=0.001)

print("Created a learning model and optimizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 114MB/s]
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    # 스케줄러 업데이트
    #scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/222]	loss: 3.984481
# Train Epoch: 0 [10/222]	loss: 3.992002
# Train Epoch: 0 [20/222]	loss: 3.744279
# Train Epoch: 0 [30/222]	loss: 3.355768
# Train Epoch: 0 [40/222]	loss: 2.995498
# Train Epoch: 0 [50/222]	loss: 3.142088
# Train Epoch: 0 [60/222]	loss: 2.661609
# Train Epoch: 0 [70/222]	loss: 2.805583
# Train Epoch: 0 [80/222]	loss: 2.670600
# Train Epoch: 0 [90/222]	loss: 2.251592
# Train Epoch: 0 [100/222]	loss: 2.237827
# Train Epoch: 0 [110/222]	loss: 2.334211
# Train Epoch: 0 [120/222]	loss: 2.291135
# Train Epoch: 0 [130/222]	loss: 1.693613
# Train Epoch: 0 [140/222]	loss: 1.711063
# Train Epoch: 0 [150/222]	loss: 1.834178
# Train Epoch: 0 [160/222]	loss: 1.867663
# Train Epoch: 0 [170/222]	loss: 1.699486
# Train Epoch: 0 [180/222]	loss: 1.611713
# Train Epoch: 0 [190/222]	loss: 1.600664
# Train Epoch: 0 [200/222]	loss: 1.527057
# Train Epoch: 0 [210/222]	loss: 1.170914
# Train Epoch: 0 [220/222]	loss: 1.133768
# [0]Validation Loss: 1.2092,Accuracy: 80.0676%
# Train Epoch: 1 [0/222]	loss: 0.991438
# Train Epoch: 1 [10/222]	loss: 0.967796
# Train Epoch: 1 [20/222]	loss: 1.110529
# Train Epoch: 1 [30/222]	loss: 1.168508
# Train Epoch: 1 [40/222]	loss: 0.973836
# Train Epoch: 1 [50/222]	loss: 0.794232
# Train Epoch: 1 [60/222]	loss: 0.949368
# Train Epoch: 1 [70/222]	loss: 0.966192
# Train Epoch: 1 [80/222]	loss: 0.938510
# Train Epoch: 1 [90/222]	loss: 0.856810
# Train Epoch: 1 [100/222]	loss: 1.000731
# Train Epoch: 1 [110/222]	loss: 0.707005
# Train Epoch: 1 [120/222]	loss: 0.711113
# Train Epoch: 1 [130/222]	loss: 0.774563
# Train Epoch: 1 [140/222]	loss: 0.814541
# Train Epoch: 1 [150/222]	loss: 0.885711
# Train Epoch: 1 [160/222]	loss: 0.552886
# Train Epoch: 1 [170/222]	loss: 1.051220
# Train Epoch: 1 [180/222]	loss: 0.508907
# Train Epoch: 1 [190/222]	loss: 0.624870
# Train Epoch: 1 [200/222]	loss: 0.704022
# Train Epoch: 1 [210/222]	loss: 0.410336
# Train Epoch: 1 [220/222]	loss: 0.565485
# [1]Validation Loss: 0.8651,Accuracy: 84.7973%
# Train Epoch: 2 [0/222]	loss: 0.585657
# Train Epoch: 2 [10/222]	loss: 0.472564
# Train Epoch: 2 [20/222]	loss: 0.482367
# Train Epoch: 2 [30/222]	loss: 0.348672
# Train Epoch: 2 [40/222]	loss: 0.438122
# Train Epoch: 2 [50/222]	loss: 0.335320
# Train Epoch: 2 [60/222]	loss: 0.236093
# Train Epoch: 2 [70/222]	loss: 0.432451
# Train Epoch: 2 [80/222]	loss: 0.473982
# Train Epoch: 2 [90/222]	loss: 0.465053
# Train Epoch: 2 [100/222]	loss: 0.307254
# Train Epoch: 2 [110/222]	loss: 0.394332
# Train Epoch: 2 [120/222]	loss: 0.324019
# Train Epoch: 2 [130/222]	loss: 0.298434
# Train Epoch: 2 [140/222]	loss: 0.302413
# Train Epoch: 2 [150/222]	loss: 0.378918
# Train Epoch: 2 [160/222]	loss: 0.209042
# Train Epoch: 2 [170/222]	loss: 0.279963
# Train Epoch: 2 [180/222]	loss: 0.494874
# Train Epoch: 2 [190/222]	loss: 0.330324
# Train Epoch: 2 [200/222]	loss: 0.362657
# Train Epoch: 2 [210/222]	loss: 0.391751
# Train Epoch: 2 [220/222]	loss: 0.381961
# [2]Validation Loss: 0.7085,Accuracy: 86.8243%
# Train Epoch: 3 [0/222]	loss: 0.420261
# Train Epoch: 3 [10/222]	loss: 0.257099
# Train Epoch: 3 [20/222]	loss: 0.275034
# Train Epoch: 3 [30/222]	loss: 0.275132
# Train Epoch: 3 [40/222]	loss: 0.179742
# Train Epoch: 3 [50/222]	loss: 0.203401
# Train Epoch: 3 [60/222]	loss: 0.185534
# Train Epoch: 3 [70/222]	loss: 0.328897
# Train Epoch: 3 [80/222]	loss: 0.420903
# Train Epoch: 3 [90/222]	loss: 0.310304
# Train Epoch: 3 [100/222]	loss: 0.254034
# Train Epoch: 3 [110/222]	loss: 0.291446
# Train Epoch: 3 [120/222]	loss: 0.244405
# Train Epoch: 3 [130/222]	loss: 0.447011
# Train Epoch: 3 [140/222]	loss: 0.267324
# Train Epoch: 3 [150/222]	loss: 0.181259
# Train Epoch: 3 [160/222]	loss: 0.139455
# Train Epoch: 3 [170/222]	loss: 0.143028
# Train Epoch: 3 [180/222]	loss: 0.472973
# Train Epoch: 3 [190/222]	loss: 0.353139
# Train Epoch: 3 [200/222]	loss: 0.245708
# Train Epoch: 3 [210/222]	loss: 0.325356
# Train Epoch: 3 [220/222]	loss: 0.445367
# [3]Validation Loss: 0.5965,Accuracy: 88.5135%
# Train Epoch: 4 [0/222]	loss: 0.188770
# Train Epoch: 4 [10/222]	loss: 0.149963
# Train Epoch: 4 [20/222]	loss: 0.263760
# Train Epoch: 4 [30/222]	loss: 0.143005
# Train Epoch: 4 [40/222]	loss: 0.226014
# Train Epoch: 4 [50/222]	loss: 0.109047
# Train Epoch: 4 [60/222]	loss: 0.158044
# Train Epoch: 4 [70/222]	loss: 0.102694
# Train Epoch: 4 [80/222]	loss: 0.232825
# Train Epoch: 4 [90/222]	loss: 0.212836
# Train Epoch: 4 [100/222]	loss: 0.184640
# Train Epoch: 4 [110/222]	loss: 0.249316
# Train Epoch: 4 [120/222]	loss: 0.115552
# Train Epoch: 4 [130/222]	loss: 0.127197
# Train Epoch: 4 [140/222]	loss: 0.113095
# Train Epoch: 4 [150/222]	loss: 0.079582
# Train Epoch: 4 [160/222]	loss: 0.122373
# Train Epoch: 4 [170/222]	loss: 0.050586
# Train Epoch: 4 [180/222]	loss: 0.123798
# Train Epoch: 4 [190/222]	loss: 0.129015
# Train Epoch: 4 [200/222]	loss: 0.135483
# Train Epoch: 4 [210/222]	loss: 0.300692
# Train Epoch: 4 [220/222]	loss: 0.154119
# [4]Validation Loss: 0.5654,Accuracy: 87.1622%
# Train Epoch: 5 [0/222]	loss: 0.110603
# Train Epoch: 5 [10/222]	loss: 0.149208
# Train Epoch: 5 [20/222]	loss: 0.170441
# Train Epoch: 5 [30/222]	loss: 0.208552
# Train Epoch: 5 [40/222]	loss: 0.060936
# Train Epoch: 5 [50/222]	loss: 0.058638
# Train Epoch: 5 [60/222]	loss: 0.133104
# Train Epoch: 5 [70/222]	loss: 0.202332
# Train Epoch: 5 [80/222]	loss: 0.088939
# Train Epoch: 5 [90/222]	loss: 0.089016
# Train Epoch: 5 [100/222]	loss: 0.142354
# Train Epoch: 5 [110/222]	loss: 0.098699
# Train Epoch: 5 [120/222]	loss: 0.221258
# Train Epoch: 5 [130/222]	loss: 0.104292
# Train Epoch: 5 [140/222]	loss: 0.088119
# Train Epoch: 5 [150/222]	loss: 0.105964
# Train Epoch: 5 [160/222]	loss: 0.128183
# Train Epoch: 5 [170/222]	loss: 0.053419
# Train Epoch: 5 [180/222]	loss: 0.095978
# Train Epoch: 5 [190/222]	loss: 0.088536
# Train Epoch: 5 [200/222]	loss: 0.170959
# Train Epoch: 5 [210/222]	loss: 0.150037
# Train Epoch: 5 [220/222]	loss: 0.140556
# [5]Validation Loss: 0.5636,Accuracy: 87.8378%
# Train Epoch: 6 [0/222]	loss: 0.187161
# Train Epoch: 6 [10/222]	loss: 0.043926
# Train Epoch: 6 [20/222]	loss: 0.077544
# Train Epoch: 6 [30/222]	loss: 0.079660
# Train Epoch: 6 [40/222]	loss: 0.066636
# Train Epoch: 6 [50/222]	loss: 0.177926
# Train Epoch: 6 [60/222]	loss: 0.119556
# Train Epoch: 6 [70/222]	loss: 0.111440
# Train Epoch: 6 [80/222]	loss: 0.091305
# Train Epoch: 6 [90/222]	loss: 0.062679
# Train Epoch: 6 [100/222]	loss: 0.107102
# Train Epoch: 6 [110/222]	loss: 0.218485
# Train Epoch: 6 [120/222]	loss: 0.162671
# Train Epoch: 6 [130/222]	loss: 0.085718
# Train Epoch: 6 [140/222]	loss: 0.053988
# Train Epoch: 6 [150/222]	loss: 0.090175
# Train Epoch: 6 [160/222]	loss: 0.060978
# Train Epoch: 6 [170/222]	loss: 0.091293
# Train Epoch: 6 [180/222]	loss: 0.173125
# Train Epoch: 6 [190/222]	loss: 0.121534
# Train Epoch: 6 [200/222]	loss: 0.053977
# Train Epoch: 6 [210/222]	loss: 0.279708
# Train Epoch: 6 [220/222]	loss: 0.044321
# [6]Validation Loss: 0.5685,Accuracy: 88.5135%
# Train Epoch: 7 [0/222]	loss: 0.111500
# Train Epoch: 7 [10/222]	loss: 0.050960
# Train Epoch: 7 [20/222]	loss: 0.094063
# Train Epoch: 7 [30/222]	loss: 0.060533
# Train Epoch: 7 [40/222]	loss: 0.202393
# Train Epoch: 7 [50/222]	loss: 0.048545
# Train Epoch: 7 [60/222]	loss: 0.034298
# Train Epoch: 7 [70/222]	loss: 0.075749
# Train Epoch: 7 [80/222]	loss: 0.097947
# Train Epoch: 7 [90/222]	loss: 0.059231
# Train Epoch: 7 [100/222]	loss: 0.049832
# Train Epoch: 7 [110/222]	loss: 0.047347
# Train Epoch: 7 [120/222]	loss: 0.060867
# Train Epoch: 7 [130/222]	loss: 0.085317
# Train Epoch: 7 [140/222]	loss: 0.043367
# Train Epoch: 7 [150/222]	loss: 0.029319
# Train Epoch: 7 [160/222]	loss: 0.227079
# Train Epoch: 7 [170/222]	loss: 0.085673
# Train Epoch: 7 [180/222]	loss: 0.044532
# Train Epoch: 7 [190/222]	loss: 0.080685
# Train Epoch: 7 [200/222]	loss: 0.117249
# Train Epoch: 7 [210/222]	loss: 0.051520
# Train Epoch: 7 [220/222]	loss: 0.050258
# [7]Validation Loss: 0.5510,Accuracy: 88.1757%
# Train Epoch: 8 [0/222]	loss: 0.019850
# Train Epoch: 8 [10/222]	loss: 0.118824
# Train Epoch: 8 [20/222]	loss: 0.054094
# Train Epoch: 8 [30/222]	loss: 0.031445
# Train Epoch: 8 [40/222]	loss: 0.033048
# Train Epoch: 8 [50/222]	loss: 0.106245
# Train Epoch: 8 [60/222]	loss: 0.061481
# Train Epoch: 8 [70/222]	loss: 0.043319
# Train Epoch: 8 [80/222]	loss: 0.026063
# Train Epoch: 8 [90/222]	loss: 0.033230
# Train Epoch: 8 [100/222]	loss: 0.113968
# Train Epoch: 8 [110/222]	loss: 0.095128
# Train Epoch: 8 [120/222]	loss: 0.073200
# Train Epoch: 8 [130/222]	loss: 0.187890
# Train Epoch: 8 [140/222]	loss: 0.026560
# Train Epoch: 8 [150/222]	loss: 0.091990
# Train Epoch: 8 [160/222]	loss: 0.072732
# Train Epoch: 8 [170/222]	loss: 0.081359
# Train Epoch: 8 [180/222]	loss: 0.029827
# Train Epoch: 8 [190/222]	loss: 0.019228
# Train Epoch: 8 [200/222]	loss: 0.128458
# Train Epoch: 8 [210/222]	loss: 0.088522
# Train Epoch: 8 [220/222]	loss: 0.107519
# [8]Validation Loss: 0.5709,Accuracy: 86.4865%
# Train Epoch: 9 [0/222]	loss: 0.055234
# Train Epoch: 9 [10/222]	loss: 0.072575
# Train Epoch: 9 [20/222]	loss: 0.118498
# Train Epoch: 9 [30/222]	loss: 0.031765
# Train Epoch: 9 [40/222]	loss: 0.094533
# Train Epoch: 9 [50/222]	loss: 0.023101
# Train Epoch: 9 [60/222]	loss: 0.034490
# Train Epoch: 9 [70/222]	loss: 0.028575
# Train Epoch: 9 [80/222]	loss: 0.020452
# Train Epoch: 9 [90/222]	loss: 0.014176
# Train Epoch: 9 [100/222]	loss: 0.020600
# Train Epoch: 9 [110/222]	loss: 0.026387
# Train Epoch: 9 [120/222]	loss: 0.122691
# Train Epoch: 9 [130/222]	loss: 0.017368
# Train Epoch: 9 [140/222]	loss: 0.051440
# Train Epoch: 9 [150/222]	loss: 0.136713
# Train Epoch: 9 [160/222]	loss: 0.150685
# Train Epoch: 9 [170/222]	loss: 0.033751
# Train Epoch: 9 [180/222]	loss: 0.129903
# Train Epoch: 9 [190/222]	loss: 0.104139
# Train Epoch: 9 [200/222]	loss: 0.035392
# Train Epoch: 9 [210/222]	loss: 0.033192
# Train Epoch: 9 [220/222]	loss: 0.018093
# [9]Validation Loss: 0.5200,Accuracy: 87.5000%
# Train Epoch: 10 [0/222]	loss: 0.040798
# Train Epoch: 10 [10/222]	loss: 0.051606
# Train Epoch: 10 [20/222]	loss: 0.022953
# Train Epoch: 10 [30/222]	loss: 0.050483
# Train Epoch: 10 [40/222]	loss: 0.035809
# Train Epoch: 10 [50/222]	loss: 0.031429
# Train Epoch: 10 [60/222]	loss: 0.017044
# Train Epoch: 10 [70/222]	loss: 0.089850
# Train Epoch: 10 [80/222]	loss: 0.077716
# Train Epoch: 10 [90/222]	loss: 0.021202
# Train Epoch: 10 [100/222]	loss: 0.091446
# Train Epoch: 10 [110/222]	loss: 0.175934
# Train Epoch: 10 [120/222]	loss: 0.183320
# Train Epoch: 10 [130/222]	loss: 0.126306
# Train Epoch: 10 [140/222]	loss: 0.049022
# Train Epoch: 10 [150/222]	loss: 0.173498
# Train Epoch: 10 [160/222]	loss: 0.043842
# Train Epoch: 10 [170/222]	loss: 0.073641
# Train Epoch: 10 [180/222]	loss: 0.065510
# Train Epoch: 10 [190/222]	loss: 0.018692
# Train Epoch: 10 [200/222]	loss: 0.110970
# Train Epoch: 10 [210/222]	loss: 0.090127
# Train Epoch: 10 [220/222]	loss: 0.026816
# [10]Validation Loss: 0.5884,Accuracy: 85.4730%
# Train Epoch: 11 [0/222]	loss: 0.025436
# Train Epoch: 11 [10/222]	loss: 0.078631
# Train Epoch: 11 [20/222]	loss: 0.033735
# Train Epoch: 11 [30/222]	loss: 0.089593
# Train Epoch: 11 [40/222]	loss: 0.014615
# Train Epoch: 11 [50/222]	loss: 0.059326
# Train Epoch: 11 [60/222]	loss: 0.124684
# Train Epoch: 11 [70/222]	loss: 0.040437
# Train Epoch: 11 [80/222]	loss: 0.048087
# Train Epoch: 11 [90/222]	loss: 0.027846
# Train Epoch: 11 [100/222]	loss: 0.158379
# Train Epoch: 11 [110/222]	loss: 0.076624
# Train Epoch: 11 [120/222]	loss: 0.079149
# Train Epoch: 11 [130/222]	loss: 0.043742
# Train Epoch: 11 [140/222]	loss: 0.054351
# Train Epoch: 11 [150/222]	loss: 0.099173
# Train Epoch: 11 [160/222]	loss: 0.024683
# Train Epoch: 11 [170/222]	loss: 0.108746
# Train Epoch: 11 [180/222]	loss: 0.052580
# Train Epoch: 11 [190/222]	loss: 0.076571
# Train Epoch: 11 [200/222]	loss: 0.050142
# Train Epoch: 11 [210/222]	loss: 0.018772
# Train Epoch: 11 [220/222]	loss: 0.032606
# [11]Validation Loss: 0.5121,Accuracy: 88.1757%
# Train Epoch: 12 [0/222]	loss: 0.033429
# Train Epoch: 12 [10/222]	loss: 0.106586
# Train Epoch: 12 [20/222]	loss: 0.048242
# Train Epoch: 12 [30/222]	loss: 0.087446
# Train Epoch: 12 [40/222]	loss: 0.078068
# Train Epoch: 12 [50/222]	loss: 0.037832
# Train Epoch: 12 [60/222]	loss: 0.020021
# Train Epoch: 12 [70/222]	loss: 0.019602
# Train Epoch: 12 [80/222]	loss: 0.034866
# Train Epoch: 12 [90/222]	loss: 0.064599
# Train Epoch: 12 [100/222]	loss: 0.166608
# Train Epoch: 12 [110/222]	loss: 0.024540
# Train Epoch: 12 [120/222]	loss: 0.060352
# Train Epoch: 12 [130/222]	loss: 0.167565
# Train Epoch: 12 [140/222]	loss: 0.014563
# Train Epoch: 12 [150/222]	loss: 0.125629
# Train Epoch: 12 [160/222]	loss: 0.086877
# Train Epoch: 12 [170/222]	loss: 0.021801
# Train Epoch: 12 [180/222]	loss: 0.072821
# Train Epoch: 12 [190/222]	loss: 0.010996
# Train Epoch: 12 [200/222]	loss: 0.096490
# Train Epoch: 12 [210/222]	loss: 0.062610
# Train Epoch: 12 [220/222]	loss: 0.079371
# [12]Validation Loss: 0.4951,Accuracy: 87.8378%
# Train Epoch: 13 [0/222]	loss: 0.041770
# Train Epoch: 13 [10/222]	loss: 0.051128
# Train Epoch: 13 [20/222]	loss: 0.008888
# Train Epoch: 13 [30/222]	loss: 0.030503
# Train Epoch: 13 [40/222]	loss: 0.006714
# Train Epoch: 13 [50/222]	loss: 0.043239
# Train Epoch: 13 [60/222]	loss: 0.020367
# Train Epoch: 13 [70/222]	loss: 0.034257
# Train Epoch: 13 [80/222]	loss: 0.032992
# Train Epoch: 13 [90/222]	loss: 0.030272
# Train Epoch: 13 [100/222]	loss: 0.014623
# Train Epoch: 13 [110/222]	loss: 0.014976
# Train Epoch: 13 [120/222]	loss: 0.086770
# Train Epoch: 13 [130/222]	loss: 0.023136
# Train Epoch: 13 [140/222]	loss: 0.026794
# Train Epoch: 13 [150/222]	loss: 0.042083
# Train Epoch: 13 [160/222]	loss: 0.041484
# Train Epoch: 13 [170/222]	loss: 0.043102
# Train Epoch: 13 [180/222]	loss: 0.149628
# Train Epoch: 13 [190/222]	loss: 0.062046
# Train Epoch: 13 [200/222]	loss: 0.029577
# Train Epoch: 13 [210/222]	loss: 0.039348
# Train Epoch: 13 [220/222]	loss: 0.032171
# [13]Validation Loss: 0.5464,Accuracy: 87.5000%
# Train Epoch: 14 [0/222]	loss: 0.010653
# Train Epoch: 14 [10/222]	loss: 0.019499
# Train Epoch: 14 [20/222]	loss: 0.067040
# Train Epoch: 14 [30/222]	loss: 0.008615
# Train Epoch: 14 [40/222]	loss: 0.042539
# Train Epoch: 14 [50/222]	loss: 0.044952
# Train Epoch: 14 [60/222]	loss: 0.036606
# Train Epoch: 14 [70/222]	loss: 0.025655
# Train Epoch: 14 [80/222]	loss: 0.021066
# Train Epoch: 14 [90/222]	loss: 0.014349
# Train Epoch: 14 [100/222]	loss: 0.013262
# Train Epoch: 14 [110/222]	loss: 0.017258
# Train Epoch: 14 [120/222]	loss: 0.043313
# Train Epoch: 14 [130/222]	loss: 0.008171
# Train Epoch: 14 [140/222]	loss: 0.031671
# Train Epoch: 14 [150/222]	loss: 0.023049
# Train Epoch: 14 [160/222]	loss: 0.005041
# Train Epoch: 14 [170/222]	loss: 0.065295
# Train Epoch: 14 [180/222]	loss: 0.018456
# Train Epoch: 14 [190/222]	loss: 0.005622
# Train Epoch: 14 [200/222]	loss: 0.089205
# Train Epoch: 14 [210/222]	loss: 0.174483
# Train Epoch: 14 [220/222]	loss: 0.016567
# [14]Validation Loss: 0.6709,Accuracy: 82.4324%
# Train Epoch: 15 [0/222]	loss: 0.030895
# Train Epoch: 15 [10/222]	loss: 0.017220
# Train Epoch: 15 [20/222]	loss: 0.057904
# Train Epoch: 15 [30/222]	loss: 0.011609
# Train Epoch: 15 [40/222]	loss: 0.011007
# Train Epoch: 15 [50/222]	loss: 0.012312
# Train Epoch: 15 [60/222]	loss: 0.014886
# Train Epoch: 15 [70/222]	loss: 0.079423
# Train Epoch: 15 [80/222]	loss: 0.020191
# Train Epoch: 15 [90/222]	loss: 0.097936
# Train Epoch: 15 [100/222]	loss: 0.048882
# Train Epoch: 15 [110/222]	loss: 0.027064
# Train Epoch: 15 [120/222]	loss: 0.039253
# Train Epoch: 15 [130/222]	loss: 0.043825
# Train Epoch: 15 [140/222]	loss: 0.020496
# Train Epoch: 15 [150/222]	loss: 0.006648
# Train Epoch: 15 [160/222]	loss: 0.008355
# Train Epoch: 15 [170/222]	loss: 0.005899
# Train Epoch: 15 [180/222]	loss: 0.005735
# Train Epoch: 15 [190/222]	loss: 0.009158
# Train Epoch: 15 [200/222]	loss: 0.085100
# Train Epoch: 15 [210/222]	loss: 0.011781
# Train Epoch: 15 [220/222]	loss: 0.006119
# [15]Validation Loss: 0.5100,Accuracy: 87.1622%
# Train Epoch: 16 [0/222]	loss: 0.066923
# Train Epoch: 16 [10/222]	loss: 0.055653
# Train Epoch: 16 [20/222]	loss: 0.076179
# Train Epoch: 16 [30/222]	loss: 0.010969
# Train Epoch: 16 [40/222]	loss: 0.057202
# Train Epoch: 16 [50/222]	loss: 0.075347
# Train Epoch: 16 [60/222]	loss: 0.100784
# Train Epoch: 16 [70/222]	loss: 0.023097
# Train Epoch: 16 [80/222]	loss: 0.051443
# Train Epoch: 16 [90/222]	loss: 0.074775
# Train Epoch: 16 [100/222]	loss: 0.015503
# Train Epoch: 16 [110/222]	loss: 0.006760
# Train Epoch: 16 [120/222]	loss: 0.094867
# Train Epoch: 16 [130/222]	loss: 0.031866
# Train Epoch: 16 [140/222]	loss: 0.018201
# Train Epoch: 16 [150/222]	loss: 0.007051
# Train Epoch: 16 [160/222]	loss: 0.078245
# Train Epoch: 16 [170/222]	loss: 0.014688
# Train Epoch: 16 [180/222]	loss: 0.029586
# Train Epoch: 16 [190/222]	loss: 0.034893
# Train Epoch: 16 [200/222]	loss: 0.033277
# Train Epoch: 16 [210/222]	loss: 0.105725
# Train Epoch: 16 [220/222]	loss: 0.085081
# [16]Validation Loss: 0.6320,Accuracy: 84.1216%
# Train Epoch: 17 [0/222]	loss: 0.038782
# Train Epoch: 17 [10/222]	loss: 0.083789
# Train Epoch: 17 [20/222]	loss: 0.093804
# Train Epoch: 17 [30/222]	loss: 0.020899
# Train Epoch: 17 [40/222]	loss: 0.016619
# Train Epoch: 17 [50/222]	loss: 0.023861
# Train Epoch: 17 [60/222]	loss: 0.041244
# Train Epoch: 17 [70/222]	loss: 0.087818
# Train Epoch: 17 [80/222]	loss: 0.015476
# Train Epoch: 17 [90/222]	loss: 0.184856
# Train Epoch: 17 [100/222]	loss: 0.031420
# Train Epoch: 17 [110/222]	loss: 0.010534
# Train Epoch: 17 [120/222]	loss: 0.031069
# Train Epoch: 17 [130/222]	loss: 0.006985
# Train Epoch: 17 [140/222]	loss: 0.019258
# Train Epoch: 17 [150/222]	loss: 0.036768
# Train Epoch: 17 [160/222]	loss: 0.007114
# Train Epoch: 17 [170/222]	loss: 0.040181
# Train Epoch: 17 [180/222]	loss: 0.011238
# Train Epoch: 17 [190/222]	loss: 0.010196
# Train Epoch: 17 [200/222]	loss: 0.011585
# Train Epoch: 17 [210/222]	loss: 0.006196
# Train Epoch: 17 [220/222]	loss: 0.046845
# [17]Validation Loss: 0.5589,Accuracy: 85.8108%
# Train Epoch: 18 [0/222]	loss: 0.006202
# Train Epoch: 18 [10/222]	loss: 0.009607
# Train Epoch: 18 [20/222]	loss: 0.012771
# Train Epoch: 18 [30/222]	loss: 0.010606
# Train Epoch: 18 [40/222]	loss: 0.016012
# Train Epoch: 18 [50/222]	loss: 0.021910
# Train Epoch: 18 [60/222]	loss: 0.067130
# Train Epoch: 18 [70/222]	loss: 0.030456
# Train Epoch: 18 [80/222]	loss: 0.030264
# Train Epoch: 18 [90/222]	loss: 0.042340
# Train Epoch: 18 [100/222]	loss: 0.011446
# Train Epoch: 18 [110/222]	loss: 0.020751
# Train Epoch: 18 [120/222]	loss: 0.052478
# Train Epoch: 18 [130/222]	loss: 0.009402
# Train Epoch: 18 [140/222]	loss: 0.022319
# Train Epoch: 18 [150/222]	loss: 0.026616
# Train Epoch: 18 [160/222]	loss: 0.043045
# Train Epoch: 18 [170/222]	loss: 0.015004
# Train Epoch: 18 [180/222]	loss: 0.012493
# Train Epoch: 18 [190/222]	loss: 0.094720
# Train Epoch: 18 [200/222]	loss: 0.043489
# Train Epoch: 18 [210/222]	loss: 0.006701
# Train Epoch: 18 [220/222]	loss: 0.028473
# [18]Validation Loss: 0.4738,Accuracy: 89.5270%
# Train Epoch: 19 [0/222]	loss: 0.013760
# Train Epoch: 19 [10/222]	loss: 0.059783
# Train Epoch: 19 [20/222]	loss: 0.019163
# Train Epoch: 19 [30/222]	loss: 0.038573
# Train Epoch: 19 [40/222]	loss: 0.004508
# Train Epoch: 19 [50/222]	loss: 0.016725
# Train Epoch: 19 [60/222]	loss: 0.004994
# Train Epoch: 19 [70/222]	loss: 0.010669
# Train Epoch: 19 [80/222]	loss: 0.007336
# Train Epoch: 19 [90/222]	loss: 0.018725
# Train Epoch: 19 [100/222]	loss: 0.006240
# Train Epoch: 19 [110/222]	loss: 0.069473
# Train Epoch: 19 [120/222]	loss: 0.005258
# Train Epoch: 19 [130/222]	loss: 0.033758
# Train Epoch: 19 [140/222]	loss: 0.016266
# Train Epoch: 19 [150/222]	loss: 0.019234
# Train Epoch: 19 [160/222]	loss: 0.004409
# Train Epoch: 19 [170/222]	loss: 0.010199
# Train Epoch: 19 [180/222]	loss: 0.015173
# Train Epoch: 19 [190/222]	loss: 0.015341
# Train Epoch: 19 [200/222]	loss: 0.003787
# Train Epoch: 19 [210/222]	loss: 0.003937
# Train Epoch: 19 [220/222]	loss: 0.037662
# [19]Validation Loss: 0.5206,Accuracy: 88.5135%
# [FINAL] Test Loss: 0.4380,Accuracy: 89.9329%
# Best Accuracy:  89.52702702702703
# Elasped Time: 1h, 72m, 44s
# time: 1h, 72m, 44s

# %%
# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# The local path to our target image
import random

# 테스트 데이터셋에서 무작위로 이미지 선택
random_index = random.randint(0, len(test_set) - 1)
img_path = test_set.image_folder[random_index]
img_path = os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test',img_path)
display(Image(img_path))

def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 1s 0us/step
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n01847000', 'drake', 6.3644433)]

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)
# Out:
# <ipython-input-16-8a3df7f2985d>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

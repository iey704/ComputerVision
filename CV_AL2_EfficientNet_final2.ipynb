# %% [markdown]
# <a href="https://colab.research.google.com/github/iey704/ComputerVision/blob/main/CV_AL2_EfficientNet_final2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   AdamP optimizer 사용
# *   Label Smoothing = 0.11
# *  efficientnet-b0 모델 사용
# * Data Augmentation:Geomentric transform + Visual corruptions

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 20.1 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.34.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.0

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=dc8c690f1421439c8eb457b6e3e47d03be03db3fd69a0f3435cc5656b3464a8e
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=32341ef101f2674a908ee727793daa3809ec20fcba6bb6af39cc889338bd9082
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
import numpy as np

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageEnhance

from efficientnet_pytorch import EfficientNet

from torch.utils.data import ConcatDataset
from collections import Counter

from adamp import AdamP

import wandb    # Import Weight&Biases

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# initialize Weight&Biases settings
run = wandb.init(
    project="Active_learning_2",
    notes = "CV_AL_2_final.ver",
    name = "efficientnet-b0(2)")

cfg = {
    "architecture": "CNN",
    "dataset": "CUB2011",
    "classes": 50,
    "learning_rate": 0.0001,
    "epochs": 30,
    "batch_size": 8,
    "label_smoothing": 0.11
}
wandb.config.update(cfg)


# Define Hyperparameters
lr = cfg['learning_rate']
BATCH_SIZE = cfg['batch_size']
EPOCH = cfg['epochs']
print("\n<Hyperparameters>\nEPOCH = {}\nBATCH SIZE = {}\nLearning rate = {}\t" .format(EPOCH, BATCH_SIZE, lr))
# Out:
# wandb: Currently logged in as: iey704 (cv_al2). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/content/wandb/run-20231112_083414-tcfnovy9</code>
# Syncing run <strong><a href='https://wandb.ai/cv_al2/Active_learning_2/runs/tcfnovy9' target="_blank">efficientnet-b0(2)</a></strong> to <a href='https://wandb.ai/cv_al2/Active_learning_2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cv_al2/Active_learning_2' target="_blank">https://wandb.ai/cv_al2/Active_learning_2</a>
#  View run at <a href='https://wandb.ai/cv_al2/Active_learning_2/runs/tcfnovy9' target="_blank">https://wandb.ai/cv_al2/Active_learning_2/runs/tcfnovy9</a>
# <Hyperparameters>
# EPOCH = 30
# BATCH SIZE = 8
# Learning rate = 0.0001

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
import matplotlib.pyplot as plt

num_rows = 2  # You can change this to the desired number of rows
num_cols = 2  # You can change this to the desired number of columns

# Function to unnormalize and display a grid of images
def imshow_grid(images, num_rows, num_cols):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 10))
    fig.subplots_adjust(hspace=0.5)  # Adjust vertical spacing between subplots
    for i in range(num_rows):
        for j in range(num_cols):
            index = i * num_cols + j
            if index < len(images):
                img = images[index]
                npimg = img.numpy()
                ax = axes[i, j]
                ax.imshow(np.transpose(npimg, (1, 2, 0)))
                ax.axis('off')

    plt.show()

# Iterate through the train_loader
for batch_idx, (images, labels) in enumerate(train_loader):
    if batch_idx >= 2:
        break  # Stop after visualizing the specified number of batches

    print(f"Batch {batch_idx + 1}")
    imshow_grid(images, num_rows, num_cols)  # Display the grid of images
# Out:
# Batch 1
# Batch 2

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 47.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 81.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
from transformers import get_cosine_schedule_with_warmup

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=50)
print(model)

### Tranfer Learning ###
model.to(DEVICE)

optimizer = AdamP(model.parameters(), lr=lr)

scheduler = get_cosine_schedule_with_warmup(optimizer,
                                    num_warmup_steps=len(train_loader)*3,
                                    num_training_steps=len(train_loader)*EPOCH)

print("Created a learning model and optimizer")
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 94.1MB/s]
# Loaded pretrained weights for efficientnet-b0
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6-7): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9-10): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12-14): 3 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.2, inplace=False)
#   (_fc): Linear(in_features=1280, out_features=50, bias=True)
#   (_swish): MemoryEfficientSwish()
# )
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch, scheduler):
  model.train()
  criterion = nn.CrossEntropyLoss(label_smoothing=0.11)
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    train_loss = criterion(output,target)

    train_loss.backward()
    optimizer.step()

    if scheduler != None:
      scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
wandb.define_metric("train_loss", summary = "min")
wandb.define_metric("val_loss", summary = "min")
wandb.define_metric("val_acc", summary = "max")

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch, scheduler)
  val_loss,val_accuracy = evaluate(model,val_loader)
  # Log train loss, validation loss, and validation accuracy into Weight & Biases by the function of epoch
  wandb.log({"train_loss": train_loss, "val_loss": val_loss, "val_acc": val_accuracy}, step=epoch)

# 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/590]	loss: 3.950508
# Train Epoch: 0 [10/590]	loss: 3.936660
# Train Epoch: 0 [20/590]	loss: 3.966353
# Train Epoch: 0 [30/590]	loss: 3.947560
# Train Epoch: 0 [40/590]	loss: 3.942793
# Train Epoch: 0 [50/590]	loss: 3.882084
# Train Epoch: 0 [60/590]	loss: 3.965343
# Train Epoch: 0 [70/590]	loss: 3.941324
# Train Epoch: 0 [80/590]	loss: 3.929090
# Train Epoch: 0 [90/590]	loss: 3.872643
# Train Epoch: 0 [100/590]	loss: 3.918866
# Train Epoch: 0 [110/590]	loss: 3.931257
# Train Epoch: 0 [120/590]	loss: 3.947340
# Train Epoch: 0 [130/590]	loss: 3.817003
# Train Epoch: 0 [140/590]	loss: 3.868900
# Train Epoch: 0 [150/590]	loss: 3.830273
# Train Epoch: 0 [160/590]	loss: 3.901105
# Train Epoch: 0 [170/590]	loss: 3.923333
# Train Epoch: 0 [180/590]	loss: 3.889089
# Train Epoch: 0 [190/590]	loss: 3.908675
# Train Epoch: 0 [200/590]	loss: 3.909000
# Train Epoch: 0 [210/590]	loss: 3.950313
# Train Epoch: 0 [220/590]	loss: 3.872914
# Train Epoch: 0 [230/590]	loss: 3.880823
# Train Epoch: 0 [240/590]	loss: 3.832919
# Train Epoch: 0 [250/590]	loss: 3.891640
# Train Epoch: 0 [260/590]	loss: 3.891694
# Train Epoch: 0 [270/590]	loss: 3.971843
# Train Epoch: 0 [280/590]	loss: 3.872387
# Train Epoch: 0 [290/590]	loss: 3.970897
# Train Epoch: 0 [300/590]	loss: 3.779021
# Train Epoch: 0 [310/590]	loss: 3.965157
# Train Epoch: 0 [320/590]	loss: 3.917359
# Train Epoch: 0 [330/590]	loss: 3.923492
# Train Epoch: 0 [340/590]	loss: 3.882452
# Train Epoch: 0 [350/590]	loss: 3.863806
# Train Epoch: 0 [360/590]	loss: 3.929243
# Train Epoch: 0 [370/590]	loss: 3.893147
# Train Epoch: 0 [380/590]	loss: 3.847384
# Train Epoch: 0 [390/590]	loss: 3.875649
# Train Epoch: 0 [400/590]	loss: 3.870440
# Train Epoch: 0 [410/590]	loss: 3.866071
# Train Epoch: 0 [420/590]	loss: 3.829468
# Train Epoch: 0 [430/590]	loss: 3.900797
# Train Epoch: 0 [440/590]	loss: 3.849756
# Train Epoch: 0 [450/590]	loss: 3.814313
# Train Epoch: 0 [460/590]	loss: 3.959688
# Train Epoch: 0 [470/590]	loss: 3.801821
# Train Epoch: 0 [480/590]	loss: 3.814611
# Train Epoch: 0 [490/590]	loss: 3.791570
# Train Epoch: 0 [500/590]	loss: 3.845299
# Train Epoch: 0 [510/590]	loss: 3.849300
# Train Epoch: 0 [520/590]	loss: 3.836627
# Train Epoch: 0 [530/590]	loss: 3.868798
# Train Epoch: 0 [540/590]	loss: 3.845408
# Train Epoch: 0 [550/590]	loss: 3.801785
# Train Epoch: 0 [560/590]	loss: 3.735895
# Train Epoch: 0 [570/590]	loss: 3.847700
# Train Epoch: 0 [580/590]	loss: 3.756361
# [0]Validation Loss: 3.7164,Accuracy: 20.6081%
# Train Epoch: 1 [0/590]	loss: 3.807020
# Train Epoch: 1 [10/590]	loss: 3.747494
# Train Epoch: 1 [20/590]	loss: 3.805687
# Train Epoch: 1 [30/590]	loss: 3.756994
# Train Epoch: 1 [40/590]	loss: 3.766260
# Train Epoch: 1 [50/590]	loss: 3.731546
# Train Epoch: 1 [60/590]	loss: 3.697380
# Train Epoch: 1 [70/590]	loss: 3.729286
# Train Epoch: 1 [80/590]	loss: 3.630869
# Train Epoch: 1 [90/590]	loss: 3.759563
# Train Epoch: 1 [100/590]	loss: 3.724904
# Train Epoch: 1 [110/590]	loss: 3.736506
# Train Epoch: 1 [120/590]	loss: 3.751443
# Train Epoch: 1 [130/590]	loss: 3.715198
# Train Epoch: 1 [140/590]	loss: 3.680682
# Train Epoch: 1 [150/590]	loss: 3.630358
# Train Epoch: 1 [160/590]	loss: 3.542596
# Train Epoch: 1 [170/590]	loss: 3.647435
# Train Epoch: 1 [180/590]	loss: 3.606772
# Train Epoch: 1 [190/590]	loss: 3.672442
# Train Epoch: 1 [200/590]	loss: 3.487775
# Train Epoch: 1 [210/590]	loss: 3.653477
# Train Epoch: 1 [220/590]	loss: 3.464365
# Train Epoch: 1 [230/590]	loss: 3.775088
# Train Epoch: 1 [240/590]	loss: 3.538879
# Train Epoch: 1 [250/590]	loss: 3.565223
# Train Epoch: 1 [260/590]	loss: 3.459322
# Train Epoch: 1 [270/590]	loss: 3.452998
# Train Epoch: 1 [280/590]	loss: 3.477457
# Train Epoch: 1 [290/590]	loss: 3.314222
# Train Epoch: 1 [300/590]	loss: 3.347920
# Train Epoch: 1 [310/590]	loss: 3.292321
# Train Epoch: 1 [320/590]	loss: 3.638630
# Train Epoch: 1 [330/590]	loss: 3.627295
# Train Epoch: 1 [340/590]	loss: 3.332338
# Train Epoch: 1 [350/590]	loss: 3.283838
# Train Epoch: 1 [360/590]	loss: 3.446984
# Train Epoch: 1 [370/590]	loss: 3.365616
# Train Epoch: 1 [380/590]	loss: 3.195692
# Train Epoch: 1 [390/590]	loss: 3.522945
# Train Epoch: 1 [400/590]	loss: 3.187062
# Train Epoch: 1 [410/590]	loss: 3.307649
# Train Epoch: 1 [420/590]	loss: 3.390203
# Train Epoch: 1 [430/590]	loss: 3.308089
# Train Epoch: 1 [440/590]	loss: 3.146405
# Train Epoch: 1 [450/590]	loss: 3.340869
# Train Epoch: 1 [460/590]	loss: 3.032681
# Train Epoch: 1 [470/590]	loss: 3.136092
# Train Epoch: 1 [480/590]	loss: 3.008553
# Train Epoch: 1 [490/590]	loss: 2.960687
# Train Epoch: 1 [500/590]	loss: 3.230774
# Train Epoch: 1 [510/590]	loss: 2.980014
# Train Epoch: 1 [520/590]	loss: 2.985117
# Train Epoch: 1 [530/590]	loss: 3.189462
# Train Epoch: 1 [540/590]	loss: 2.960985
# Train Epoch: 1 [550/590]	loss: 3.039631
# Train Epoch: 1 [560/590]	loss: 2.613547
# Train Epoch: 1 [570/590]	loss: 2.592351
# Train Epoch: 1 [580/590]	loss: 2.725224
# [1]Validation Loss: 1.9935,Accuracy: 60.1351%
# Train Epoch: 2 [0/590]	loss: 2.962445
# Train Epoch: 2 [10/590]	loss: 2.921024
# Train Epoch: 2 [20/590]	loss: 3.098634
# Train Epoch: 2 [30/590]	loss: 2.658437
# Train Epoch: 2 [40/590]	loss: 2.357266
# Train Epoch: 2 [50/590]	loss: 2.768627
# Train Epoch: 2 [60/590]	loss: 2.402392
# Train Epoch: 2 [70/590]	loss: 2.590426
# Train Epoch: 2 [80/590]	loss: 2.881873
# Train Epoch: 2 [90/590]	loss: 2.661623
# Train Epoch: 2 [100/590]	loss: 2.986161
# Train Epoch: 2 [110/590]	loss: 2.333720
# Train Epoch: 2 [120/590]	loss: 2.343491
# Train Epoch: 2 [130/590]	loss: 2.643995
# Train Epoch: 2 [140/590]	loss: 2.896091
# Train Epoch: 2 [150/590]	loss: 2.363851
# Train Epoch: 2 [160/590]	loss: 2.655120
# Train Epoch: 2 [170/590]	loss: 2.626499
# Train Epoch: 2 [180/590]	loss: 2.396749
# Train Epoch: 2 [190/590]	loss: 2.461831
# Train Epoch: 2 [200/590]	loss: 2.108105
# Train Epoch: 2 [210/590]	loss: 2.502302
# Train Epoch: 2 [220/590]	loss: 2.387889
# Train Epoch: 2 [230/590]	loss: 2.421829
# Train Epoch: 2 [240/590]	loss: 2.022326
# Train Epoch: 2 [250/590]	loss: 2.063205
# Train Epoch: 2 [260/590]	loss: 2.108541
# Train Epoch: 2 [270/590]	loss: 1.987674
# Train Epoch: 2 [280/590]	loss: 2.373626
# Train Epoch: 2 [290/590]	loss: 2.200803
# Train Epoch: 2 [300/590]	loss: 1.939650
# Train Epoch: 2 [310/590]	loss: 2.267930
# Train Epoch: 2 [320/590]	loss: 2.417666
# Train Epoch: 2 [330/590]	loss: 2.309434
# Train Epoch: 2 [340/590]	loss: 2.169364
# Train Epoch: 2 [350/590]	loss: 1.883923
# Train Epoch: 2 [360/590]	loss: 2.160323
# Train Epoch: 2 [370/590]	loss: 1.727460
# Train Epoch: 2 [380/590]	loss: 2.158485
# Train Epoch: 2 [390/590]	loss: 2.025373
# Train Epoch: 2 [400/590]	loss: 1.980333
# Train Epoch: 2 [410/590]	loss: 2.004552
# Train Epoch: 2 [420/590]	loss: 1.898646
# Train Epoch: 2 [430/590]	loss: 1.968426
# Train Epoch: 2 [440/590]	loss: 2.125413
# Train Epoch: 2 [450/590]	loss: 1.742759
# Train Epoch: 2 [460/590]	loss: 2.000239
# Train Epoch: 2 [470/590]	loss: 2.429740
# Train Epoch: 2 [480/590]	loss: 1.639327
# Train Epoch: 2 [490/590]	loss: 1.928423
# Train Epoch: 2 [500/590]	loss: 2.370809
# Train Epoch: 2 [510/590]	loss: 2.207751
# Train Epoch: 2 [520/590]	loss: 1.772518
# Train Epoch: 2 [530/590]	loss: 1.928593
# Train Epoch: 2 [540/590]	loss: 1.887818
# Train Epoch: 2 [550/590]	loss: 2.141133
# Train Epoch: 2 [560/590]	loss: 1.869297
# Train Epoch: 2 [570/590]	loss: 1.759711
# Train Epoch: 2 [580/590]	loss: 1.687197
# [2]Validation Loss: 0.7796,Accuracy: 83.1081%
# Train Epoch: 3 [0/590]	loss: 1.676029
# Train Epoch: 3 [10/590]	loss: 1.672025
# Train Epoch: 3 [20/590]	loss: 1.710973
# Train Epoch: 3 [30/590]	loss: 1.980229
# Train Epoch: 3 [40/590]	loss: 1.645951
# Train Epoch: 3 [50/590]	loss: 1.767421
# Train Epoch: 3 [60/590]	loss: 1.493424
# Train Epoch: 3 [70/590]	loss: 1.482136
# Train Epoch: 3 [80/590]	loss: 1.915087
# Train Epoch: 3 [90/590]	loss: 1.729017
# Train Epoch: 3 [100/590]	loss: 1.536273
# Train Epoch: 3 [110/590]	loss: 1.329948
# Train Epoch: 3 [120/590]	loss: 1.846653
# Train Epoch: 3 [130/590]	loss: 1.572186
# Train Epoch: 3 [140/590]	loss: 1.709569
# Train Epoch: 3 [150/590]	loss: 1.778099
# Train Epoch: 3 [160/590]	loss: 1.872125
# Train Epoch: 3 [170/590]	loss: 2.442324
# Train Epoch: 3 [180/590]	loss: 1.697835
# Train Epoch: 3 [190/590]	loss: 1.407943
# Train Epoch: 3 [200/590]	loss: 1.461113
# Train Epoch: 3 [210/590]	loss: 1.823834
# Train Epoch: 3 [220/590]	loss: 1.441806
# Train Epoch: 3 [230/590]	loss: 1.443898
# Train Epoch: 3 [240/590]	loss: 1.651899
# Train Epoch: 3 [250/590]	loss: 1.185674
# Train Epoch: 3 [260/590]	loss: 2.219663
# Train Epoch: 3 [270/590]	loss: 1.232838
# Train Epoch: 3 [280/590]	loss: 1.194766
# Train Epoch: 3 [290/590]	loss: 1.456831
# Train Epoch: 3 [300/590]	loss: 1.473837
# Train Epoch: 3 [310/590]	loss: 1.507264
# Train Epoch: 3 [320/590]	loss: 1.608366
# Train Epoch: 3 [330/590]	loss: 1.348452
# Train Epoch: 3 [340/590]	loss: 1.235567
# Train Epoch: 3 [350/590]	loss: 1.319549
# Train Epoch: 3 [360/590]	loss: 1.501956
# Train Epoch: 3 [370/590]	loss: 1.373930
# Train Epoch: 3 [380/590]	loss: 1.258246
# Train Epoch: 3 [390/590]	loss: 1.178581
# Train Epoch: 3 [400/590]	loss: 2.049282
# Train Epoch: 3 [410/590]	loss: 1.738096
# Train Epoch: 3 [420/590]	loss: 1.673873
# Train Epoch: 3 [430/590]	loss: 1.469028
# Train Epoch: 3 [440/590]	loss: 1.392244
# Train Epoch: 3 [450/590]	loss: 1.240515
# Train Epoch: 3 [460/590]	loss: 1.705869
# Train Epoch: 3 [470/590]	loss: 1.490869
# Train Epoch: 3 [480/590]	loss: 1.244551
# Train Epoch: 3 [490/590]	loss: 1.248028
# Train Epoch: 3 [500/590]	loss: 1.327381
# Train Epoch: 3 [510/590]	loss: 1.085597
# Train Epoch: 3 [520/590]	loss: 1.169065
# Train Epoch: 3 [530/590]	loss: 1.347185
# Train Epoch: 3 [540/590]	loss: 1.699626
# Train Epoch: 3 [550/590]	loss: 1.459923
# Train Epoch: 3 [560/590]	loss: 1.821841
# Train Epoch: 3 [570/590]	loss: 1.523287
# Train Epoch: 3 [580/590]	loss: 0.975440
# [3]Validation Loss: 0.4892,Accuracy: 85.8108%
# Train Epoch: 4 [0/590]	loss: 1.625698
# Train Epoch: 4 [10/590]	loss: 1.324540
# Train Epoch: 4 [20/590]	loss: 1.177107
# Train Epoch: 4 [30/590]	loss: 1.408841
# Train Epoch: 4 [40/590]	loss: 1.016856
# Train Epoch: 4 [50/590]	loss: 1.384470
# Train Epoch: 4 [60/590]	loss: 1.529448
# Train Epoch: 4 [70/590]	loss: 1.257464
# Train Epoch: 4 [80/590]	loss: 1.314659
# Train Epoch: 4 [90/590]	loss: 1.219012
# Train Epoch: 4 [100/590]	loss: 1.340661
# Train Epoch: 4 [110/590]	loss: 1.223265
# Train Epoch: 4 [120/590]	loss: 1.529521
# Train Epoch: 4 [130/590]	loss: 1.138791
# Train Epoch: 4 [140/590]	loss: 1.333586
# Train Epoch: 4 [150/590]	loss: 2.070384
# Train Epoch: 4 [160/590]	loss: 1.368861
# Train Epoch: 4 [170/590]	loss: 1.162985
# Train Epoch: 4 [180/590]	loss: 1.209580
# Train Epoch: 4 [190/590]	loss: 1.098912
# Train Epoch: 4 [200/590]	loss: 1.120838
# Train Epoch: 4 [210/590]	loss: 1.223353
# Train Epoch: 4 [220/590]	loss: 1.146663
# Train Epoch: 4 [230/590]	loss: 1.334738
# Train Epoch: 4 [240/590]	loss: 1.329647
# Train Epoch: 4 [250/590]	loss: 1.442958
# Train Epoch: 4 [260/590]	loss: 0.958608
# Train Epoch: 4 [270/590]	loss: 1.882223
# Train Epoch: 4 [280/590]	loss: 1.307615
# Train Epoch: 4 [290/590]	loss: 1.430416
# Train Epoch: 4 [300/590]	loss: 2.062803
# Train Epoch: 4 [310/590]	loss: 1.465877
# Train Epoch: 4 [320/590]	loss: 1.224664
# Train Epoch: 4 [330/590]	loss: 1.671989
# Train Epoch: 4 [340/590]	loss: 1.081877
# Train Epoch: 4 [350/590]	loss: 1.683037
# Train Epoch: 4 [360/590]	loss: 1.209515
# Train Epoch: 4 [370/590]	loss: 1.129637
# Train Epoch: 4 [380/590]	loss: 1.755148
# Train Epoch: 4 [390/590]	loss: 1.036288
# Train Epoch: 4 [400/590]	loss: 1.028185
# Train Epoch: 4 [410/590]	loss: 1.443655
# Train Epoch: 4 [420/590]	loss: 1.094547
# Train Epoch: 4 [430/590]	loss: 1.175774
# Train Epoch: 4 [440/590]	loss: 1.252336
# Train Epoch: 4 [450/590]	loss: 1.176699
# Train Epoch: 4 [460/590]	loss: 1.721803
# Train Epoch: 4 [470/590]	loss: 1.692609
# Train Epoch: 4 [480/590]	loss: 1.173690
# Train Epoch: 4 [490/590]	loss: 1.297130
# Train Epoch: 4 [500/590]	loss: 1.779778
# Train Epoch: 4 [510/590]	loss: 1.518636
# Train Epoch: 4 [520/590]	loss: 1.160706
# Train Epoch: 4 [530/590]	loss: 1.179988
# Train Epoch: 4 [540/590]	loss: 1.528000
# Train Epoch: 4 [550/590]	loss: 1.376438
# Train Epoch: 4 [560/590]	loss: 1.109751
# Train Epoch: 4 [570/590]	loss: 1.133626
# Train Epoch: 4 [580/590]	loss: 1.445450
# [4]Validation Loss: 0.4001,Accuracy: 91.2162%
# Train Epoch: 5 [0/590]	loss: 0.990864
# Train Epoch: 5 [10/590]	loss: 1.126343
# Train Epoch: 5 [20/590]	loss: 0.921595
# Train Epoch: 5 [30/590]	loss: 1.169778
# Train Epoch: 5 [40/590]	loss: 1.320785
# Train Epoch: 5 [50/590]	loss: 1.009743
# Train Epoch: 5 [60/590]	loss: 1.067956
# Train Epoch: 5 [70/590]	loss: 1.544324
# Train Epoch: 5 [80/590]	loss: 1.315965
# Train Epoch: 5 [90/590]	loss: 1.997025
# Train Epoch: 5 [100/590]	loss: 1.512391
# Train Epoch: 5 [110/590]	loss: 1.079491
# Train Epoch: 5 [120/590]	loss: 1.001471
# Train Epoch: 5 [130/590]	loss: 1.297038
# Train Epoch: 5 [140/590]	loss: 1.059164
# Train Epoch: 5 [150/590]	loss: 1.041629
# Train Epoch: 5 [160/590]	loss: 1.007824
# Train Epoch: 5 [170/590]	loss: 1.354804
# Train Epoch: 5 [180/590]	loss: 0.968830
# Train Epoch: 5 [190/590]	loss: 1.040757
# Train Epoch: 5 [200/590]	loss: 1.244735
# Train Epoch: 5 [210/590]	loss: 1.122956
# Train Epoch: 5 [220/590]	loss: 1.229309
# Train Epoch: 5 [230/590]	loss: 1.035907
# Train Epoch: 5 [240/590]	loss: 1.054653
# Train Epoch: 5 [250/590]	loss: 1.022234
# Train Epoch: 5 [260/590]	loss: 1.413946
# Train Epoch: 5 [270/590]	loss: 1.264876
# Train Epoch: 5 [280/590]	loss: 0.919730
# Train Epoch: 5 [290/590]	loss: 1.347695
# Train Epoch: 5 [300/590]	loss: 0.955311
# Train Epoch: 5 [310/590]	loss: 1.508645
# Train Epoch: 5 [320/590]	loss: 1.470165
# Train Epoch: 5 [330/590]	loss: 1.756684
# Train Epoch: 5 [340/590]	loss: 1.058772
# Train Epoch: 5 [350/590]	loss: 1.283871
# Train Epoch: 5 [360/590]	loss: 1.214844
# Train Epoch: 5 [370/590]	loss: 1.577776
# Train Epoch: 5 [380/590]	loss: 0.931797
# Train Epoch: 5 [390/590]	loss: 1.148211
# Train Epoch: 5 [400/590]	loss: 1.190264
# Train Epoch: 5 [410/590]	loss: 1.270693
# Train Epoch: 5 [420/590]	loss: 1.032457
# Train Epoch: 5 [430/590]	loss: 1.355204
# Train Epoch: 5 [440/590]	loss: 1.126678
# Train Epoch: 5 [450/590]	loss: 1.174146
# Train Epoch: 5 [460/590]	loss: 1.296640
# Train Epoch: 5 [470/590]	loss: 1.151922
# Train Epoch: 5 [480/590]	loss: 1.325134
# Train Epoch: 5 [490/590]	loss: 1.341979
# Train Epoch: 5 [500/590]	loss: 1.030109
# Train Epoch: 5 [510/590]	loss: 1.147164
# Train Epoch: 5 [520/590]	loss: 1.025187
# Train Epoch: 5 [530/590]	loss: 1.052369
# Train Epoch: 5 [540/590]	loss: 1.112394
# Train Epoch: 5 [550/590]	loss: 1.178548
# Train Epoch: 5 [560/590]	loss: 1.152558
# Train Epoch: 5 [570/590]	loss: 0.972740
# Train Epoch: 5 [580/590]	loss: 1.014218
# [5]Validation Loss: 0.3255,Accuracy: 90.8784%
# Train Epoch: 6 [0/590]	loss: 1.009319
# Train Epoch: 6 [10/590]	loss: 1.091114
# Train Epoch: 6 [20/590]	loss: 0.907341
# Train Epoch: 6 [30/590]	loss: 1.206712
# Train Epoch: 6 [40/590]	loss: 1.031353
# Train Epoch: 6 [50/590]	loss: 1.054654
# Train Epoch: 6 [60/590]	loss: 1.064631
# Train Epoch: 6 [70/590]	loss: 0.989325
# Train Epoch: 6 [80/590]	loss: 1.038025
# Train Epoch: 6 [90/590]	loss: 1.215934
# Train Epoch: 6 [100/590]	loss: 1.044054
# Train Epoch: 6 [110/590]	loss: 0.978749
# Train Epoch: 6 [120/590]	loss: 1.084426
# Train Epoch: 6 [130/590]	loss: 1.008661
# Train Epoch: 6 [140/590]	loss: 0.948393
# Train Epoch: 6 [150/590]	loss: 0.970504
# Train Epoch: 6 [160/590]	loss: 1.452146
# Train Epoch: 6 [170/590]	loss: 0.905745
# Train Epoch: 6 [180/590]	loss: 0.884031
# Train Epoch: 6 [190/590]	loss: 1.574306
# Train Epoch: 6 [200/590]	loss: 0.885948
# Train Epoch: 6 [210/590]	loss: 0.969415
# Train Epoch: 6 [220/590]	loss: 0.966101
# Train Epoch: 6 [230/590]	loss: 1.224125
# Train Epoch: 6 [240/590]	loss: 0.917539
# Train Epoch: 6 [250/590]	loss: 1.308303
# Train Epoch: 6 [260/590]	loss: 0.985575
# Train Epoch: 6 [270/590]	loss: 1.281379
# Train Epoch: 6 [280/590]	loss: 0.945154
# Train Epoch: 6 [290/590]	loss: 0.883750
# Train Epoch: 6 [300/590]	loss: 1.053848
# Train Epoch: 6 [310/590]	loss: 1.332399
# Train Epoch: 6 [320/590]	loss: 0.987357
# Train Epoch: 6 [330/590]	loss: 1.002778
# Train Epoch: 6 [340/590]	loss: 1.024583
# Train Epoch: 6 [350/590]	loss: 0.977577
# Train Epoch: 6 [360/590]	loss: 0.990281
# Train Epoch: 6 [370/590]	loss: 0.972590
# Train Epoch: 6 [380/590]	loss: 1.185574
# Train Epoch: 6 [390/590]	loss: 0.934092
# Train Epoch: 6 [400/590]	loss: 1.062360
# Train Epoch: 6 [410/590]	loss: 1.099119
# Train Epoch: 6 [420/590]	loss: 1.141875
# Train Epoch: 6 [430/590]	loss: 0.967934
# Train Epoch: 6 [440/590]	loss: 1.039688
# Train Epoch: 6 [450/590]	loss: 0.866641
# Train Epoch: 6 [460/590]	loss: 1.318895
# Train Epoch: 6 [470/590]	loss: 0.998294
# Train Epoch: 6 [480/590]	loss: 1.192672
# Train Epoch: 6 [490/590]	loss: 1.223651
# Train Epoch: 6 [500/590]	loss: 1.339558
# Train Epoch: 6 [510/590]	loss: 0.878745
# Train Epoch: 6 [520/590]	loss: 1.201131
# Train Epoch: 6 [530/590]	loss: 0.989882
# Train Epoch: 6 [540/590]	loss: 1.020555
# Train Epoch: 6 [550/590]	loss: 1.184574
# Train Epoch: 6 [560/590]	loss: 0.857816
# Train Epoch: 6 [570/590]	loss: 0.969083
# Train Epoch: 6 [580/590]	loss: 1.084788
# [6]Validation Loss: 0.3686,Accuracy: 90.5405%
# Train Epoch: 7 [0/590]	loss: 0.899189
# Train Epoch: 7 [10/590]	loss: 1.083145
# Train Epoch: 7 [20/590]	loss: 0.950625
# Train Epoch: 7 [30/590]	loss: 1.314182
# Train Epoch: 7 [40/590]	loss: 1.056264
# Train Epoch: 7 [50/590]	loss: 0.907452
# Train Epoch: 7 [60/590]	loss: 0.874083
# Train Epoch: 7 [70/590]	loss: 0.847983
# Train Epoch: 7 [80/590]	loss: 0.934486
# Train Epoch: 7 [90/590]	loss: 0.972004
# Train Epoch: 7 [100/590]	loss: 1.246391
# Train Epoch: 7 [110/590]	loss: 1.026328
# Train Epoch: 7 [120/590]	loss: 0.939550
# Train Epoch: 7 [130/590]	loss: 0.986337
# Train Epoch: 7 [140/590]	loss: 0.956070
# Train Epoch: 7 [150/590]	loss: 0.990171
# Train Epoch: 7 [160/590]	loss: 1.286224
# Train Epoch: 7 [170/590]	loss: 0.900077
# Train Epoch: 7 [180/590]	loss: 0.916410
# Train Epoch: 7 [190/590]	loss: 1.068825
# Train Epoch: 7 [200/590]	loss: 0.910616
# Train Epoch: 7 [210/590]	loss: 0.899821
# Train Epoch: 7 [220/590]	loss: 1.049010
# Train Epoch: 7 [230/590]	loss: 1.039308
# Train Epoch: 7 [240/590]	loss: 0.900202
# Train Epoch: 7 [250/590]	loss: 0.943043
# Train Epoch: 7 [260/590]	loss: 0.854133
# Train Epoch: 7 [270/590]	loss: 0.986358
# Train Epoch: 7 [280/590]	loss: 1.041880
# Train Epoch: 7 [290/590]	loss: 0.871152
# Train Epoch: 7 [300/590]	loss: 0.915700
# Train Epoch: 7 [310/590]	loss: 0.902777
# Train Epoch: 7 [320/590]	loss: 0.875247
# Train Epoch: 7 [330/590]	loss: 1.044883
# Train Epoch: 7 [340/590]	loss: 1.224165
# Train Epoch: 7 [350/590]	loss: 0.896277
# Train Epoch: 7 [360/590]	loss: 0.930076
# Train Epoch: 7 [370/590]	loss: 0.899987
# Train Epoch: 7 [380/590]	loss: 1.290321
# Train Epoch: 7 [390/590]	loss: 0.917808
# Train Epoch: 7 [400/590]	loss: 0.937879
# Train Epoch: 7 [410/590]	loss: 0.974071
# Train Epoch: 7 [420/590]	loss: 1.184594
# Train Epoch: 7 [430/590]	loss: 0.945754
# Train Epoch: 7 [440/590]	loss: 0.957566
# Train Epoch: 7 [450/590]	loss: 0.972878
# Train Epoch: 7 [460/590]	loss: 0.911944
# Train Epoch: 7 [470/590]	loss: 0.947400
# Train Epoch: 7 [480/590]	loss: 0.876491
# Train Epoch: 7 [490/590]	loss: 1.073103
# Train Epoch: 7 [500/590]	loss: 0.915298
# Train Epoch: 7 [510/590]	loss: 0.853411
# Train Epoch: 7 [520/590]	loss: 1.130448
# Train Epoch: 7 [530/590]	loss: 0.950165
# Train Epoch: 7 [540/590]	loss: 1.125130
# Train Epoch: 7 [550/590]	loss: 0.917188
# Train Epoch: 7 [560/590]	loss: 1.011265
# Train Epoch: 7 [570/590]	loss: 0.953938
# Train Epoch: 7 [580/590]	loss: 1.063419
# [7]Validation Loss: 0.3202,Accuracy: 93.5811%
# Train Epoch: 8 [0/590]	loss: 1.239988
# Train Epoch: 8 [10/590]	loss: 1.028913
# Train Epoch: 8 [20/590]	loss: 0.925629
# Train Epoch: 8 [30/590]	loss: 1.103718
# Train Epoch: 8 [40/590]	loss: 1.245328
# Train Epoch: 8 [50/590]	loss: 0.906161
# Train Epoch: 8 [60/590]	loss: 1.009351
# Train Epoch: 8 [70/590]	loss: 0.874595
# Train Epoch: 8 [80/590]	loss: 0.926772
# Train Epoch: 8 [90/590]	loss: 0.955860
# Train Epoch: 8 [100/590]	loss: 0.980397
# Train Epoch: 8 [110/590]	loss: 0.924359
# Train Epoch: 8 [120/590]	loss: 1.004054
# Train Epoch: 8 [130/590]	loss: 0.860581
# Train Epoch: 8 [140/590]	loss: 0.995134
# Train Epoch: 8 [150/590]	loss: 0.880369
# Train Epoch: 8 [160/590]	loss: 1.090532
# Train Epoch: 8 [170/590]	loss: 0.924786
# Train Epoch: 8 [180/590]	loss: 0.970918
# Train Epoch: 8 [190/590]	loss: 1.004077
# Train Epoch: 8 [200/590]	loss: 0.864126
# Train Epoch: 8 [210/590]	loss: 1.127475
# Train Epoch: 8 [220/590]	loss: 0.871917
# Train Epoch: 8 [230/590]	loss: 1.049920
# Train Epoch: 8 [240/590]	loss: 0.930953
# Train Epoch: 8 [250/590]	loss: 1.128004
# Train Epoch: 8 [260/590]	loss: 0.992648
# Train Epoch: 8 [270/590]	loss: 1.277856
# Train Epoch: 8 [280/590]	loss: 0.881833
# Train Epoch: 8 [290/590]	loss: 0.934323
# Train Epoch: 8 [300/590]	loss: 0.958737
# Train Epoch: 8 [310/590]	loss: 0.927590
# Train Epoch: 8 [320/590]	loss: 0.861990
# Train Epoch: 8 [330/590]	loss: 1.058888
# Train Epoch: 8 [340/590]	loss: 0.950698
# Train Epoch: 8 [350/590]	loss: 1.179242
# Train Epoch: 8 [360/590]	loss: 0.967349
# Train Epoch: 8 [370/590]	loss: 0.869000
# Train Epoch: 8 [380/590]	loss: 1.564545
# Train Epoch: 8 [390/590]	loss: 1.061235
# Train Epoch: 8 [400/590]	loss: 1.193931
# Train Epoch: 8 [410/590]	loss: 0.979970
# Train Epoch: 8 [420/590]	loss: 0.978670
# Train Epoch: 8 [430/590]	loss: 0.908639
# Train Epoch: 8 [440/590]	loss: 0.969037
# Train Epoch: 8 [450/590]	loss: 0.878878
# Train Epoch: 8 [460/590]	loss: 0.907016
# Train Epoch: 8 [470/590]	loss: 0.964913
# Train Epoch: 8 [480/590]	loss: 1.013542
# Train Epoch: 8 [490/590]	loss: 1.069385
# Train Epoch: 8 [500/590]	loss: 0.966371
# Train Epoch: 8 [510/590]	loss: 0.987155
# Train Epoch: 8 [520/590]	loss: 0.908342
# Train Epoch: 8 [530/590]	loss: 0.879612
# Train Epoch: 8 [540/590]	loss: 0.876300
# Train Epoch: 8 [550/590]	loss: 0.960124
# Train Epoch: 8 [560/590]	loss: 0.924024
# Train Epoch: 8 [570/590]	loss: 1.007647
# Train Epoch: 8 [580/590]	loss: 1.258574
# [8]Validation Loss: 0.3174,Accuracy: 92.2297%
# Train Epoch: 9 [0/590]	loss: 0.973091
# Train Epoch: 9 [10/590]	loss: 0.907843
# Train Epoch: 9 [20/590]	loss: 0.856735
# Train Epoch: 9 [30/590]	loss: 0.875294
# Train Epoch: 9 [40/590]	loss: 1.027294
# Train Epoch: 9 [50/590]	loss: 0.978173
# Train Epoch: 9 [60/590]	loss: 0.920670
# Train Epoch: 9 [70/590]	loss: 0.913465
# Train Epoch: 9 [80/590]	loss: 0.875148
# Train Epoch: 9 [90/590]	loss: 0.853908
# Train Epoch: 9 [100/590]	loss: 0.948444
# Train Epoch: 9 [110/590]	loss: 0.880084
# Train Epoch: 9 [120/590]	loss: 1.055703
# Train Epoch: 9 [130/590]	loss: 0.928718
# Train Epoch: 9 [140/590]	loss: 0.856026
# Train Epoch: 9 [150/590]	loss: 0.895683
# Train Epoch: 9 [160/590]	loss: 0.984947
# Train Epoch: 9 [170/590]	loss: 0.886442
# Train Epoch: 9 [180/590]	loss: 0.899392
# Train Epoch: 9 [190/590]	loss: 0.980637
# Train Epoch: 9 [200/590]	loss: 1.126540
# Train Epoch: 9 [210/590]	loss: 0.877771
# Train Epoch: 9 [220/590]	loss: 0.866744
# Train Epoch: 9 [230/590]	loss: 0.936679
# Train Epoch: 9 [240/590]	loss: 0.982045
# Train Epoch: 9 [250/590]	loss: 0.867946
# Train Epoch: 9 [260/590]	loss: 0.889920
# Train Epoch: 9 [270/590]	loss: 0.836063
# Train Epoch: 9 [280/590]	loss: 0.853160
# Train Epoch: 9 [290/590]	loss: 0.964561
# Train Epoch: 9 [300/590]	loss: 0.910177
# Train Epoch: 9 [310/590]	loss: 0.951481
# Train Epoch: 9 [320/590]	loss: 0.996328
# Train Epoch: 9 [330/590]	loss: 0.863734
# Train Epoch: 9 [340/590]	loss: 0.890272
# Train Epoch: 9 [350/590]	loss: 0.857566
# Train Epoch: 9 [360/590]	loss: 0.855252
# Train Epoch: 9 [370/590]	loss: 0.853885
# Train Epoch: 9 [380/590]	loss: 0.872909
# Train Epoch: 9 [390/590]	loss: 0.940794
# Train Epoch: 9 [400/590]	loss: 1.024030
# Train Epoch: 9 [410/590]	loss: 1.111753
# Train Epoch: 9 [420/590]	loss: 1.217739
# Train Epoch: 9 [430/590]	loss: 0.928432
# Train Epoch: 9 [440/590]	loss: 0.901553
# Train Epoch: 9 [450/590]	loss: 0.849972
# Train Epoch: 9 [460/590]	loss: 0.833674
# Train Epoch: 9 [470/590]	loss: 0.914410
# Train Epoch: 9 [480/590]	loss: 0.877253
# Train Epoch: 9 [490/590]	loss: 0.948423
# Train Epoch: 9 [500/590]	loss: 0.905698
# Train Epoch: 9 [510/590]	loss: 0.850064
# Train Epoch: 9 [520/590]	loss: 1.137013
# Train Epoch: 9 [530/590]	loss: 0.845411
# Train Epoch: 9 [540/590]	loss: 1.018588
# Train Epoch: 9 [550/590]	loss: 1.110019
# Train Epoch: 9 [560/590]	loss: 0.872358
# Train Epoch: 9 [570/590]	loss: 0.871306
# Train Epoch: 9 [580/590]	loss: 1.448500
# [9]Validation Loss: 0.3001,Accuracy: 92.2297%
# Train Epoch: 10 [0/590]	loss: 0.953986
# Train Epoch: 10 [10/590]	loss: 0.845969
# Train Epoch: 10 [20/590]	loss: 0.908599
# Train Epoch: 10 [30/590]	loss: 0.875479
# Train Epoch: 10 [40/590]	loss: 1.065264
# Train Epoch: 10 [50/590]	loss: 1.015327
# Train Epoch: 10 [60/590]	loss: 0.903305
# Train Epoch: 10 [70/590]	loss: 0.891372
# Train Epoch: 10 [80/590]	loss: 0.860287
# Train Epoch: 10 [90/590]	loss: 0.920425
# Train Epoch: 10 [100/590]	loss: 0.860989
# Train Epoch: 10 [110/590]	loss: 1.000662
# Train Epoch: 10 [120/590]	loss: 0.909439
# Train Epoch: 10 [130/590]	loss: 0.911601
# Train Epoch: 10 [140/590]	loss: 0.994224
# Train Epoch: 10 [150/590]	loss: 0.946095
# Train Epoch: 10 [160/590]	loss: 0.849696
# Train Epoch: 10 [170/590]	loss: 0.922090
# Train Epoch: 10 [180/590]	loss: 1.387340
# Train Epoch: 10 [190/590]	loss: 0.922770
# Train Epoch: 10 [200/590]	loss: 0.913867
# Train Epoch: 10 [210/590]	loss: 1.049796
# Train Epoch: 10 [220/590]	loss: 0.868738
# Train Epoch: 10 [230/590]	loss: 0.935496
# Train Epoch: 10 [240/590]	loss: 0.889196
# Train Epoch: 10 [250/590]	loss: 1.076334
# Train Epoch: 10 [260/590]	loss: 0.920878
# Train Epoch: 10 [270/590]	loss: 0.932247
# Train Epoch: 10 [280/590]	loss: 0.875904
# Train Epoch: 10 [290/590]	loss: 0.862474
# Train Epoch: 10 [300/590]	loss: 0.867240
# Train Epoch: 10 [310/590]	loss: 1.073293
# Train Epoch: 10 [320/590]	loss: 0.952666
# Train Epoch: 10 [330/590]	loss: 0.844614
# Train Epoch: 10 [340/590]	loss: 0.907236
# Train Epoch: 10 [350/590]	loss: 0.882846
# Train Epoch: 10 [360/590]	loss: 1.243421
# Train Epoch: 10 [370/590]	loss: 0.861467
# Train Epoch: 10 [380/590]	loss: 0.921741
# Train Epoch: 10 [390/590]	loss: 1.256997
# Train Epoch: 10 [400/590]	loss: 0.995197
# Train Epoch: 10 [410/590]	loss: 0.900197
# Train Epoch: 10 [420/590]	loss: 0.976181
# Train Epoch: 10 [430/590]	loss: 0.890666
# Train Epoch: 10 [440/590]	loss: 0.848080
# Train Epoch: 10 [450/590]	loss: 0.875002
# Train Epoch: 10 [460/590]	loss: 0.857527
# Train Epoch: 10 [470/590]	loss: 0.927161
# Train Epoch: 10 [480/590]	loss: 0.860986
# Train Epoch: 10 [490/590]	loss: 0.980862
# Train Epoch: 10 [500/590]	loss: 0.909466
# Train Epoch: 10 [510/590]	loss: 0.847459
# Train Epoch: 10 [520/590]	loss: 1.070859
# Train Epoch: 10 [530/590]	loss: 1.122436
# Train Epoch: 10 [540/590]	loss: 0.905522
# Train Epoch: 10 [550/590]	loss: 0.855157
# Train Epoch: 10 [560/590]	loss: 0.843019
# Train Epoch: 10 [570/590]	loss: 0.985695
# Train Epoch: 10 [580/590]	loss: 0.966768
# [10]Validation Loss: 0.3091,Accuracy: 92.9054%
# Train Epoch: 11 [0/590]	loss: 0.866453
# Train Epoch: 11 [10/590]	loss: 0.833014
# Train Epoch: 11 [20/590]	loss: 0.881060
# Train Epoch: 11 [30/590]	loss: 0.948926
# Train Epoch: 11 [40/590]	loss: 0.849968
# Train Epoch: 11 [50/590]	loss: 0.897577
# Train Epoch: 11 [60/590]	loss: 0.864784
# Train Epoch: 11 [70/590]	loss: 0.887799
# Train Epoch: 11 [80/590]	loss: 0.977502
# Train Epoch: 11 [90/590]	loss: 0.948771
# Train Epoch: 11 [100/590]	loss: 1.048270
# Train Epoch: 11 [110/590]	loss: 0.940033
# Train Epoch: 11 [120/590]	loss: 0.867316
# Train Epoch: 11 [130/590]	loss: 0.849177
# Train Epoch: 11 [140/590]	loss: 0.839806
# Train Epoch: 11 [150/590]	loss: 0.860286
# Train Epoch: 11 [160/590]	loss: 0.979608
# Train Epoch: 11 [170/590]	loss: 1.209574
# Train Epoch: 11 [180/590]	loss: 0.873679
# Train Epoch: 11 [190/590]	loss: 0.894234
# Train Epoch: 11 [200/590]	loss: 0.930007
# Train Epoch: 11 [210/590]	loss: 0.902270
# Train Epoch: 11 [220/590]	loss: 1.096997
# Train Epoch: 11 [230/590]	loss: 0.856495
# Train Epoch: 11 [240/590]	loss: 0.927246
# Train Epoch: 11 [250/590]	loss: 1.107842
# Train Epoch: 11 [260/590]	loss: 0.832930
# Train Epoch: 11 [270/590]	loss: 1.020213
# Train Epoch: 11 [280/590]	loss: 0.831393
# Train Epoch: 11 [290/590]	loss: 0.929525
# Train Epoch: 11 [300/590]	loss: 0.818627
# Train Epoch: 11 [310/590]	loss: 0.898054
# Train Epoch: 11 [320/590]	loss: 0.845111
# Train Epoch: 11 [330/590]	loss: 0.933190
# Train Epoch: 11 [340/590]	loss: 1.138243
# Train Epoch: 11 [350/590]	loss: 0.947533
# Train Epoch: 11 [360/590]	loss: 0.987536
# Train Epoch: 11 [370/590]	loss: 0.921774
# Train Epoch: 11 [380/590]	loss: 0.852132
# Train Epoch: 11 [390/590]	loss: 0.894381
# Train Epoch: 11 [400/590]	loss: 0.833385
# Train Epoch: 11 [410/590]	loss: 1.035683
# Train Epoch: 11 [420/590]	loss: 0.891866
# Train Epoch: 11 [430/590]	loss: 0.917030
# Train Epoch: 11 [440/590]	loss: 0.936783
# Train Epoch: 11 [450/590]	loss: 0.858880
# Train Epoch: 11 [460/590]	loss: 1.217879
# Train Epoch: 11 [470/590]	loss: 0.915146
# Train Epoch: 11 [480/590]	loss: 0.820285
# Train Epoch: 11 [490/590]	loss: 0.919521
# Train Epoch: 11 [500/590]	loss: 0.826934
# Train Epoch: 11 [510/590]	loss: 1.026892
# Train Epoch: 11 [520/590]	loss: 0.853643
# Train Epoch: 11 [530/590]	loss: 0.861605
# Train Epoch: 11 [540/590]	loss: 0.889952
# Train Epoch: 11 [550/590]	loss: 0.934225
# Train Epoch: 11 [560/590]	loss: 0.958593
# Train Epoch: 11 [570/590]	loss: 0.876099
# Train Epoch: 11 [580/590]	loss: 0.928534
# [11]Validation Loss: 0.3073,Accuracy: 93.5811%
# Train Epoch: 12 [0/590]	loss: 0.837365
# Train Epoch: 12 [10/590]	loss: 0.856827
# Train Epoch: 12 [20/590]	loss: 0.865116
# Train Epoch: 12 [30/590]	loss: 0.873541
# Train Epoch: 12 [40/590]	loss: 0.851802
# Train Epoch: 12 [50/590]	loss: 0.946769
# Train Epoch: 12 [60/590]	loss: 0.869737
# Train Epoch: 12 [70/590]	loss: 0.856251
# Train Epoch: 12 [80/590]	loss: 0.831904
# Train Epoch: 12 [90/590]	loss: 0.846328
# Train Epoch: 12 [100/590]	loss: 0.865509
# Train Epoch: 12 [110/590]	loss: 1.023106
# Train Epoch: 12 [120/590]	loss: 0.936737
# Train Epoch: 12 [130/590]	loss: 1.012582
# Train Epoch: 12 [140/590]	loss: 0.902463
# Train Epoch: 12 [150/590]	loss: 1.115784
# Train Epoch: 12 [160/590]	loss: 0.919931
# Train Epoch: 12 [170/590]	loss: 0.866839
# Train Epoch: 12 [180/590]	loss: 0.997699
# Train Epoch: 12 [190/590]	loss: 0.825676
# Train Epoch: 12 [200/590]	loss: 0.972479
# Train Epoch: 12 [210/590]	loss: 0.846810
# Train Epoch: 12 [220/590]	loss: 0.911424
# Train Epoch: 12 [230/590]	loss: 0.989159
# Train Epoch: 12 [240/590]	loss: 0.834670
# Train Epoch: 12 [250/590]	loss: 0.871155
# Train Epoch: 12 [260/590]	loss: 1.202363
# Train Epoch: 12 [270/590]	loss: 0.843940
# Train Epoch: 12 [280/590]	loss: 1.071707
# Train Epoch: 12 [290/590]	loss: 0.856449
# Train Epoch: 12 [300/590]	loss: 0.839645
# Train Epoch: 12 [310/590]	loss: 0.827178
# Train Epoch: 12 [320/590]	loss: 0.863451
# Train Epoch: 12 [330/590]	loss: 0.842989
# Train Epoch: 12 [340/590]	loss: 0.871294
# Train Epoch: 12 [350/590]	loss: 1.046813
# Train Epoch: 12 [360/590]	loss: 0.977774
# Train Epoch: 12 [370/590]	loss: 0.851526
# Train Epoch: 12 [380/590]	loss: 0.928404
# Train Epoch: 12 [390/590]	loss: 0.821037
# Train Epoch: 12 [400/590]	loss: 0.822369
# Train Epoch: 12 [410/590]	loss: 0.980983
# Train Epoch: 12 [420/590]	loss: 0.913134
# Train Epoch: 12 [430/590]	loss: 0.939154
# Train Epoch: 12 [440/590]	loss: 0.863234
# Train Epoch: 12 [450/590]	loss: 0.885613
# Train Epoch: 12 [460/590]	loss: 0.823156
# Train Epoch: 12 [470/590]	loss: 0.856474
# Train Epoch: 12 [480/590]	loss: 1.032174
# Train Epoch: 12 [490/590]	loss: 0.808273
# Train Epoch: 12 [500/590]	loss: 0.923400
# Train Epoch: 12 [510/590]	loss: 0.899350
# Train Epoch: 12 [520/590]	loss: 1.517645
# Train Epoch: 12 [530/590]	loss: 0.889993
# Train Epoch: 12 [540/590]	loss: 0.854374
# Train Epoch: 12 [550/590]	loss: 0.889537
# Train Epoch: 12 [560/590]	loss: 0.844053
# Train Epoch: 12 [570/590]	loss: 0.865895
# Train Epoch: 12 [580/590]	loss: 0.852738
# [12]Validation Loss: 0.2994,Accuracy: 92.9054%
# Train Epoch: 13 [0/590]	loss: 0.899606
# Train Epoch: 13 [10/590]	loss: 0.862008
# Train Epoch: 13 [20/590]	loss: 0.837622
# Train Epoch: 13 [30/590]	loss: 0.855541
# Train Epoch: 13 [40/590]	loss: 0.849131
# Train Epoch: 13 [50/590]	loss: 0.851921
# Train Epoch: 13 [60/590]	loss: 0.844932
# Train Epoch: 13 [70/590]	loss: 0.912672
# Train Epoch: 13 [80/590]	loss: 0.825363
# Train Epoch: 13 [90/590]	loss: 0.841406
# Train Epoch: 13 [100/590]	loss: 0.823811
# Train Epoch: 13 [110/590]	loss: 0.871293
# Train Epoch: 13 [120/590]	loss: 0.844990
# Train Epoch: 13 [130/590]	loss: 1.115567
# Train Epoch: 13 [140/590]	loss: 0.868171
# Train Epoch: 13 [150/590]	loss: 0.904317
# Train Epoch: 13 [160/590]	loss: 0.866353
# Train Epoch: 13 [170/590]	loss: 1.165105
# Train Epoch: 13 [180/590]	loss: 0.994866
# Train Epoch: 13 [190/590]	loss: 0.890672
# Train Epoch: 13 [200/590]	loss: 0.859244
# Train Epoch: 13 [210/590]	loss: 0.857226
# Train Epoch: 13 [220/590]	loss: 0.825347
# Train Epoch: 13 [230/590]	loss: 0.900791
# Train Epoch: 13 [240/590]	loss: 0.848449
# Train Epoch: 13 [250/590]	loss: 1.020249
# Train Epoch: 13 [260/590]	loss: 0.827026
# Train Epoch: 13 [270/590]	loss: 0.906583
# Train Epoch: 13 [280/590]	loss: 0.830475
# Train Epoch: 13 [290/590]	loss: 0.828646
# Train Epoch: 13 [300/590]	loss: 0.813861
# Train Epoch: 13 [310/590]	loss: 0.925569
# Train Epoch: 13 [320/590]	loss: 0.985571
# Train Epoch: 13 [330/590]	loss: 0.820322
# Train Epoch: 13 [340/590]	loss: 0.997720
# Train Epoch: 13 [350/590]	loss: 0.901995
# Train Epoch: 13 [360/590]	loss: 0.836602
# Train Epoch: 13 [370/590]	loss: 1.023871
# Train Epoch: 13 [380/590]	loss: 0.965510
# Train Epoch: 13 [390/590]	loss: 1.020029
# Train Epoch: 13 [400/590]	loss: 0.835367
# Train Epoch: 13 [410/590]	loss: 0.914932
# Train Epoch: 13 [420/590]	loss: 0.836357
# Train Epoch: 13 [430/590]	loss: 0.948849
# Train Epoch: 13 [440/590]	loss: 0.873787
# Train Epoch: 13 [450/590]	loss: 1.065924
# Train Epoch: 13 [460/590]	loss: 0.820175
# Train Epoch: 13 [470/590]	loss: 1.084312
# Train Epoch: 13 [480/590]	loss: 0.930106
# Train Epoch: 13 [490/590]	loss: 0.813150
# Train Epoch: 13 [500/590]	loss: 0.830557
# Train Epoch: 13 [510/590]	loss: 0.806172
# Train Epoch: 13 [520/590]	loss: 0.839041
# Train Epoch: 13 [530/590]	loss: 0.899594
# Train Epoch: 13 [540/590]	loss: 0.817964
# Train Epoch: 13 [550/590]	loss: 0.869116
# Train Epoch: 13 [560/590]	loss: 0.879624
# Train Epoch: 13 [570/590]	loss: 0.833157
# Train Epoch: 13 [580/590]	loss: 0.823158
# [13]Validation Loss: 0.3051,Accuracy: 93.2432%
# Train Epoch: 14 [0/590]	loss: 0.907665
# Train Epoch: 14 [10/590]	loss: 0.811463
# Train Epoch: 14 [20/590]	loss: 0.903429
# Train Epoch: 14 [30/590]	loss: 0.896183
# Train Epoch: 14 [40/590]	loss: 0.858316
# Train Epoch: 14 [50/590]	loss: 0.857030
# Train Epoch: 14 [60/590]	loss: 0.827131
# Train Epoch: 14 [70/590]	loss: 0.865449
# Train Epoch: 14 [80/590]	loss: 0.848320
# Train Epoch: 14 [90/590]	loss: 0.845427
# Train Epoch: 14 [100/590]	loss: 0.813719
# Train Epoch: 14 [110/590]	loss: 1.019676
# Train Epoch: 14 [120/590]	loss: 0.845961
# Train Epoch: 14 [130/590]	loss: 0.809425
# Train Epoch: 14 [140/590]	loss: 0.853280
# Train Epoch: 14 [150/590]	loss: 0.933757
# Train Epoch: 14 [160/590]	loss: 1.209638
# Train Epoch: 14 [170/590]	loss: 0.832448
# Train Epoch: 14 [180/590]	loss: 0.821006
# Train Epoch: 14 [190/590]	loss: 0.823671
# Train Epoch: 14 [200/590]	loss: 0.894889
# Train Epoch: 14 [210/590]	loss: 0.963730
# Train Epoch: 14 [220/590]	loss: 0.888726
# Train Epoch: 14 [230/590]	loss: 0.937320
# Train Epoch: 14 [240/590]	loss: 0.845897
# Train Epoch: 14 [250/590]	loss: 0.958753
# Train Epoch: 14 [260/590]	loss: 0.947064
# Train Epoch: 14 [270/590]	loss: 0.866442
# Train Epoch: 14 [280/590]	loss: 0.820826
# Train Epoch: 14 [290/590]	loss: 0.901462
# Train Epoch: 14 [300/590]	loss: 1.065216
# Train Epoch: 14 [310/590]	loss: 1.102938
# Train Epoch: 14 [320/590]	loss: 0.869987
# Train Epoch: 14 [330/590]	loss: 0.919374
# Train Epoch: 14 [340/590]	loss: 0.829105
# Train Epoch: 14 [350/590]	loss: 1.042855
# Train Epoch: 14 [360/590]	loss: 0.872875
# Train Epoch: 14 [370/590]	loss: 1.233993
# Train Epoch: 14 [380/590]	loss: 0.910560
# Train Epoch: 14 [390/590]	loss: 0.865126
# Train Epoch: 14 [400/590]	loss: 0.902824
# Train Epoch: 14 [410/590]	loss: 0.807892
# Train Epoch: 14 [420/590]	loss: 0.972948
# Train Epoch: 14 [430/590]	loss: 0.827162
# Train Epoch: 14 [440/590]	loss: 0.816857
# Train Epoch: 14 [450/590]	loss: 0.807390
# Train Epoch: 14 [460/590]	loss: 0.809205
# Train Epoch: 14 [470/590]	loss: 0.903410
# Train Epoch: 14 [480/590]	loss: 0.833803
# Train Epoch: 14 [490/590]	loss: 0.836527
# Train Epoch: 14 [500/590]	loss: 0.839960
# Train Epoch: 14 [510/590]	loss: 0.856091
# Train Epoch: 14 [520/590]	loss: 0.980872
# Train Epoch: 14 [530/590]	loss: 1.172097
# Train Epoch: 14 [540/590]	loss: 1.001625
# Train Epoch: 14 [550/590]	loss: 0.856670
# Train Epoch: 14 [560/590]	loss: 0.811147
# Train Epoch: 14 [570/590]	loss: 0.809894
# Train Epoch: 14 [580/590]	loss: 0.821533
# [14]Validation Loss: 0.2824,Accuracy: 93.2432%
# Train Epoch: 15 [0/590]	loss: 0.813658
# Train Epoch: 15 [10/590]	loss: 0.844440
# Train Epoch: 15 [20/590]	loss: 0.808388
# Train Epoch: 15 [30/590]	loss: 0.831730
# Train Epoch: 15 [40/590]	loss: 0.807104
# Train Epoch: 15 [50/590]	loss: 0.820694
# Train Epoch: 15 [60/590]	loss: 0.832719
# Train Epoch: 15 [70/590]	loss: 0.838645
# Train Epoch: 15 [80/590]	loss: 0.900800
# Train Epoch: 15 [90/590]	loss: 1.113539
# Train Epoch: 15 [100/590]	loss: 0.814092
# Train Epoch: 15 [110/590]	loss: 0.951096
# Train Epoch: 15 [120/590]	loss: 0.814421
# Train Epoch: 15 [130/590]	loss: 0.893003
# Train Epoch: 15 [140/590]	loss: 0.842122
# Train Epoch: 15 [150/590]	loss: 0.828568
# Train Epoch: 15 [160/590]	loss: 0.899881
# Train Epoch: 15 [170/590]	loss: 0.843025
# Train Epoch: 15 [180/590]	loss: 0.865423
# Train Epoch: 15 [190/590]	loss: 0.833943
# Train Epoch: 15 [200/590]	loss: 0.816904
# Train Epoch: 15 [210/590]	loss: 0.881149
# Train Epoch: 15 [220/590]	loss: 0.911320
# Train Epoch: 15 [230/590]	loss: 0.885543
# Train Epoch: 15 [240/590]	loss: 0.936390
# Train Epoch: 15 [250/590]	loss: 0.818026
# Train Epoch: 15 [260/590]	loss: 0.895905
# Train Epoch: 15 [270/590]	loss: 0.865482
# Train Epoch: 15 [280/590]	loss: 0.888279
# Train Epoch: 15 [290/590]	loss: 0.823510
# Train Epoch: 15 [300/590]	loss: 0.828296
# Train Epoch: 15 [310/590]	loss: 0.906785
# Train Epoch: 15 [320/590]	loss: 0.865019
# Train Epoch: 15 [330/590]	loss: 0.887878
# Train Epoch: 15 [340/590]	loss: 0.927027
# Train Epoch: 15 [350/590]	loss: 0.870219
# Train Epoch: 15 [360/590]	loss: 0.841629
# Train Epoch: 15 [370/590]	loss: 0.809570
# Train Epoch: 15 [380/590]	loss: 1.007830
# Train Epoch: 15 [390/590]	loss: 0.821192
# Train Epoch: 15 [400/590]	loss: 0.906821
# Train Epoch: 15 [410/590]	loss: 0.834571
# Train Epoch: 15 [420/590]	loss: 0.817348
# Train Epoch: 15 [430/590]	loss: 0.851644
# Train Epoch: 15 [440/590]	loss: 0.818357
# Train Epoch: 15 [450/590]	loss: 0.808578
# Train Epoch: 15 [460/590]	loss: 0.857526
# Train Epoch: 15 [470/590]	loss: 0.841262
# Train Epoch: 15 [480/590]	loss: 0.872495
# Train Epoch: 15 [490/590]	loss: 0.887592
# Train Epoch: 15 [500/590]	loss: 0.802600
# Train Epoch: 15 [510/590]	loss: 0.801683
# Train Epoch: 15 [520/590]	loss: 0.819949
# Train Epoch: 15 [530/590]	loss: 0.934858
# Train Epoch: 15 [540/590]	loss: 0.858763
# Train Epoch: 15 [550/590]	loss: 0.928367
# Train Epoch: 15 [560/590]	loss: 0.826147
# Train Epoch: 15 [570/590]	loss: 0.919809
# Train Epoch: 15 [580/590]	loss: 0.803907
# [15]Validation Loss: 0.2946,Accuracy: 91.2162%
# Train Epoch: 16 [0/590]	loss: 0.825229
# Train Epoch: 16 [10/590]	loss: 0.949302
# Train Epoch: 16 [20/590]	loss: 0.946370
# Train Epoch: 16 [30/590]	loss: 0.828271
# Train Epoch: 16 [40/590]	loss: 0.828858
# Train Epoch: 16 [50/590]	loss: 0.902318
# Train Epoch: 16 [60/590]	loss: 0.829866
# Train Epoch: 16 [70/590]	loss: 0.836291
# Train Epoch: 16 [80/590]	loss: 0.814553
# Train Epoch: 16 [90/590]	loss: 0.814764
# Train Epoch: 16 [100/590]	loss: 0.885378
# Train Epoch: 16 [110/590]	loss: 0.940990
# Train Epoch: 16 [120/590]	loss: 0.803038
# Train Epoch: 16 [130/590]	loss: 0.831467
# Train Epoch: 16 [140/590]	loss: 0.797688
# Train Epoch: 16 [150/590]	loss: 0.813491
# Train Epoch: 16 [160/590]	loss: 0.877875
# Train Epoch: 16 [170/590]	loss: 1.104815
# Train Epoch: 16 [180/590]	loss: 0.962929
# Train Epoch: 16 [190/590]	loss: 0.844474
# Train Epoch: 16 [200/590]	loss: 0.877478
# Train Epoch: 16 [210/590]	loss: 0.976385
# Train Epoch: 16 [220/590]	loss: 0.811912
# Train Epoch: 16 [230/590]	loss: 0.976110
# Train Epoch: 16 [240/590]	loss: 0.813392
# Train Epoch: 16 [250/590]	loss: 1.005989
# Train Epoch: 16 [260/590]	loss: 0.834409
# Train Epoch: 16 [270/590]	loss: 0.860915
# Train Epoch: 16 [280/590]	loss: 1.031334
# Train Epoch: 16 [290/590]	loss: 0.823823
# Train Epoch: 16 [300/590]	loss: 0.968174
# Train Epoch: 16 [310/590]	loss: 0.800718
# Train Epoch: 16 [320/590]	loss: 0.869766
# Train Epoch: 16 [330/590]	loss: 0.885247
# Train Epoch: 16 [340/590]	loss: 0.815805
# Train Epoch: 16 [350/590]	loss: 1.082147
# Train Epoch: 16 [360/590]	loss: 0.938898
# Train Epoch: 16 [370/590]	loss: 0.808592
# Train Epoch: 16 [380/590]	loss: 0.814455
# Train Epoch: 16 [390/590]	loss: 0.811121
# Train Epoch: 16 [400/590]	loss: 0.823142
# Train Epoch: 16 [410/590]	loss: 0.835702
# Train Epoch: 16 [420/590]	loss: 0.860628
# Train Epoch: 16 [430/590]	loss: 0.829412
# Train Epoch: 16 [440/590]	loss: 0.815158
# Train Epoch: 16 [450/590]	loss: 0.816416
# Train Epoch: 16 [460/590]	loss: 0.821207
# Train Epoch: 16 [470/590]	loss: 0.833267
# Train Epoch: 16 [480/590]	loss: 0.805676
# Train Epoch: 16 [490/590]	loss: 1.283656
# Train Epoch: 16 [500/590]	loss: 1.085630
# Train Epoch: 16 [510/590]	loss: 0.884653
# Train Epoch: 16 [520/590]	loss: 0.830660
# Train Epoch: 16 [530/590]	loss: 0.884262
# Train Epoch: 16 [540/590]	loss: 0.842407
# Train Epoch: 16 [550/590]	loss: 0.913389
# Train Epoch: 16 [560/590]	loss: 0.840877
# Train Epoch: 16 [570/590]	loss: 0.810693
# Train Epoch: 16 [580/590]	loss: 0.833596
# [16]Validation Loss: 0.2797,Accuracy: 93.5811%
# Train Epoch: 17 [0/590]	loss: 0.851633
# Train Epoch: 17 [10/590]	loss: 0.819658
# Train Epoch: 17 [20/590]	loss: 0.808693
# Train Epoch: 17 [30/590]	loss: 0.832279
# Train Epoch: 17 [40/590]	loss: 0.807374
# Train Epoch: 17 [50/590]	loss: 0.841925
# Train Epoch: 17 [60/590]	loss: 0.926500
# Train Epoch: 17 [70/590]	loss: 0.837814
# Train Epoch: 17 [80/590]	loss: 0.807186
# Train Epoch: 17 [90/590]	loss: 0.932242
# Train Epoch: 17 [100/590]	loss: 0.810286
# Train Epoch: 17 [110/590]	loss: 0.853251
# Train Epoch: 17 [120/590]	loss: 0.810976
# Train Epoch: 17 [130/590]	loss: 0.961876
# Train Epoch: 17 [140/590]	loss: 0.834242
# Train Epoch: 17 [150/590]	loss: 0.856808
# Train Epoch: 17 [160/590]	loss: 0.891235
# Train Epoch: 17 [170/590]	loss: 0.907522
# Train Epoch: 17 [180/590]	loss: 0.814724
# Train Epoch: 17 [190/590]	loss: 1.002410
# Train Epoch: 17 [200/590]	loss: 1.007541
# Train Epoch: 17 [210/590]	loss: 0.809283
# Train Epoch: 17 [220/590]	loss: 0.878037
# Train Epoch: 17 [230/590]	loss: 0.803452
# Train Epoch: 17 [240/590]	loss: 0.848183
# Train Epoch: 17 [250/590]	loss: 0.879357
# Train Epoch: 17 [260/590]	loss: 0.811015
# Train Epoch: 17 [270/590]	loss: 0.822058
# Train Epoch: 17 [280/590]	loss: 0.908310
# Train Epoch: 17 [290/590]	loss: 0.811792
# Train Epoch: 17 [300/590]	loss: 0.825910
# Train Epoch: 17 [310/590]	loss: 0.813705
# Train Epoch: 17 [320/590]	loss: 0.815014
# Train Epoch: 17 [330/590]	loss: 0.814753
# Train Epoch: 17 [340/590]	loss: 0.814116
# Train Epoch: 17 [350/590]	loss: 0.804164
# Train Epoch: 17 [360/590]	loss: 0.817480
# Train Epoch: 17 [370/590]	loss: 0.981968
# Train Epoch: 17 [380/590]	loss: 0.812085
# Train Epoch: 17 [390/590]	loss: 0.847702
# Train Epoch: 17 [400/590]	loss: 0.857477
# Train Epoch: 17 [410/590]	loss: 0.799625
# Train Epoch: 17 [420/590]	loss: 0.845078
# Train Epoch: 17 [430/590]	loss: 0.842403
# Train Epoch: 17 [440/590]	loss: 0.829032
# Train Epoch: 17 [450/590]	loss: 0.868650
# Train Epoch: 17 [460/590]	loss: 0.834742
# Train Epoch: 17 [470/590]	loss: 0.843560
# Train Epoch: 17 [480/590]	loss: 0.805061
# Train Epoch: 17 [490/590]	loss: 0.852379
# Train Epoch: 17 [500/590]	loss: 0.811976
# Train Epoch: 17 [510/590]	loss: 0.815737
# Train Epoch: 17 [520/590]	loss: 0.808605
# Train Epoch: 17 [530/590]	loss: 0.805464
# Train Epoch: 17 [540/590]	loss: 0.812719
# Train Epoch: 17 [550/590]	loss: 0.860558
# Train Epoch: 17 [560/590]	loss: 0.816920
# Train Epoch: 17 [570/590]	loss: 0.799774
# Train Epoch: 17 [580/590]	loss: 0.831154
# [17]Validation Loss: 0.3070,Accuracy: 93.5811%
# Train Epoch: 18 [0/590]	loss: 0.846433
# Train Epoch: 18 [10/590]	loss: 0.853862
# Train Epoch: 18 [20/590]	loss: 0.805963
# Train Epoch: 18 [30/590]	loss: 0.913551
# Train Epoch: 18 [40/590]	loss: 0.817402
# Train Epoch: 18 [50/590]	loss: 0.811664
# Train Epoch: 18 [60/590]	loss: 0.828441
# Train Epoch: 18 [70/590]	loss: 0.943929
# Train Epoch: 18 [80/590]	loss: 0.792388
# Train Epoch: 18 [90/590]	loss: 0.866622
# Train Epoch: 18 [100/590]	loss: 0.823014
# Train Epoch: 18 [110/590]	loss: 0.845872
# Train Epoch: 18 [120/590]	loss: 0.805321
# Train Epoch: 18 [130/590]	loss: 0.827301
# Train Epoch: 18 [140/590]	loss: 0.844749
# Train Epoch: 18 [150/590]	loss: 0.895389
# Train Epoch: 18 [160/590]	loss: 0.815978
# Train Epoch: 18 [170/590]	loss: 0.837285
# Train Epoch: 18 [180/590]	loss: 0.801440
# Train Epoch: 18 [190/590]	loss: 0.831687
# Train Epoch: 18 [200/590]	loss: 0.800985
# Train Epoch: 18 [210/590]	loss: 0.830067
# Train Epoch: 18 [220/590]	loss: 0.916728
# Train Epoch: 18 [230/590]	loss: 0.817929
# Train Epoch: 18 [240/590]	loss: 0.944108
# Train Epoch: 18 [250/590]	loss: 0.813414
# Train Epoch: 18 [260/590]	loss: 0.803195
# Train Epoch: 18 [270/590]	loss: 0.842560
# Train Epoch: 18 [280/590]	loss: 0.854924
# Train Epoch: 18 [290/590]	loss: 0.804568
# Train Epoch: 18 [300/590]	loss: 0.821620
# Train Epoch: 18 [310/590]	loss: 1.037006
# Train Epoch: 18 [320/590]	loss: 1.037206
# Train Epoch: 18 [330/590]	loss: 0.826106
# Train Epoch: 18 [340/590]	loss: 0.852053
# Train Epoch: 18 [350/590]	loss: 0.828058
# Train Epoch: 18 [360/590]	loss: 0.948057
# Train Epoch: 18 [370/590]	loss: 0.792056
# Train Epoch: 18 [380/590]	loss: 0.908678
# Train Epoch: 18 [390/590]	loss: 0.829563
# Train Epoch: 18 [400/590]	loss: 0.849092
# Train Epoch: 18 [410/590]	loss: 0.816887
# Train Epoch: 18 [420/590]	loss: 0.827159
# Train Epoch: 18 [430/590]	loss: 0.834529
# Train Epoch: 18 [440/590]	loss: 0.913200
# Train Epoch: 18 [450/590]	loss: 0.861515
# Train Epoch: 18 [460/590]	loss: 0.814620
# Train Epoch: 18 [470/590]	loss: 0.826890
# Train Epoch: 18 [480/590]	loss: 0.946015
# Train Epoch: 18 [490/590]	loss: 0.816395
# Train Epoch: 18 [500/590]	loss: 0.861214
# Train Epoch: 18 [510/590]	loss: 0.813309
# Train Epoch: 18 [520/590]	loss: 0.817739
# Train Epoch: 18 [530/590]	loss: 0.826592
# Train Epoch: 18 [540/590]	loss: 0.840213
# Train Epoch: 18 [550/590]	loss: 0.852003
# Train Epoch: 18 [560/590]	loss: 0.826152
# Train Epoch: 18 [570/590]	loss: 0.832181
# Train Epoch: 18 [580/590]	loss: 0.846135
# [18]Validation Loss: 0.2891,Accuracy: 93.5811%
# Train Epoch: 19 [0/590]	loss: 0.801115
# Train Epoch: 19 [10/590]	loss: 0.809234
# Train Epoch: 19 [20/590]	loss: 0.805080
# Train Epoch: 19 [30/590]	loss: 0.807304
# Train Epoch: 19 [40/590]	loss: 0.903561
# Train Epoch: 19 [50/590]	loss: 0.829801
# Train Epoch: 19 [60/590]	loss: 0.800699
# Train Epoch: 19 [70/590]	loss: 0.802992
# Train Epoch: 19 [80/590]	loss: 0.893205
# Train Epoch: 19 [90/590]	loss: 0.810943
# Train Epoch: 19 [100/590]	loss: 0.815723
# Train Epoch: 19 [110/590]	loss: 0.978009
# Train Epoch: 19 [120/590]	loss: 0.805746
# Train Epoch: 19 [130/590]	loss: 0.852313
# Train Epoch: 19 [140/590]	loss: 0.830382
# Train Epoch: 19 [150/590]	loss: 0.785572
# Train Epoch: 19 [160/590]	loss: 0.822950
# Train Epoch: 19 [170/590]	loss: 0.806362
# Train Epoch: 19 [180/590]	loss: 1.094802
# Train Epoch: 19 [190/590]	loss: 0.979849
# Train Epoch: 19 [200/590]	loss: 1.005412
# Train Epoch: 19 [210/590]	loss: 0.793320
# Train Epoch: 19 [220/590]	loss: 0.942075
# Train Epoch: 19 [230/590]	loss: 0.819250
# Train Epoch: 19 [240/590]	loss: 0.838204
# Train Epoch: 19 [250/590]	loss: 0.834027
# Train Epoch: 19 [260/590]	loss: 0.923643
# Train Epoch: 19 [270/590]	loss: 0.798830
# Train Epoch: 19 [280/590]	loss: 0.859044
# Train Epoch: 19 [290/590]	loss: 0.813866
# Train Epoch: 19 [300/590]	loss: 0.830904
# Train Epoch: 19 [310/590]	loss: 0.819779
# Train Epoch: 19 [320/590]	loss: 0.801402
# Train Epoch: 19 [330/590]	loss: 0.819555
# Train Epoch: 19 [340/590]	loss: 0.829607
# Train Epoch: 19 [350/590]	loss: 0.819255
# Train Epoch: 19 [360/590]	loss: 0.830540
# Train Epoch: 19 [370/590]	loss: 0.867049
# Train Epoch: 19 [380/590]	loss: 0.794921
# Train Epoch: 19 [390/590]	loss: 0.791612
# Train Epoch: 19 [400/590]	loss: 0.829925
# Train Epoch: 19 [410/590]	loss: 0.807302
# Train Epoch: 19 [420/590]	loss: 0.925400
# Train Epoch: 19 [430/590]	loss: 0.857733
# Train Epoch: 19 [440/590]	loss: 0.828399
# Train Epoch: 19 [450/590]	loss: 0.905400
# Train Epoch: 19 [460/590]	loss: 0.804277
# ...
# Train Epoch: 23 [330/590]	loss: 0.812582
# Train Epoch: 23 [340/590]	loss: 0.848018
# Train Epoch: 23 [350/590]	loss: 0.794423
# Train Epoch: 23 [360/590]	loss: 0.801005
# Train Epoch: 23 [370/590]	loss: 0.823447
# Train Epoch: 23 [380/590]	loss: 0.814923
# Train Epoch: 23 [390/590]	loss: 0.804297
# Train Epoch: 23 [400/590]	loss: 0.814714
# Train Epoch: 23 [410/590]	loss: 0.816602
# Train Epoch: 23 [420/590]	loss: 1.015648
# Train Epoch: 23 [430/590]	loss: 0.793550
# Train Epoch: 23 [440/590]	loss: 0.807266
# Train Epoch: 23 [450/590]	loss: 0.815749
# Train Epoch: 23 [460/590]	loss: 0.794033
# Train Epoch: 23 [470/590]	loss: 0.925959
# Train Epoch: 23 [480/590]	loss: 0.792899
# Train Epoch: 23 [490/590]	loss: 1.269660
# Train Epoch: 23 [500/590]	loss: 0.825291
# Train Epoch: 23 [510/590]	loss: 0.796617
# Train Epoch: 23 [520/590]	loss: 0.816766
# Train Epoch: 23 [530/590]	loss: 0.951168
# Train Epoch: 23 [540/590]	loss: 0.808457
# Train Epoch: 23 [550/590]	loss: 0.803582
# Train Epoch: 23 [560/590]	loss: 0.813852
# Train Epoch: 23 [570/590]	loss: 0.811863
# Train Epoch: 23 [580/590]	loss: 0.798453
# [23]Validation Loss: 0.2808,Accuracy: 94.2568%
# Train Epoch: 24 [0/590]	loss: 0.798130
# Train Epoch: 24 [10/590]	loss: 0.873370
# Train Epoch: 24 [20/590]	loss: 0.851191
# Train Epoch: 24 [30/590]	loss: 0.788481
# Train Epoch: 24 [40/590]	loss: 0.800960
# Train Epoch: 24 [50/590]	loss: 0.850397
# Train Epoch: 24 [60/590]	loss: 0.806007
# Train Epoch: 24 [70/590]	loss: 0.803055
# Train Epoch: 24 [80/590]	loss: 0.776923
# Train Epoch: 24 [90/590]	loss: 0.837921
# Train Epoch: 24 [100/590]	loss: 0.877251
# Train Epoch: 24 [110/590]	loss: 0.812405
# Train Epoch: 24 [120/590]	loss: 0.791263
# Train Epoch: 24 [130/590]	loss: 0.859369
# Train Epoch: 24 [140/590]	loss: 0.794279
# Train Epoch: 24 [150/590]	loss: 0.804342
# Train Epoch: 24 [160/590]	loss: 0.796854
# Train Epoch: 24 [170/590]	loss: 0.939524
# Train Epoch: 24 [180/590]	loss: 0.801384
# Train Epoch: 24 [190/590]	loss: 0.813823
# Train Epoch: 24 [200/590]	loss: 0.829215
# Train Epoch: 24 [210/590]	loss: 0.790645
# Train Epoch: 24 [220/590]	loss: 0.793730
# Train Epoch: 24 [230/590]	loss: 0.818384
# Train Epoch: 24 [240/590]	loss: 0.833325
# Train Epoch: 24 [250/590]	loss: 0.808589
# Train Epoch: 24 [260/590]	loss: 0.922858
# Train Epoch: 24 [270/590]	loss: 0.840340
# Train Epoch: 24 [280/590]	loss: 0.833647
# Train Epoch: 24 [290/590]	loss: 0.809039
# Train Epoch: 24 [300/590]	loss: 0.808505
# Train Epoch: 24 [310/590]	loss: 0.802546
# Train Epoch: 24 [320/590]	loss: 0.825997
# Train Epoch: 24 [330/590]	loss: 0.799735
# Train Epoch: 24 [340/590]	loss: 0.804139
# Train Epoch: 24 [350/590]	loss: 0.794333
# Train Epoch: 24 [360/590]	loss: 0.805507
# Train Epoch: 24 [370/590]	loss: 0.793067
# Train Epoch: 24 [380/590]	loss: 0.898043
# Train Epoch: 24 [390/590]	loss: 0.946324
# Train Epoch: 24 [400/590]	loss: 0.803530
# Train Epoch: 24 [410/590]	loss: 0.811399
# Train Epoch: 24 [420/590]	loss: 0.818067
# Train Epoch: 24 [430/590]	loss: 0.828984
# Train Epoch: 24 [440/590]	loss: 0.812798
# Train Epoch: 24 [450/590]	loss: 0.829011
# Train Epoch: 24 [460/590]	loss: 0.797065
# Train Epoch: 24 [470/590]	loss: 0.800718
# Train Epoch: 24 [480/590]	loss: 0.818942
# Train Epoch: 24 [490/590]	loss: 0.799831
# Train Epoch: 24 [500/590]	loss: 0.793543
# Train Epoch: 24 [510/590]	loss: 0.806996
# Train Epoch: 24 [520/590]	loss: 0.843947
# Train Epoch: 24 [530/590]	loss: 0.793783
# Train Epoch: 24 [540/590]	loss: 0.864841
# Train Epoch: 24 [550/590]	loss: 0.829176
# Train Epoch: 24 [560/590]	loss: 0.802030
# Train Epoch: 24 [570/590]	loss: 0.808727
# Train Epoch: 24 [580/590]	loss: 0.807973
# [24]Validation Loss: 0.2736,Accuracy: 93.5811%
# Train Epoch: 25 [0/590]	loss: 0.800986
# Train Epoch: 25 [10/590]	loss: 0.794469
# Train Epoch: 25 [20/590]	loss: 0.816314
# Train Epoch: 25 [30/590]	loss: 0.873636
# Train Epoch: 25 [40/590]	loss: 0.800466
# Train Epoch: 25 [50/590]	loss: 0.858855
# Train Epoch: 25 [60/590]	loss: 0.808583
# Train Epoch: 25 [70/590]	loss: 0.814185
# Train Epoch: 25 [80/590]	loss: 0.823573
# Train Epoch: 25 [90/590]	loss: 0.812808
# Train Epoch: 25 [100/590]	loss: 0.803215
# Train Epoch: 25 [110/590]	loss: 0.854398
# Train Epoch: 25 [120/590]	loss: 0.787990
# Train Epoch: 25 [130/590]	loss: 0.806086
# Train Epoch: 25 [140/590]	loss: 0.801236
# Train Epoch: 25 [150/590]	loss: 0.796952
# Train Epoch: 25 [160/590]	loss: 0.798593
# Train Epoch: 25 [170/590]	loss: 0.800959
# Train Epoch: 25 [180/590]	loss: 0.822661
# Train Epoch: 25 [190/590]	loss: 0.830256
# Train Epoch: 25 [200/590]	loss: 0.845375
# Train Epoch: 25 [210/590]	loss: 0.876094
# Train Epoch: 25 [220/590]	loss: 0.829986
# Train Epoch: 25 [230/590]	loss: 0.797057
# Train Epoch: 25 [240/590]	loss: 0.864717
# Train Epoch: 25 [250/590]	loss: 0.831976
# Train Epoch: 25 [260/590]	loss: 0.791317
# Train Epoch: 25 [270/590]	loss: 0.789575
# Train Epoch: 25 [280/590]	loss: 1.034854
# Train Epoch: 25 [290/590]	loss: 0.842155
# Train Epoch: 25 [300/590]	loss: 0.818098
# Train Epoch: 25 [310/590]	loss: 0.793893
# Train Epoch: 25 [320/590]	loss: 0.812006
# Train Epoch: 25 [330/590]	loss: 0.817626
# Train Epoch: 25 [340/590]	loss: 0.813950
# Train Epoch: 25 [350/590]	loss: 0.829929
# Train Epoch: 25 [360/590]	loss: 0.834248
# Train Epoch: 25 [370/590]	loss: 0.800917
# Train Epoch: 25 [380/590]	loss: 0.801874
# Train Epoch: 25 [390/590]	loss: 0.898694
# Train Epoch: 25 [400/590]	loss: 0.810857
# Train Epoch: 25 [410/590]	loss: 0.793053
# Train Epoch: 25 [420/590]	loss: 0.830881
# Train Epoch: 25 [430/590]	loss: 0.813417
# Train Epoch: 25 [440/590]	loss: 0.795274
# Train Epoch: 25 [450/590]	loss: 0.822365
# Train Epoch: 25 [460/590]	loss: 0.820682
# Train Epoch: 25 [470/590]	loss: 0.807734
# Train Epoch: 25 [480/590]	loss: 0.817961
# Train Epoch: 25 [490/590]	loss: 0.815781
# Train Epoch: 25 [500/590]	loss: 0.836673
# Train Epoch: 25 [510/590]	loss: 0.871280
# Train Epoch: 25 [520/590]	loss: 0.800195
# Train Epoch: 25 [530/590]	loss: 0.869433
# Train Epoch: 25 [540/590]	loss: 0.800922
# Train Epoch: 25 [550/590]	loss: 0.890672
# Train Epoch: 25 [560/590]	loss: 0.807938
# Train Epoch: 25 [570/590]	loss: 0.823043
# Train Epoch: 25 [580/590]	loss: 0.829784
# [25]Validation Loss: 0.2856,Accuracy: 93.5811%
# Train Epoch: 26 [0/590]	loss: 0.819682
# Train Epoch: 26 [10/590]	loss: 0.853217
# Train Epoch: 26 [20/590]	loss: 0.784549
# Train Epoch: 26 [30/590]	loss: 0.815873
# Train Epoch: 26 [40/590]	loss: 0.796632
# Train Epoch: 26 [50/590]	loss: 0.797339
# Train Epoch: 26 [60/590]	loss: 0.810913
# Train Epoch: 26 [70/590]	loss: 0.793961
# Train Epoch: 26 [80/590]	loss: 0.806988
# Train Epoch: 26 [90/590]	loss: 0.831035
# Train Epoch: 26 [100/590]	loss: 0.853522
# Train Epoch: 26 [110/590]	loss: 0.806872
# Train Epoch: 26 [120/590]	loss: 0.789061
# Train Epoch: 26 [130/590]	loss: 0.796966
# Train Epoch: 26 [140/590]	loss: 0.814000
# Train Epoch: 26 [150/590]	loss: 0.827357
# Train Epoch: 26 [160/590]	loss: 0.817050
# Train Epoch: 26 [170/590]	loss: 0.796218
# Train Epoch: 26 [180/590]	loss: 0.806857
# Train Epoch: 26 [190/590]	loss: 0.811875
# Train Epoch: 26 [200/590]	loss: 0.790005
# Train Epoch: 26 [210/590]	loss: 0.801302
# Train Epoch: 26 [220/590]	loss: 0.842123
# Train Epoch: 26 [230/590]	loss: 0.824657
# Train Epoch: 26 [240/590]	loss: 0.870683
# Train Epoch: 26 [250/590]	loss: 0.810314
# Train Epoch: 26 [260/590]	loss: 0.884926
# Train Epoch: 26 [270/590]	loss: 0.815607
# Train Epoch: 26 [280/590]	loss: 0.787084
# Train Epoch: 26 [290/590]	loss: 0.795430
# Train Epoch: 26 [300/590]	loss: 0.849957
# Train Epoch: 26 [310/590]	loss: 0.823177
# Train Epoch: 26 [320/590]	loss: 0.796609
# Train Epoch: 26 [330/590]	loss: 0.795105
# Train Epoch: 26 [340/590]	loss: 0.804645
# Train Epoch: 26 [350/590]	loss: 0.812532
# Train Epoch: 26 [360/590]	loss: 0.878898
# Train Epoch: 26 [370/590]	loss: 0.826015
# Train Epoch: 26 [380/590]	loss: 0.815580
# Train Epoch: 26 [390/590]	loss: 0.794002
# Train Epoch: 26 [400/590]	loss: 0.819170
# Train Epoch: 26 [410/590]	loss: 0.819431
# Train Epoch: 26 [420/590]	loss: 0.835692
# Train Epoch: 26 [430/590]	loss: 0.804146
# Train Epoch: 26 [440/590]	loss: 0.816952
# Train Epoch: 26 [450/590]	loss: 0.829659
# Train Epoch: 26 [460/590]	loss: 0.795474
# Train Epoch: 26 [470/590]	loss: 0.842280
# Train Epoch: 26 [480/590]	loss: 0.839658
# Train Epoch: 26 [490/590]	loss: 0.797799
# Train Epoch: 26 [500/590]	loss: 0.786798
# Train Epoch: 26 [510/590]	loss: 0.807192
# Train Epoch: 26 [520/590]	loss: 0.871438
# Train Epoch: 26 [530/590]	loss: 0.793158
# Train Epoch: 26 [540/590]	loss: 0.792859
# Train Epoch: 26 [550/590]	loss: 0.828123
# Train Epoch: 26 [560/590]	loss: 0.801107
# Train Epoch: 26 [570/590]	loss: 0.840977
# Train Epoch: 26 [580/590]	loss: 0.852895
# [26]Validation Loss: 0.2829,Accuracy: 93.9189%
# Train Epoch: 27 [0/590]	loss: 0.821142
# Train Epoch: 27 [10/590]	loss: 0.790939
# Train Epoch: 27 [20/590]	loss: 0.815664
# Train Epoch: 27 [30/590]	loss: 0.806992
# Train Epoch: 27 [40/590]	loss: 0.879206
# Train Epoch: 27 [50/590]	loss: 0.941608
# Train Epoch: 27 [60/590]	loss: 0.805418
# Train Epoch: 27 [70/590]	loss: 0.926193
# Train Epoch: 27 [80/590]	loss: 0.815723
# Train Epoch: 27 [90/590]	loss: 0.805498
# Train Epoch: 27 [100/590]	loss: 0.890376
# Train Epoch: 27 [110/590]	loss: 0.813744
# Train Epoch: 27 [120/590]	loss: 0.878427
# Train Epoch: 27 [130/590]	loss: 0.828726
# Train Epoch: 27 [140/590]	loss: 0.809418
# Train Epoch: 27 [150/590]	loss: 0.804283
# Train Epoch: 27 [160/590]	loss: 0.819873
# Train Epoch: 27 [170/590]	loss: 0.896964
# Train Epoch: 27 [180/590]	loss: 1.059672
# Train Epoch: 27 [190/590]	loss: 0.805025
# Train Epoch: 27 [200/590]	loss: 0.807189
# Train Epoch: 27 [210/590]	loss: 0.796417
# Train Epoch: 27 [220/590]	loss: 0.894376
# Train Epoch: 27 [230/590]	loss: 0.805263
# Train Epoch: 27 [240/590]	loss: 0.894644
# Train Epoch: 27 [250/590]	loss: 0.794908
# Train Epoch: 27 [260/590]	loss: 0.804475
# Train Epoch: 27 [270/590]	loss: 0.809463
# Train Epoch: 27 [280/590]	loss: 0.791343
# Train Epoch: 27 [290/590]	loss: 0.829932
# Train Epoch: 27 [300/590]	loss: 0.821290
# Train Epoch: 27 [310/590]	loss: 0.812925
# Train Epoch: 27 [320/590]	loss: 0.797284
# Train Epoch: 27 [330/590]	loss: 0.821474
# Train Epoch: 27 [340/590]	loss: 0.851138
# Train Epoch: 27 [350/590]	loss: 0.797340
# Train Epoch: 27 [360/590]	loss: 0.805149
# Train Epoch: 27 [370/590]	loss: 0.788627
# Train Epoch: 27 [380/590]	loss: 0.856820
# Train Epoch: 27 [390/590]	loss: 0.873593
# Train Epoch: 27 [400/590]	loss: 0.794894
# Train Epoch: 27 [410/590]	loss: 0.800328
# Train Epoch: 27 [420/590]	loss: 0.800305
# Train Epoch: 27 [430/590]	loss: 0.802317
# Train Epoch: 27 [440/590]	loss: 0.791592
# Train Epoch: 27 [450/590]	loss: 0.878623
# Train Epoch: 27 [460/590]	loss: 0.797402
# Train Epoch: 27 [470/590]	loss: 0.794852
# Train Epoch: 27 [480/590]	loss: 0.800474
# Train Epoch: 27 [490/590]	loss: 0.792796
# Train Epoch: 27 [500/590]	loss: 0.795196
# Train Epoch: 27 [510/590]	loss: 0.855654
# Train Epoch: 27 [520/590]	loss: 0.799262
# Train Epoch: 27 [530/590]	loss: 0.809188
# Train Epoch: 27 [540/590]	loss: 0.798715
# Train Epoch: 27 [550/590]	loss: 0.798293
# Train Epoch: 27 [560/590]	loss: 0.822415
# Train Epoch: 27 [570/590]	loss: 0.807262
# Train Epoch: 27 [580/590]	loss: 0.849823
# [27]Validation Loss: 0.2791,Accuracy: 93.9189%
# Train Epoch: 28 [0/590]	loss: 0.797118
# Train Epoch: 28 [10/590]	loss: 0.800783
# Train Epoch: 28 [20/590]	loss: 0.794239
# Train Epoch: 28 [30/590]	loss: 0.804397
# Train Epoch: 28 [40/590]	loss: 0.808403
# Train Epoch: 28 [50/590]	loss: 0.787824
# Train Epoch: 28 [60/590]	loss: 0.785705
# Train Epoch: 28 [70/590]	loss: 0.788755
# Train Epoch: 28 [80/590]	loss: 0.847334
# Train Epoch: 28 [90/590]	loss: 0.817669
# Train Epoch: 28 [100/590]	loss: 0.819315
# Train Epoch: 28 [110/590]	loss: 1.054595
# Train Epoch: 28 [120/590]	loss: 0.800326
# Train Epoch: 28 [130/590]	loss: 0.801563
# Train Epoch: 28 [140/590]	loss: 0.831771
# Train Epoch: 28 [150/590]	loss: 0.802399
# Train Epoch: 28 [160/590]	loss: 0.789502
# Train Epoch: 28 [170/590]	loss: 0.801366
# Train Epoch: 28 [180/590]	loss: 0.829943
# Train Epoch: 28 [190/590]	loss: 0.813500
# Train Epoch: 28 [200/590]	loss: 0.834197
# Train Epoch: 28 [210/590]	loss: 0.854599
# Train Epoch: 28 [220/590]	loss: 0.859868
# Train Epoch: 28 [230/590]	loss: 0.835817
# Train Epoch: 28 [240/590]	loss: 0.788296
# Train Epoch: 28 [250/590]	loss: 0.796919
# Train Epoch: 28 [260/590]	loss: 0.795814
# Train Epoch: 28 [270/590]	loss: 0.920572
# Train Epoch: 28 [280/590]	loss: 0.804482
# Train Epoch: 28 [290/590]	loss: 0.803369
# Train Epoch: 28 [300/590]	loss: 0.820718
# Train Epoch: 28 [310/590]	loss: 0.790803
# Train Epoch: 28 [320/590]	loss: 0.834242
# Train Epoch: 28 [330/590]	loss: 0.798051
# Train Epoch: 28 [340/590]	loss: 0.803743
# Train Epoch: 28 [350/590]	loss: 0.870433
# Train Epoch: 28 [360/590]	loss: 0.810726
# Train Epoch: 28 [370/590]	loss: 0.883838
# Train Epoch: 28 [380/590]	loss: 0.796211
# Train Epoch: 28 [390/590]	loss: 0.837719
# Train Epoch: 28 [400/590]	loss: 0.808008
# Train Epoch: 28 [410/590]	loss: 0.804497
# Train Epoch: 28 [420/590]	loss: 0.794510
# Train Epoch: 28 [430/590]	loss: 0.826997
# Train Epoch: 28 [440/590]	loss: 0.787381
# Train Epoch: 28 [450/590]	loss: 0.796658
# Train Epoch: 28 [460/590]	loss: 0.811136
# Train Epoch: 28 [470/590]	loss: 0.784078
# Train Epoch: 28 [480/590]	loss: 0.793006
# Train Epoch: 28 [490/590]	loss: 0.823193
# Train Epoch: 28 [500/590]	loss: 0.802504
# Train Epoch: 28 [510/590]	loss: 0.811965
# Train Epoch: 28 [520/590]	loss: 0.801139
# Train Epoch: 28 [530/590]	loss: 0.803857
# Train Epoch: 28 [540/590]	loss: 0.796384
# Train Epoch: 28 [550/590]	loss: 0.832383
# Train Epoch: 28 [560/590]	loss: 0.872590
# Train Epoch: 28 [570/590]	loss: 0.825984
# Train Epoch: 28 [580/590]	loss: 0.794642
# [28]Validation Loss: 0.2791,Accuracy: 93.9189%
# Train Epoch: 29 [0/590]	loss: 0.794171
# Train Epoch: 29 [10/590]	loss: 0.802888
# Train Epoch: 29 [20/590]	loss: 0.812286
# Train Epoch: 29 [30/590]	loss: 0.796518
# Train Epoch: 29 [40/590]	loss: 0.797806
# Train Epoch: 29 [50/590]	loss: 0.806153
# Train Epoch: 29 [60/590]	loss: 0.793197
# Train Epoch: 29 [70/590]	loss: 0.811034
# Train Epoch: 29 [80/590]	loss: 0.817383
# Train Epoch: 29 [90/590]	loss: 0.798230
# Train Epoch: 29 [100/590]	loss: 0.795379
# Train Epoch: 29 [110/590]	loss: 0.803159
# Train Epoch: 29 [120/590]	loss: 0.802614
# Train Epoch: 29 [130/590]	loss: 0.804874
# Train Epoch: 29 [140/590]	loss: 0.849932
# Train Epoch: 29 [150/590]	loss: 0.820560
# Train Epoch: 29 [160/590]	loss: 0.790599
# Train Epoch: 29 [170/590]	loss: 0.812620
# Train Epoch: 29 [180/590]	loss: 0.802670
# Train Epoch: 29 [190/590]	loss: 0.805523
# Train Epoch: 29 [200/590]	loss: 0.855134
# Train Epoch: 29 [210/590]	loss: 0.796767
# Train Epoch: 29 [220/590]	loss: 0.838289
# Train Epoch: 29 [230/590]	loss: 0.817925
# Train Epoch: 29 [240/590]	loss: 0.813598
# Train Epoch: 29 [250/590]	loss: 0.809041
# Train Epoch: 29 [260/590]	loss: 0.791070
# Train Epoch: 29 [270/590]	loss: 0.782744
# Train Epoch: 29 [280/590]	loss: 0.847416
# Train Epoch: 29 [290/590]	loss: 0.842249
# Train Epoch: 29 [300/590]	loss: 0.785145
# Train Epoch: 29 [310/590]	loss: 0.780362
# Train Epoch: 29 [320/590]	loss: 1.060690
# Train Epoch: 29 [330/590]	loss: 0.828966
# Train Epoch: 29 [340/590]	loss: 0.801647
# Train Epoch: 29 [350/590]	loss: 0.801427
# Train Epoch: 29 [360/590]	loss: 0.804854
# Train Epoch: 29 [370/590]	loss: 0.845831
# Train Epoch: 29 [380/590]	loss: 0.812527
# Train Epoch: 29 [390/590]	loss: 0.805333
# Train Epoch: 29 [400/590]	loss: 0.788367
# Train Epoch: 29 [410/590]	loss: 0.796231
# Train Epoch: 29 [420/590]	loss: 0.829075
# Train Epoch: 29 [430/590]	loss: 0.838274
# Train Epoch: 29 [440/590]	loss: 0.783346
# Train Epoch: 29 [450/590]	loss: 0.927649
# Train Epoch: 29 [460/590]	loss: 0.867862
# Train Epoch: 29 [470/590]	loss: 0.802537
# Train Epoch: 29 [480/590]	loss: 0.855227
# Train Epoch: 29 [490/590]	loss: 0.811023
# Train Epoch: 29 [500/590]	loss: 0.815170
# Train Epoch: 29 [510/590]	loss: 0.794384
# Train Epoch: 29 [520/590]	loss: 0.808061
# Train Epoch: 29 [530/590]	loss: 0.799407
# Train Epoch: 29 [540/590]	loss: 0.796589
# Train Epoch: 29 [550/590]	loss: 0.794171
# Train Epoch: 29 [560/590]	loss: 0.829888
# Train Epoch: 29 [570/590]	loss: 0.795480
# Train Epoch: 29 [580/590]	loss: 0.801797
# [29]Validation Loss: 0.2791,Accuracy: 93.9189%
# [FINAL] Test Loss: 0.3033,Accuracy: 93.9597%
# Best Accuracy:  94.25675675675676
# Elasped Time: 2h, 133m, 6s
# time: 2h, 133m, 6s

# %%
# Finish Weight & Biases
wandb.finish()
# Out:
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▅▃▂▂▂▂▁▂▂▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▅▇▇██████████████████████████</td></tr><tr><td>val_loss</td><td>█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficientnet-b0(2)</strong> at: <a href='https://wandb.ai/cv_al2/Active_learning_2/runs/tcfnovy9' target="_blank">https://wandb.ai/cv_al2/Active_learning_2/runs/tcfnovy9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231112_083414-tcfnovy9/logs</code>

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# The local path to our target image
import random

# 테스트 데이터셋에서 무작위로 이미지 선택
random_index = random.randint(0, len(test_set) - 1)
img_path = test_set.image_folder[random_index]
img_path = os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test',img_path)
display(Image(img_path))

def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 1s 0us/step
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n02025239', 'ruddy_turnstone', 8.062851)]

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)
# Out:
# <ipython-input-21-8a3df7f2985d>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

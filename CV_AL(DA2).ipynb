# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor,Normalize, RandomHorizontalFlip, Resize
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image

from torch.utils.data import ConcatDataset

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
# Create DataLoader
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.mode = mode
    self.transform = transform

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)

    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([transforms.Resize((448, 448)),transforms.ToTensor(),])
transforms_test = transforms.Compose([transforms.Resize((448,448)),transforms.ToTensor(),])
transforms_train_aug = transforms.RandomApply([
    transforms.Resize((448, 448)),
    transforms.RandomCrop(448),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),],p=1)

BATCH_SIZE = 32
train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

# 데이터 증강을 위해 원래 데이터를 복사하고 추가
train_set_augmented = CUB2011(mode='train', transform=transforms_train_aug)

# 두 데이터셋을 연결하여 새로운 훈련 데이터셋 생성
train_set_combined = ConcatDataset([train_set_origin, train_set_augmented])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
### Model / Optimizer ###
EPOCH = 30
lr = 0.1

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.SGD(model.parameters(),lr=lr)

print("Created a learning model and optimizer")

### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  # 모델을 학습 모드로 변환
  model.train()

  for i,(image,target) in enumerate(train_loader):
    # 각 image와 target을 앞서 설정한 DEVICE(GPU 혹은 CPU)에 보내기
    image,target = image.to(DEVICE),target.to(DEVICE)
    # data를 모델에 넣어서 hypothesis 획득
    output = model(image)
    # 반복 때마다 기울기를 새로 계산, 이 함수로 초기화
    optimizer.zero_grad()
    # 비교해서 loss 계산
    train_loss = F.cross_entropy(output,target).to(DEVICE)
    # loss를 backward 계산
    train_loss.backward()
    # 계산한 기울기를 앞서 정의한 알고리즘에 맞춰서 가중치를 수정
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  # 모델을 평가 모드로 변환
  model.eval()

  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 78.1MB/s]
# Created a learning model and optimizer

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/148]	loss: 3.880374
# Train Epoch: 0 [10/148]	loss: 4.759263
# Train Epoch: 0 [20/148]	loss: 3.464854
# Train Epoch: 0 [30/148]	loss: 2.521425
# Train Epoch: 0 [40/148]	loss: 2.220012
# Train Epoch: 0 [50/148]	loss: 1.791762
# Train Epoch: 0 [60/148]	loss: 2.032056
# Train Epoch: 0 [70/148]	loss: 1.454412
# Train Epoch: 0 [80/148]	loss: 1.357602
# Train Epoch: 0 [90/148]	loss: 0.849423
# Train Epoch: 0 [100/148]	loss: 0.974224
# Train Epoch: 0 [110/148]	loss: 1.204466
# Train Epoch: 0 [120/148]	loss: 0.793179
# Train Epoch: 0 [130/148]	loss: 0.845412
# Train Epoch: 0 [140/148]	loss: 0.296829
# [0]Validation Loss: 1.4796,Accuracy: 61.1486%
# Train Epoch: 1 [0/148]	loss: 0.575013
# Train Epoch: 1 [10/148]	loss: 0.354312
# Train Epoch: 1 [20/148]	loss: 0.286686
# Train Epoch: 1 [30/148]	loss: 0.377199
# Train Epoch: 1 [40/148]	loss: 0.589413
# Train Epoch: 1 [50/148]	loss: 0.512594
# Train Epoch: 1 [60/148]	loss: 0.324053
# Train Epoch: 1 [70/148]	loss: 0.200249
# Train Epoch: 1 [80/148]	loss: 0.500341
# Train Epoch: 1 [90/148]	loss: 0.293932
# Train Epoch: 1 [100/148]	loss: 0.207654
# Train Epoch: 1 [110/148]	loss: 0.515862
# Train Epoch: 1 [120/148]	loss: 0.152777
# Train Epoch: 1 [130/148]	loss: 0.243826
# Train Epoch: 1 [140/148]	loss: 0.275422
# [1]Validation Loss: 0.7078,Accuracy: 81.7568%
# Train Epoch: 2 [0/148]	loss: 0.176793
# Train Epoch: 2 [10/148]	loss: 0.067373
# Train Epoch: 2 [20/148]	loss: 0.083250
# Train Epoch: 2 [30/148]	loss: 0.155730
# Train Epoch: 2 [40/148]	loss: 0.132851
# Train Epoch: 2 [50/148]	loss: 0.124334
# Train Epoch: 2 [60/148]	loss: 0.116341
# Train Epoch: 2 [70/148]	loss: 0.090272
# Train Epoch: 2 [80/148]	loss: 0.217198
# Train Epoch: 2 [90/148]	loss: 0.106411
# Train Epoch: 2 [100/148]	loss: 0.145582
# Train Epoch: 2 [110/148]	loss: 0.112375
# Train Epoch: 2 [120/148]	loss: 0.078985
# Train Epoch: 2 [130/148]	loss: 0.041090
# Train Epoch: 2 [140/148]	loss: 0.129717
# [2]Validation Loss: 0.4353,Accuracy: 88.8514%
# Train Epoch: 3 [0/148]	loss: 0.038707
# Train Epoch: 3 [10/148]	loss: 0.051370
# Train Epoch: 3 [20/148]	loss: 0.055535
# Train Epoch: 3 [30/148]	loss: 0.025234
# Train Epoch: 3 [40/148]	loss: 0.043220
# Train Epoch: 3 [50/148]	loss: 0.078892
# Train Epoch: 3 [60/148]	loss: 0.034350
# Train Epoch: 3 [70/148]	loss: 0.065173
# Train Epoch: 3 [80/148]	loss: 0.021848
# Train Epoch: 3 [90/148]	loss: 0.043721
# Train Epoch: 3 [100/148]	loss: 0.027167
# Train Epoch: 3 [110/148]	loss: 0.045188
# Train Epoch: 3 [120/148]	loss: 0.130663
# Train Epoch: 3 [130/148]	loss: 0.049444
# Train Epoch: 3 [140/148]	loss: 0.020893
# [3]Validation Loss: 1.0944,Accuracy: 73.3108%
# Train Epoch: 4 [0/148]	loss: 0.031153
# Train Epoch: 4 [10/148]	loss: 0.016839
# Train Epoch: 4 [20/148]	loss: 0.020594
# Train Epoch: 4 [30/148]	loss: 0.014738
# Train Epoch: 4 [40/148]	loss: 0.013478
# Train Epoch: 4 [50/148]	loss: 0.012170
# Train Epoch: 4 [60/148]	loss: 0.021030
# Train Epoch: 4 [70/148]	loss: 0.015366
# Train Epoch: 4 [80/148]	loss: 0.040440
# Train Epoch: 4 [90/148]	loss: 0.020503
# Train Epoch: 4 [100/148]	loss: 0.019529
# Train Epoch: 4 [110/148]	loss: 0.019722
# Train Epoch: 4 [120/148]	loss: 0.023428
# Train Epoch: 4 [130/148]	loss: 0.071761
# Train Epoch: 4 [140/148]	loss: 0.070963
# [4]Validation Loss: 0.4033,Accuracy: 89.1892%
# Train Epoch: 5 [0/148]	loss: 0.025798
# Train Epoch: 5 [10/148]	loss: 0.025503
# Train Epoch: 5 [20/148]	loss: 0.013744
# Train Epoch: 5 [30/148]	loss: 0.014743
# Train Epoch: 5 [40/148]	loss: 0.053146
# Train Epoch: 5 [50/148]	loss: 0.119793
# Train Epoch: 5 [60/148]	loss: 0.010377
# Train Epoch: 5 [70/148]	loss: 0.013839
# Train Epoch: 5 [80/148]	loss: 0.016556
# Train Epoch: 5 [90/148]	loss: 0.026878
# Train Epoch: 5 [100/148]	loss: 0.014255
# Train Epoch: 5 [110/148]	loss: 0.008472
# Train Epoch: 5 [120/148]	loss: 0.028658
# Train Epoch: 5 [130/148]	loss: 0.014772
# Train Epoch: 5 [140/148]	loss: 0.017059
# [5]Validation Loss: 0.3275,Accuracy: 90.8784%
# Train Epoch: 6 [0/148]	loss: 0.013709
# Train Epoch: 6 [10/148]	loss: 0.008800
# Train Epoch: 6 [20/148]	loss: 0.010773
# Train Epoch: 6 [30/148]	loss: 0.021831
# Train Epoch: 6 [40/148]	loss: 0.011777
# Train Epoch: 6 [50/148]	loss: 0.008519
# Train Epoch: 6 [60/148]	loss: 0.004159
# Train Epoch: 6 [70/148]	loss: 0.014747
# Train Epoch: 6 [80/148]	loss: 0.004929
# Train Epoch: 6 [90/148]	loss: 0.018442
# Train Epoch: 6 [100/148]	loss: 0.009685
# Train Epoch: 6 [110/148]	loss: 0.006917
# Train Epoch: 6 [120/148]	loss: 0.016722
# Train Epoch: 6 [130/148]	loss: 0.005011
# Train Epoch: 6 [140/148]	loss: 0.003967
# [6]Validation Loss: 0.3540,Accuracy: 91.2162%
# Train Epoch: 7 [0/148]	loss: 0.004698
# Train Epoch: 7 [10/148]	loss: 0.006970
# Train Epoch: 7 [20/148]	loss: 0.017494
# Train Epoch: 7 [30/148]	loss: 0.008502
# Train Epoch: 7 [40/148]	loss: 0.011251
# Train Epoch: 7 [50/148]	loss: 0.007897
# Train Epoch: 7 [60/148]	loss: 0.012193
# Train Epoch: 7 [70/148]	loss: 0.006542
# Train Epoch: 7 [80/148]	loss: 0.005906
# Train Epoch: 7 [90/148]	loss: 0.010933
# Train Epoch: 7 [100/148]	loss: 0.007361
# Train Epoch: 7 [110/148]	loss: 0.005980
# Train Epoch: 7 [120/148]	loss: 0.038865
# Train Epoch: 7 [130/148]	loss: 0.005629
# Train Epoch: 7 [140/148]	loss: 0.004906
# [7]Validation Loss: 0.3664,Accuracy: 89.5270%
# Train Epoch: 8 [0/148]	loss: 0.008153
# Train Epoch: 8 [10/148]	loss: 0.003265
# Train Epoch: 8 [20/148]	loss: 0.013125
# Train Epoch: 8 [30/148]	loss: 0.004753
# Train Epoch: 8 [40/148]	loss: 0.021112
# Train Epoch: 8 [50/148]	loss: 0.005916
# Train Epoch: 8 [60/148]	loss: 0.004394
# Train Epoch: 8 [70/148]	loss: 0.004483
# Train Epoch: 8 [80/148]	loss: 0.004994
# Train Epoch: 8 [90/148]	loss: 0.003599
# Train Epoch: 8 [100/148]	loss: 0.019946
# Train Epoch: 8 [110/148]	loss: 0.003968
# Train Epoch: 8 [120/148]	loss: 0.006119
# Train Epoch: 8 [130/148]	loss: 0.006410
# Train Epoch: 8 [140/148]	loss: 0.004092
# [8]Validation Loss: 0.3465,Accuracy: 90.8784%
# Train Epoch: 9 [0/148]	loss: 0.007102
# Train Epoch: 9 [10/148]	loss: 0.003810
# Train Epoch: 9 [20/148]	loss: 0.006669
# Train Epoch: 9 [30/148]	loss: 0.003800
# Train Epoch: 9 [40/148]	loss: 0.010308
# Train Epoch: 9 [50/148]	loss: 0.003293
# Train Epoch: 9 [60/148]	loss: 0.004684
# Train Epoch: 9 [70/148]	loss: 0.004083
# Train Epoch: 9 [80/148]	loss: 0.005731
# Train Epoch: 9 [90/148]	loss: 0.013529
# Train Epoch: 9 [100/148]	loss: 0.004589
# Train Epoch: 9 [110/148]	loss: 0.004810
# Train Epoch: 9 [120/148]	loss: 0.004157
# Train Epoch: 9 [130/148]	loss: 0.003211
# Train Epoch: 9 [140/148]	loss: 0.010022
# [9]Validation Loss: 0.3315,Accuracy: 91.2162%
# Train Epoch: 10 [0/148]	loss: 0.004771
# Train Epoch: 10 [10/148]	loss: 0.006520
# Train Epoch: 10 [20/148]	loss: 0.004245
# Train Epoch: 10 [30/148]	loss: 0.003701
# Train Epoch: 10 [40/148]	loss: 0.003600
# Train Epoch: 10 [50/148]	loss: 0.008116
# Train Epoch: 10 [60/148]	loss: 0.008381
# Train Epoch: 10 [70/148]	loss: 0.001864
# Train Epoch: 10 [80/148]	loss: 0.005770
# Train Epoch: 10 [90/148]	loss: 0.003209
# Train Epoch: 10 [100/148]	loss: 0.002565
# Train Epoch: 10 [110/148]	loss: 0.001943
# Train Epoch: 10 [120/148]	loss: 0.002563
# Train Epoch: 10 [130/148]	loss: 0.003584
# Train Epoch: 10 [140/148]	loss: 0.002902
# [10]Validation Loss: 0.3125,Accuracy: 90.8784%
# Train Epoch: 11 [0/148]	loss: 0.003156
# Train Epoch: 11 [10/148]	loss: 0.008244
# Train Epoch: 11 [20/148]	loss: 0.002732
# Train Epoch: 11 [30/148]	loss: 0.004394
# Train Epoch: 11 [40/148]	loss: 0.002245
# Train Epoch: 11 [50/148]	loss: 0.001301
# Train Epoch: 11 [60/148]	loss: 0.002248
# Train Epoch: 11 [70/148]	loss: 0.002693
# Train Epoch: 11 [80/148]	loss: 0.002979
# Train Epoch: 11 [90/148]	loss: 0.003755
# Train Epoch: 11 [100/148]	loss: 0.002274
# Train Epoch: 11 [110/148]	loss: 0.003126
# Train Epoch: 11 [120/148]	loss: 0.003726
# Train Epoch: 11 [130/148]	loss: 0.003908
# Train Epoch: 11 [140/148]	loss: 0.003846
# [11]Validation Loss: 0.3034,Accuracy: 91.8919%
# Train Epoch: 12 [0/148]	loss: 0.002965
# Train Epoch: 12 [10/148]	loss: 0.002070
# Train Epoch: 12 [20/148]	loss: 0.003064
# Train Epoch: 12 [30/148]	loss: 0.005322
# Train Epoch: 12 [40/148]	loss: 0.004006
# Train Epoch: 12 [50/148]	loss: 0.003880
# Train Epoch: 12 [60/148]	loss: 0.002031
# Train Epoch: 12 [70/148]	loss: 0.007242
# Train Epoch: 12 [80/148]	loss: 0.005044
# Train Epoch: 12 [90/148]	loss: 0.003307
# Train Epoch: 12 [100/148]	loss: 0.001794
# Train Epoch: 12 [110/148]	loss: 0.001635
# Train Epoch: 12 [120/148]	loss: 0.002070
# Train Epoch: 12 [130/148]	loss: 0.003661
# Train Epoch: 12 [140/148]	loss: 0.003805
# [12]Validation Loss: 0.3069,Accuracy: 90.8784%
# Train Epoch: 13 [0/148]	loss: 0.002487
# Train Epoch: 13 [10/148]	loss: 0.021165
# Train Epoch: 13 [20/148]	loss: 0.002363
# Train Epoch: 13 [30/148]	loss: 0.004235
# Train Epoch: 13 [40/148]	loss: 0.001665
# Train Epoch: 13 [50/148]	loss: 0.006781
# Train Epoch: 13 [60/148]	loss: 0.003075
# Train Epoch: 13 [70/148]	loss: 0.004152
# Train Epoch: 13 [80/148]	loss: 0.001793
# Train Epoch: 13 [90/148]	loss: 0.002140
# Train Epoch: 13 [100/148]	loss: 0.002472
# Train Epoch: 13 [110/148]	loss: 0.007480
# Train Epoch: 13 [120/148]	loss: 0.002950
# Train Epoch: 13 [130/148]	loss: 0.002414
# Train Epoch: 13 [140/148]	loss: 0.001286
# [13]Validation Loss: 0.3091,Accuracy: 91.5541%
# Train Epoch: 14 [0/148]	loss: 0.002857
# Train Epoch: 14 [10/148]	loss: 0.004153
# Train Epoch: 14 [20/148]	loss: 0.002686
# Train Epoch: 14 [30/148]	loss: 0.003904
# Train Epoch: 14 [40/148]	loss: 0.003437
# Train Epoch: 14 [50/148]	loss: 0.004849
# Train Epoch: 14 [60/148]	loss: 0.001276
# Train Epoch: 14 [70/148]	loss: 0.001202
# Train Epoch: 14 [80/148]	loss: 0.002071
# Train Epoch: 14 [90/148]	loss: 0.002468
# Train Epoch: 14 [100/148]	loss: 0.002580
# Train Epoch: 14 [110/148]	loss: 0.002228
# Train Epoch: 14 [120/148]	loss: 0.001486
# Train Epoch: 14 [130/148]	loss: 0.003197
# Train Epoch: 14 [140/148]	loss: 0.001486
# [14]Validation Loss: 0.3012,Accuracy: 92.2297%
# Train Epoch: 15 [0/148]	loss: 0.002183
# Train Epoch: 15 [10/148]	loss: 0.001553
# Train Epoch: 15 [20/148]	loss: 0.001877
# Train Epoch: 15 [30/148]	loss: 0.006823
# Train Epoch: 15 [40/148]	loss: 0.000985
# Train Epoch: 15 [50/148]	loss: 0.002164
# Train Epoch: 15 [60/148]	loss: 0.001867
# Train Epoch: 15 [70/148]	loss: 0.001208
# Train Epoch: 15 [80/148]	loss: 0.003534
# Train Epoch: 15 [90/148]	loss: 0.001953
# Train Epoch: 15 [100/148]	loss: 0.003791
# Train Epoch: 15 [110/148]	loss: 0.002209
# Train Epoch: 15 [120/148]	loss: 0.002835
# Train Epoch: 15 [130/148]	loss: 0.000958
# Train Epoch: 15 [140/148]	loss: 0.002993
# [15]Validation Loss: 0.2963,Accuracy: 92.2297%
# Train Epoch: 16 [0/148]	loss: 0.001050
# Train Epoch: 16 [10/148]	loss: 0.003399
# Train Epoch: 16 [20/148]	loss: 0.001459
# Train Epoch: 16 [30/148]	loss: 0.002312
# Train Epoch: 16 [40/148]	loss: 0.001342
# Train Epoch: 16 [50/148]	loss: 0.001748
# Train Epoch: 16 [60/148]	loss: 0.002762
# Train Epoch: 16 [70/148]	loss: 0.001856
# Train Epoch: 16 [80/148]	loss: 0.001648
# Train Epoch: 16 [90/148]	loss: 0.002216
# Train Epoch: 16 [100/148]	loss: 0.001252
# Train Epoch: 16 [110/148]	loss: 0.005044
# Train Epoch: 16 [120/148]	loss: 0.002239
# Train Epoch: 16 [130/148]	loss: 0.003581
# Train Epoch: 16 [140/148]	loss: 0.001807
# [16]Validation Loss: 0.3043,Accuracy: 91.8919%
# Train Epoch: 17 [0/148]	loss: 0.002405
# Train Epoch: 17 [10/148]	loss: 0.002722
# Train Epoch: 17 [20/148]	loss: 0.001569
# Train Epoch: 17 [30/148]	loss: 0.001541
# Train Epoch: 17 [40/148]	loss: 0.004093
# Train Epoch: 17 [50/148]	loss: 0.002909
# Train Epoch: 17 [60/148]	loss: 0.002380
# Train Epoch: 17 [70/148]	loss: 0.000885
# Train Epoch: 17 [80/148]	loss: 0.001346
# Train Epoch: 17 [90/148]	loss: 0.002546
# Train Epoch: 17 [100/148]	loss: 0.004506
# Train Epoch: 17 [110/148]	loss: 0.001411
# Train Epoch: 17 [120/148]	loss: 0.002560
# Train Epoch: 17 [130/148]	loss: 0.001141
# Train Epoch: 17 [140/148]	loss: 0.001305
# [17]Validation Loss: 0.3060,Accuracy: 91.8919%
# Train Epoch: 18 [0/148]	loss: 0.002147
# Train Epoch: 18 [10/148]	loss: 0.003774
# Train Epoch: 18 [20/148]	loss: 0.002267
# Train Epoch: 18 [30/148]	loss: 0.002072
# Train Epoch: 18 [40/148]	loss: 0.001020
# Train Epoch: 18 [50/148]	loss: 0.001782
# Train Epoch: 18 [60/148]	loss: 0.002652
# Train Epoch: 18 [70/148]	loss: 0.001206
# Train Epoch: 18 [80/148]	loss: 0.001376
# Train Epoch: 18 [90/148]	loss: 0.001560
# Train Epoch: 18 [100/148]	loss: 0.001243
# Train Epoch: 18 [110/148]	loss: 0.001569
# Train Epoch: 18 [120/148]	loss: 0.002159
# Train Epoch: 18 [130/148]	loss: 0.001328
# Train Epoch: 18 [140/148]	loss: 0.001104
# [18]Validation Loss: 0.3020,Accuracy: 91.8919%
# Train Epoch: 19 [0/148]	loss: 0.002299
# Train Epoch: 19 [10/148]	loss: 0.001520
# Train Epoch: 19 [20/148]	loss: 0.001294
# Train Epoch: 19 [30/148]	loss: 0.005650
# Train Epoch: 19 [40/148]	loss: 0.001006
# Train Epoch: 19 [50/148]	loss: 0.001387
# Train Epoch: 19 [60/148]	loss: 0.001521
# Train Epoch: 19 [70/148]	loss: 0.002344
# Train Epoch: 19 [80/148]	loss: 0.000697
# Train Epoch: 19 [90/148]	loss: 0.001152
# Train Epoch: 19 [100/148]	loss: 0.000846
# Train Epoch: 19 [110/148]	loss: 0.001585
# Train Epoch: 19 [120/148]	loss: 0.001686
# Train Epoch: 19 [130/148]	loss: 0.005224
# Train Epoch: 19 [140/148]	loss: 0.002067
# [19]Validation Loss: 0.2963,Accuracy: 91.8919%
# Train Epoch: 20 [0/148]	loss: 0.001422
# Train Epoch: 20 [10/148]	loss: 0.001724
# Train Epoch: 20 [20/148]	loss: 0.001458
# Train Epoch: 20 [30/148]	loss: 0.001104
# Train Epoch: 20 [40/148]	loss: 0.002545
# Train Epoch: 20 [50/148]	loss: 0.001211
# Train Epoch: 20 [60/148]	loss: 0.001717
# Train Epoch: 20 [70/148]	loss: 0.001359
# Train Epoch: 20 [80/148]	loss: 0.001349
# Train Epoch: 20 [90/148]	loss: 0.001107
# Train Epoch: 20 [100/148]	loss: 0.002318
# Train Epoch: 20 [110/148]	loss: 0.001630
# Train Epoch: 20 [120/148]	loss: 0.001289
# Train Epoch: 20 [130/148]	loss: 0.001499
# Train Epoch: 20 [140/148]	loss: 0.005257
# [20]Validation Loss: 0.3022,Accuracy: 91.8919%
# Train Epoch: 21 [0/148]	loss: 0.001722
# Train Epoch: 21 [10/148]	loss: 0.001462
# Train Epoch: 21 [20/148]	loss: 0.001102
# Train Epoch: 21 [30/148]	loss: 0.001210
# Train Epoch: 21 [40/148]	loss: 0.001755
# Train Epoch: 21 [50/148]	loss: 0.002032
# Train Epoch: 21 [60/148]	loss: 0.000850
# Train Epoch: 21 [70/148]	loss: 0.001640
# Train Epoch: 21 [80/148]	loss: 0.001456
# Train Epoch: 21 [90/148]	loss: 0.000800
# Train Epoch: 21 [100/148]	loss: 0.001554
# Train Epoch: 21 [110/148]	loss: 0.008912
# Train Epoch: 21 [120/148]	loss: 0.002029
# Train Epoch: 21 [130/148]	loss: 0.001384
# Train Epoch: 21 [140/148]	loss: 0.002084
# [21]Validation Loss: 0.2951,Accuracy: 92.2297%
# Train Epoch: 22 [0/148]	loss: 0.001706
# Train Epoch: 22 [10/148]	loss: 0.001383
# Train Epoch: 22 [20/148]	loss: 0.001607
# Train Epoch: 22 [30/148]	loss: 0.002266
# Train Epoch: 22 [40/148]	loss: 0.001057
# Train Epoch: 22 [50/148]	loss: 0.000986
# Train Epoch: 22 [60/148]	loss: 0.001613
# Train Epoch: 22 [70/148]	loss: 0.001394
# Train Epoch: 22 [80/148]	loss: 0.001820
# Train Epoch: 22 [90/148]	loss: 0.002958
# Train Epoch: 22 [100/148]	loss: 0.002379
# Train Epoch: 22 [110/148]	loss: 0.002506
# Train Epoch: 22 [120/148]	loss: 0.001005
# Train Epoch: 22 [130/148]	loss: 0.005151
# Train Epoch: 22 [140/148]	loss: 0.001445
# [22]Validation Loss: 0.2981,Accuracy: 91.5541%
# Train Epoch: 23 [0/148]	loss: 0.001043
# Train Epoch: 23 [10/148]	loss: 0.001048
# Train Epoch: 23 [20/148]	loss: 0.001641
# Train Epoch: 23 [30/148]	loss: 0.002380
# Train Epoch: 23 [40/148]	loss: 0.001379
# Train Epoch: 23 [50/148]	loss: 0.000890
# Train Epoch: 23 [60/148]	loss: 0.001462
# Train Epoch: 23 [70/148]	loss: 0.001749
# Train Epoch: 23 [80/148]	loss: 0.001258
# Train Epoch: 23 [90/148]	loss: 0.001803
# Train Epoch: 23 [100/148]	loss: 0.002920
# Train Epoch: 23 [110/148]	loss: 0.001163
# Train Epoch: 23 [120/148]	loss: 0.001566
# Train Epoch: 23 [130/148]	loss: 0.001370
# Train Epoch: 23 [140/148]	loss: 0.000751
# [23]Validation Loss: 0.3023,Accuracy: 91.8919%
# Train Epoch: 24 [0/148]	loss: 0.001617
# Train Epoch: 24 [10/148]	loss: 0.001775
# Train Epoch: 24 [20/148]	loss: 0.001250
# Train Epoch: 24 [30/148]	loss: 0.000989
# Train Epoch: 24 [40/148]	loss: 0.000998
# Train Epoch: 24 [50/148]	loss: 0.000829
# Train Epoch: 24 [60/148]	loss: 0.000791
# Train Epoch: 24 [70/148]	loss: 0.003017
# Train Epoch: 24 [80/148]	loss: 0.001457
# Train Epoch: 24 [90/148]	loss: 0.000766
# Train Epoch: 24 [100/148]	loss: 0.000829
# Train Epoch: 24 [110/148]	loss: 0.001778
# Train Epoch: 24 [120/148]	loss: 0.000650
# Train Epoch: 24 [130/148]	loss: 0.001125
# Train Epoch: 24 [140/148]	loss: 0.000749
# [24]Validation Loss: 0.3054,Accuracy: 91.8919%
# Train Epoch: 25 [0/148]	loss: 0.001238
# Train Epoch: 25 [10/148]	loss: 0.003966
# Train Epoch: 25 [20/148]	loss: 0.000891
# Train Epoch: 25 [30/148]	loss: 0.000620
# Train Epoch: 25 [40/148]	loss: 0.000683
# Train Epoch: 25 [50/148]	loss: 0.002417
# Train Epoch: 25 [60/148]	loss: 0.000745
# Train Epoch: 25 [70/148]	loss: 0.000545
# Train Epoch: 25 [80/148]	loss: 0.000658
# Train Epoch: 25 [90/148]	loss: 0.000813
# Train Epoch: 25 [100/148]	loss: 0.001488
# Train Epoch: 25 [110/148]	loss: 0.001539
# Train Epoch: 25 [120/148]	loss: 0.003495
# Train Epoch: 25 [130/148]	loss: 0.000812
# Train Epoch: 25 [140/148]	loss: 0.001862
# [25]Validation Loss: 0.3029,Accuracy: 92.2297%
# Train Epoch: 26 [0/148]	loss: 0.001344
# Train Epoch: 26 [10/148]	loss: 0.001145
# Train Epoch: 26 [20/148]	loss: 0.000607
# Train Epoch: 26 [30/148]	loss: 0.000974
# Train Epoch: 26 [40/148]	loss: 0.000754
# Train Epoch: 26 [50/148]	loss: 0.001485
# Train Epoch: 26 [60/148]	loss: 0.000838
# Train Epoch: 26 [70/148]	loss: 0.000689
# Train Epoch: 26 [80/148]	loss: 0.001438
# Train Epoch: 26 [90/148]	loss: 0.001892
# Train Epoch: 26 [100/148]	loss: 0.000817
# Train Epoch: 26 [110/148]	loss: 0.000881
# Train Epoch: 26 [120/148]	loss: 0.001261
# Train Epoch: 26 [130/148]	loss: 0.004636
# Train Epoch: 26 [140/148]	loss: 0.000571
# [26]Validation Loss: 0.3125,Accuracy: 91.8919%
# Train Epoch: 27 [0/148]	loss: 0.000854
# Train Epoch: 27 [10/148]	loss: 0.001244
# Train Epoch: 27 [20/148]	loss: 0.000878
# Train Epoch: 27 [30/148]	loss: 0.001328
# Train Epoch: 27 [40/148]	loss: 0.000673
# Train Epoch: 27 [50/148]	loss: 0.000804
# Train Epoch: 27 [60/148]	loss: 0.000834
# Train Epoch: 27 [70/148]	loss: 0.001528
# Train Epoch: 27 [80/148]	loss: 0.002403
# Train Epoch: 27 [90/148]	loss: 0.001839
# Train Epoch: 27 [100/148]	loss: 0.001808
# Train Epoch: 27 [110/148]	loss: 0.002621
# Train Epoch: 27 [120/148]	loss: 0.002046
# Train Epoch: 27 [130/148]	loss: 0.000986
# Train Epoch: 27 [140/148]	loss: 0.000708
# [27]Validation Loss: 0.3100,Accuracy: 91.2162%
# Train Epoch: 28 [0/148]	loss: 0.000660
# Train Epoch: 28 [10/148]	loss: 0.000677
# Train Epoch: 28 [20/148]	loss: 0.001264
# Train Epoch: 28 [30/148]	loss: 0.000931
# Train Epoch: 28 [40/148]	loss: 0.000981
# Train Epoch: 28 [50/148]	loss: 0.001297
# Train Epoch: 28 [60/148]	loss: 0.000730
# Train Epoch: 28 [70/148]	loss: 0.001079
# Train Epoch: 28 [80/148]	loss: 0.001343
# Train Epoch: 28 [90/148]	loss: 0.002246
# Train Epoch: 28 [100/148]	loss: 0.001570
# Train Epoch: 28 [110/148]	loss: 0.001073
# Train Epoch: 28 [120/148]	loss: 0.000835
# Train Epoch: 28 [130/148]	loss: 0.000827
# Train Epoch: 28 [140/148]	loss: 0.000713
# [28]Validation Loss: 0.3107,Accuracy: 91.2162%
# Train Epoch: 29 [0/148]	loss: 0.000875
# Train Epoch: 29 [10/148]	loss: 0.001016
# Train Epoch: 29 [20/148]	loss: 0.001466
# Train Epoch: 29 [30/148]	loss: 0.000858
# Train Epoch: 29 [40/148]	loss: 0.000705
# Train Epoch: 29 [50/148]	loss: 0.001036
# Train Epoch: 29 [60/148]	loss: 0.001162
# Train Epoch: 29 [70/148]	loss: 0.000637
# Train Epoch: 29 [80/148]	loss: 0.000881
# Train Epoch: 29 [90/148]	loss: 0.002304
# Train Epoch: 29 [100/148]	loss: 0.000842
# Train Epoch: 29 [110/148]	loss: 0.001251
# Train Epoch: 29 [120/148]	loss: 0.001200
# Train Epoch: 29 [130/148]	loss: 0.001178
# Train Epoch: 29 [140/148]	loss: 0.000882
# [29]Validation Loss: 0.3010,Accuracy: 91.8919%
# [FINAL] Test Loss: 0.3387,Accuracy: 90.6040%
# Best Accuracy:  92.22972972972973
# Elasped Time: 1h, 67m, 18s
# time: 1h, 67m, 18s

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

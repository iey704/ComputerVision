# %% [markdown]
# <a href="https://colab.research.google.com/github/iey704/ComputerVision/blob/main/CV_AL2_EfficientNet(2)_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   AdamP optimizer 사용
# *   Label Smoothing =0.15
# *   EfficientNet2 모델 사용
# *  Batch = 8
# * lr = 0.0001

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=92505c8496addd234923b647d6e3eee1aea14eed20d477f314732e8944844ae1
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=736ab03e99718fccb13f1d292055634406bb4d37127840034fc43e047549946d
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageEnhance

from efficientnet_pytorch import EfficientNet

from torch.utils.data import ConcatDataset
from collections import Counter

from adamp import AdamP

import numpy as np

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/Colab Notebooks/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = torch.hub.load('hankyul2/EfficientNetV2-pytorch', 'efficientnet_v2_s', pretrained=True, nclass=50)
print(model)

'''
# 가중치 규제 추가
weight_decay = 0.001
l1_loss = nn.L1Loss()
l2_loss = nn.MSELoss()

def weight_regularizer(model):
  l1_reg = 0.
  l2_reg = 0.
  for param in model.parameters():
    l1_reg += l1_loss(param, torch.zeros_like(param))
    l2_reg += l2_loss(param, torch.zeros_like(param))
  return l1_reg * weight_decay + l2_reg * weight_decay
  '''

### Tranfer Learning ###
model.to(DEVICE)

optimizer = AdamP(model.parameters(), lr=lr) #, weight_decay=weight_regularizer(model))

print("Created a learning model and optimizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/hankyul2/EfficientNetV2-pytorch/zipball/main" to /root/.cache/torch/hub/main.zip
# EfficientNetV2(
#   (stem): ConvBNAct(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU()
#   )
#   (blocks): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (4): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (5): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (6): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (7): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (8): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (9): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (10): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (11): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (12): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (13): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (14): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (15): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (16): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (17): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (18): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (19): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (20): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (21): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (22): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (23): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (24): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (25): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (26): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (27): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (28): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (29): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (30): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (31): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (32): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (33): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (34): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (35): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (36): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (37): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (38): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (39): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#   )
#   (head): Sequential(
#     (bottleneck): ConvBNAct(
#       (0): Conv2d(256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU()
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (dropout): Dropout(p=0.1, inplace=True)
#     (classifier): Linear(in_features=1280, out_features=50, bias=True)
#   )
# )
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  criterion = nn.CrossEntropyLoss(label_smoothing=0.15)
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    train_loss = criterion(output,target)
    #train_loss = criterion(output,target)+weight_regularizer(model)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

# 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/590]	loss: 3.911173
# Train Epoch: 0 [10/590]	loss: 3.884250
# Train Epoch: 0 [20/590]	loss: 3.917105
# Train Epoch: 0 [30/590]	loss: 3.835802
# Train Epoch: 0 [40/590]	loss: 3.827281
# Train Epoch: 0 [50/590]	loss: 3.826489
# Train Epoch: 0 [60/590]	loss: 3.806169
# Train Epoch: 0 [70/590]	loss: 3.715011
# Train Epoch: 0 [80/590]	loss: 3.678702
# Train Epoch: 0 [90/590]	loss: 3.695238
# Train Epoch: 0 [100/590]	loss: 3.615648
# Train Epoch: 0 [110/590]	loss: 3.672032
# Train Epoch: 0 [120/590]	loss: 3.618501
# Train Epoch: 0 [130/590]	loss: 3.643029
# Train Epoch: 0 [140/590]	loss: 3.448147
# Train Epoch: 0 [150/590]	loss: 3.281641
# Train Epoch: 0 [160/590]	loss: 3.362841
# Train Epoch: 0 [170/590]	loss: 3.159698
# Train Epoch: 0 [180/590]	loss: 3.334679
# Train Epoch: 0 [190/590]	loss: 3.513720
# Train Epoch: 0 [200/590]	loss: 3.269033
# Train Epoch: 0 [210/590]	loss: 3.248815
# Train Epoch: 0 [220/590]	loss: 2.988522
# Train Epoch: 0 [230/590]	loss: 3.017218
# Train Epoch: 0 [240/590]	loss: 2.987416
# Train Epoch: 0 [250/590]	loss: 3.129225
# Train Epoch: 0 [260/590]	loss: 3.240874
# Train Epoch: 0 [270/590]	loss: 3.111411
# Train Epoch: 0 [280/590]	loss: 2.672131
# Train Epoch: 0 [290/590]	loss: 2.852433
# Train Epoch: 0 [300/590]	loss: 2.584736
# Train Epoch: 0 [310/590]	loss: 2.593669
# Train Epoch: 0 [320/590]	loss: 2.591121
# Train Epoch: 0 [330/590]	loss: 2.312455
# Train Epoch: 0 [340/590]	loss: 2.754632
# Train Epoch: 0 [350/590]	loss: 2.400855
# Train Epoch: 0 [360/590]	loss: 2.676524
# Train Epoch: 0 [370/590]	loss: 2.256100
# Train Epoch: 0 [380/590]	loss: 2.552239
# Train Epoch: 0 [390/590]	loss: 2.637449
# Train Epoch: 0 [400/590]	loss: 2.269029
# Train Epoch: 0 [410/590]	loss: 2.795797
# Train Epoch: 0 [420/590]	loss: 2.213752
# Train Epoch: 0 [430/590]	loss: 2.215250
# Train Epoch: 0 [440/590]	loss: 2.255232
# Train Epoch: 0 [450/590]	loss: 2.316609
# Train Epoch: 0 [460/590]	loss: 2.420522
# Train Epoch: 0 [470/590]	loss: 2.047807
# Train Epoch: 0 [480/590]	loss: 1.844217
# Train Epoch: 0 [490/590]	loss: 1.831167
# Train Epoch: 0 [500/590]	loss: 2.082144
# Train Epoch: 0 [510/590]	loss: 2.354183
# Train Epoch: 0 [520/590]	loss: 1.880920
# Train Epoch: 0 [530/590]	loss: 1.944250
# Train Epoch: 0 [540/590]	loss: 1.980246
# Train Epoch: 0 [550/590]	loss: 2.094218
# Train Epoch: 0 [560/590]	loss: 2.063169
# Train Epoch: 0 [570/590]	loss: 1.904109
# Train Epoch: 0 [580/590]	loss: 1.816416
# [0]Validation Loss: 0.7884,Accuracy: 85.8108%
# Train Epoch: 1 [0/590]	loss: 2.170583
# Train Epoch: 1 [10/590]	loss: 2.148180
# Train Epoch: 1 [20/590]	loss: 2.082699
# Train Epoch: 1 [30/590]	loss: 1.637627
# Train Epoch: 1 [40/590]	loss: 1.579567
# Train Epoch: 1 [50/590]	loss: 1.889311
# Train Epoch: 1 [60/590]	loss: 1.657900
# Train Epoch: 1 [70/590]	loss: 2.314042
# Train Epoch: 1 [80/590]	loss: 1.557244
# Train Epoch: 1 [90/590]	loss: 1.802009
# Train Epoch: 1 [100/590]	loss: 2.072480
# Train Epoch: 1 [110/590]	loss: 1.603200
# Train Epoch: 1 [120/590]	loss: 1.637889
# Train Epoch: 1 [130/590]	loss: 1.555224
# Train Epoch: 1 [140/590]	loss: 2.000062
# Train Epoch: 1 [150/590]	loss: 1.703137
# Train Epoch: 1 [160/590]	loss: 1.987680
# Train Epoch: 1 [170/590]	loss: 1.600703
# Train Epoch: 1 [180/590]	loss: 1.317078
# Train Epoch: 1 [190/590]	loss: 1.453376
# Train Epoch: 1 [200/590]	loss: 1.715854
# Train Epoch: 1 [210/590]	loss: 1.355661
# Train Epoch: 1 [220/590]	loss: 1.445733
# Train Epoch: 1 [230/590]	loss: 1.672060
# Train Epoch: 1 [240/590]	loss: 1.673856
# Train Epoch: 1 [250/590]	loss: 1.404789
# Train Epoch: 1 [260/590]	loss: 1.514413
# Train Epoch: 1 [270/590]	loss: 1.497690
# Train Epoch: 1 [280/590]	loss: 1.424362
# Train Epoch: 1 [290/590]	loss: 1.141330
# Train Epoch: 1 [300/590]	loss: 1.299134
# Train Epoch: 1 [310/590]	loss: 1.873703
# Train Epoch: 1 [320/590]	loss: 1.515105
# Train Epoch: 1 [330/590]	loss: 1.365731
# Train Epoch: 1 [340/590]	loss: 1.999466
# Train Epoch: 1 [350/590]	loss: 1.349028
# Train Epoch: 1 [360/590]	loss: 1.528030
# Train Epoch: 1 [370/590]	loss: 1.499833
# Train Epoch: 1 [380/590]	loss: 1.404918
# Train Epoch: 1 [390/590]	loss: 2.054935
# Train Epoch: 1 [400/590]	loss: 1.154472
# Train Epoch: 1 [410/590]	loss: 1.611121
# Train Epoch: 1 [420/590]	loss: 1.354263
# Train Epoch: 1 [430/590]	loss: 1.511376
# Train Epoch: 1 [440/590]	loss: 1.176710
# Train Epoch: 1 [450/590]	loss: 1.633117
# Train Epoch: 1 [460/590]	loss: 1.191881
# Train Epoch: 1 [470/590]	loss: 1.532657
# Train Epoch: 1 [480/590]	loss: 1.387156
# Train Epoch: 1 [490/590]	loss: 1.607114
# Train Epoch: 1 [500/590]	loss: 1.300138
# Train Epoch: 1 [510/590]	loss: 1.413464
# Train Epoch: 1 [520/590]	loss: 1.389529
# Train Epoch: 1 [530/590]	loss: 1.599465
# Train Epoch: 1 [540/590]	loss: 1.428356
# Train Epoch: 1 [550/590]	loss: 1.478558
# Train Epoch: 1 [560/590]	loss: 1.329886
# Train Epoch: 1 [570/590]	loss: 1.504508
# Train Epoch: 1 [580/590]	loss: 1.154526
# [1]Validation Loss: 0.3531,Accuracy: 93.5811%
# Train Epoch: 2 [0/590]	loss: 1.720393
# Train Epoch: 2 [10/590]	loss: 1.470995
# Train Epoch: 2 [20/590]	loss: 1.248581
# Train Epoch: 2 [30/590]	loss: 1.202914
# Train Epoch: 2 [40/590]	loss: 1.161059
# Train Epoch: 2 [50/590]	loss: 1.297245
# Train Epoch: 2 [60/590]	loss: 1.639897
# Train Epoch: 2 [70/590]	loss: 1.459459
# Train Epoch: 2 [80/590]	loss: 1.357797
# Train Epoch: 2 [90/590]	loss: 1.582524
# Train Epoch: 2 [100/590]	loss: 1.357000
# Train Epoch: 2 [110/590]	loss: 1.162580
# Train Epoch: 2 [120/590]	loss: 1.454982
# Train Epoch: 2 [130/590]	loss: 1.212040
# Train Epoch: 2 [140/590]	loss: 1.279656
# Train Epoch: 2 [150/590]	loss: 1.352180
# Train Epoch: 2 [160/590]	loss: 1.229445
# Train Epoch: 2 [170/590]	loss: 1.646778
# Train Epoch: 2 [180/590]	loss: 1.124928
# Train Epoch: 2 [190/590]	loss: 1.280962
# Train Epoch: 2 [200/590]	loss: 1.514500
# Train Epoch: 2 [210/590]	loss: 1.125096
# Train Epoch: 2 [220/590]	loss: 1.270001
# Train Epoch: 2 [230/590]	loss: 1.216409
# Train Epoch: 2 [240/590]	loss: 1.416601
# Train Epoch: 2 [250/590]	loss: 1.121185
# Train Epoch: 2 [260/590]	loss: 1.112667
# Train Epoch: 2 [270/590]	loss: 1.259816
# Train Epoch: 2 [280/590]	loss: 1.211953
# Train Epoch: 2 [290/590]	loss: 1.239456
# Train Epoch: 2 [300/590]	loss: 1.208328
# Train Epoch: 2 [310/590]	loss: 1.442862
# Train Epoch: 2 [320/590]	loss: 1.109029
# Train Epoch: 2 [330/590]	loss: 1.148123
# Train Epoch: 2 [340/590]	loss: 1.191434
# Train Epoch: 2 [350/590]	loss: 1.535866
# Train Epoch: 2 [360/590]	loss: 1.138303
# Train Epoch: 2 [370/590]	loss: 1.104895
# Train Epoch: 2 [380/590]	loss: 1.928824
# Train Epoch: 2 [390/590]	loss: 1.452387
# Train Epoch: 2 [400/590]	loss: 1.228040
# Train Epoch: 2 [410/590]	loss: 1.453402
# Train Epoch: 2 [420/590]	loss: 1.345146
# Train Epoch: 2 [430/590]	loss: 1.570164
# Train Epoch: 2 [440/590]	loss: 1.113236
# Train Epoch: 2 [450/590]	loss: 1.216404
# Train Epoch: 2 [460/590]	loss: 1.244781
# Train Epoch: 2 [470/590]	loss: 1.249494
# Train Epoch: 2 [480/590]	loss: 1.119891
# Train Epoch: 2 [490/590]	loss: 1.417157
# Train Epoch: 2 [500/590]	loss: 1.247826
# Train Epoch: 2 [510/590]	loss: 1.221053
# Train Epoch: 2 [520/590]	loss: 1.339635
# Train Epoch: 2 [530/590]	loss: 1.129564
# Train Epoch: 2 [540/590]	loss: 1.207910
# Train Epoch: 2 [550/590]	loss: 1.076206
# Train Epoch: 2 [560/590]	loss: 1.262883
# Train Epoch: 2 [570/590]	loss: 1.178884
# Train Epoch: 2 [580/590]	loss: 1.426608
# [2]Validation Loss: 0.3027,Accuracy: 95.6081%
# Train Epoch: 3 [0/590]	loss: 1.490667
# Train Epoch: 3 [10/590]	loss: 1.202520
# Train Epoch: 3 [20/590]	loss: 1.228680
# Train Epoch: 3 [30/590]	loss: 1.240888
# Train Epoch: 3 [40/590]	loss: 1.315754
# Train Epoch: 3 [50/590]	loss: 1.394500
# Train Epoch: 3 [60/590]	loss: 1.182066
# Train Epoch: 3 [70/590]	loss: 1.227342
# Train Epoch: 3 [80/590]	loss: 1.354890
# Train Epoch: 3 [90/590]	loss: 1.223676
# Train Epoch: 3 [100/590]	loss: 1.401095
# Train Epoch: 3 [110/590]	loss: 1.318407
# Train Epoch: 3 [120/590]	loss: 1.217686
# Train Epoch: 3 [130/590]	loss: 1.079736
# Train Epoch: 3 [140/590]	loss: 1.136397
# Train Epoch: 3 [150/590]	loss: 1.649433
# Train Epoch: 3 [160/590]	loss: 1.089813
# Train Epoch: 3 [170/590]	loss: 1.087029
# Train Epoch: 3 [180/590]	loss: 1.066054
# Train Epoch: 3 [190/590]	loss: 1.290202
# Train Epoch: 3 [200/590]	loss: 1.107876
# Train Epoch: 3 [210/590]	loss: 1.133180
# Train Epoch: 3 [220/590]	loss: 1.145474
# Train Epoch: 3 [230/590]	loss: 1.214110
# Train Epoch: 3 [240/590]	loss: 1.102376
# Train Epoch: 3 [250/590]	loss: 1.081345
# Train Epoch: 3 [260/590]	loss: 1.275615
# Train Epoch: 3 [270/590]	loss: 1.123269
# Train Epoch: 3 [280/590]	loss: 1.117885
# Train Epoch: 3 [290/590]	loss: 1.136038
# Train Epoch: 3 [300/590]	loss: 1.157568
# Train Epoch: 3 [310/590]	loss: 1.319593
# Train Epoch: 3 [320/590]	loss: 1.114027
# Train Epoch: 3 [330/590]	loss: 1.341469
# Train Epoch: 3 [340/590]	loss: 1.252004
# Train Epoch: 3 [350/590]	loss: 1.400528
# Train Epoch: 3 [360/590]	loss: 1.449610
# Train Epoch: 3 [370/590]	loss: 1.088294
# Train Epoch: 3 [380/590]	loss: 1.136568
# Train Epoch: 3 [390/590]	loss: 1.123902
# Train Epoch: 3 [400/590]	loss: 1.404345
# Train Epoch: 3 [410/590]	loss: 1.285110
# Train Epoch: 3 [420/590]	loss: 1.092660
# Train Epoch: 3 [430/590]	loss: 1.223337
# Train Epoch: 3 [440/590]	loss: 1.112047
# Train Epoch: 3 [450/590]	loss: 1.159119
# Train Epoch: 3 [460/590]	loss: 1.258760
# Train Epoch: 3 [470/590]	loss: 1.288786
# Train Epoch: 3 [480/590]	loss: 1.321468
# Train Epoch: 3 [490/590]	loss: 1.104424
# Train Epoch: 3 [500/590]	loss: 1.590082
# Train Epoch: 3 [510/590]	loss: 1.072876
# Train Epoch: 3 [520/590]	loss: 1.077586
# Train Epoch: 3 [530/590]	loss: 1.192989
# Train Epoch: 3 [540/590]	loss: 1.728687
# Train Epoch: 3 [550/590]	loss: 1.129301
# Train Epoch: 3 [560/590]	loss: 1.164828
# Train Epoch: 3 [570/590]	loss: 1.255858
# Train Epoch: 3 [580/590]	loss: 1.107057
# [3]Validation Loss: 0.3152,Accuracy: 93.2432%
# Train Epoch: 4 [0/590]	loss: 1.268501
# Train Epoch: 4 [10/590]	loss: 1.049057
# Train Epoch: 4 [20/590]	loss: 1.197620
# Train Epoch: 4 [30/590]	loss: 1.092602
# Train Epoch: 4 [40/590]	loss: 1.135123
# Train Epoch: 4 [50/590]	loss: 1.043743
# Train Epoch: 4 [60/590]	loss: 1.160728
# Train Epoch: 4 [70/590]	loss: 1.052666
# Train Epoch: 4 [80/590]	loss: 1.083008
# Train Epoch: 4 [90/590]	loss: 1.214599
# Train Epoch: 4 [100/590]	loss: 1.211529
# Train Epoch: 4 [110/590]	loss: 1.065759
# Train Epoch: 4 [120/590]	loss: 1.055224
# Train Epoch: 4 [130/590]	loss: 1.087613
# Train Epoch: 4 [140/590]	loss: 1.154752
# Train Epoch: 4 [150/590]	loss: 1.151821
# Train Epoch: 4 [160/590]	loss: 1.092867
# Train Epoch: 4 [170/590]	loss: 1.260106
# Train Epoch: 4 [180/590]	loss: 1.116878
# Train Epoch: 4 [190/590]	loss: 1.407234
# Train Epoch: 4 [200/590]	loss: 1.070653
# Train Epoch: 4 [210/590]	loss: 1.116539
# Train Epoch: 4 [220/590]	loss: 1.292552
# Train Epoch: 4 [230/590]	loss: 1.073684
# Train Epoch: 4 [240/590]	loss: 1.046644
# Train Epoch: 4 [250/590]	loss: 1.069749
# Train Epoch: 4 [260/590]	loss: 1.218668
# Train Epoch: 4 [270/590]	loss: 1.195706
# Train Epoch: 4 [280/590]	loss: 1.114146
# Train Epoch: 4 [290/590]	loss: 1.075731
# Train Epoch: 4 [300/590]	loss: 1.051477
# Train Epoch: 4 [310/590]	loss: 1.170558
# Train Epoch: 4 [320/590]	loss: 1.076356
# Train Epoch: 4 [330/590]	loss: 1.280305
# Train Epoch: 4 [340/590]	loss: 1.293375
# Train Epoch: 4 [350/590]	loss: 1.049126
# Train Epoch: 4 [360/590]	loss: 1.144193
# Train Epoch: 4 [370/590]	loss: 1.067335
# Train Epoch: 4 [380/590]	loss: 1.049907
# Train Epoch: 4 [390/590]	loss: 1.121233
# Train Epoch: 4 [400/590]	loss: 1.366572
# Train Epoch: 4 [410/590]	loss: 1.184766
# Train Epoch: 4 [420/590]	loss: 1.136803
# Train Epoch: 4 [430/590]	loss: 1.119658
# Train Epoch: 4 [440/590]	loss: 1.430432
# Train Epoch: 4 [450/590]	loss: 1.241065
# Train Epoch: 4 [460/590]	loss: 1.410357
# Train Epoch: 4 [470/590]	loss: 1.048564
# Train Epoch: 4 [480/590]	loss: 1.128945
# Train Epoch: 4 [490/590]	loss: 1.100260
# Train Epoch: 4 [500/590]	loss: 1.054178
# Train Epoch: 4 [510/590]	loss: 1.053756
# Train Epoch: 4 [520/590]	loss: 1.790951
# Train Epoch: 4 [530/590]	loss: 1.276166
# Train Epoch: 4 [540/590]	loss: 1.061706
# Train Epoch: 4 [550/590]	loss: 1.069483
# Train Epoch: 4 [560/590]	loss: 1.255559
# Train Epoch: 4 [570/590]	loss: 1.108634
# Train Epoch: 4 [580/590]	loss: 1.052582
# [4]Validation Loss: 0.2991,Accuracy: 92.5676%
# Train Epoch: 5 [0/590]	loss: 1.147041
# Train Epoch: 5 [10/590]	loss: 1.178679
# Train Epoch: 5 [20/590]	loss: 1.046915
# Train Epoch: 5 [30/590]	loss: 1.449492
# Train Epoch: 5 [40/590]	loss: 1.180891
# Train Epoch: 5 [50/590]	loss: 1.360096
# Train Epoch: 5 [60/590]	loss: 1.307042
# Train Epoch: 5 [70/590]	loss: 1.031198
# Train Epoch: 5 [80/590]	loss: 1.413969
# Train Epoch: 5 [90/590]	loss: 1.494677
# Train Epoch: 5 [100/590]	loss: 1.078448
# Train Epoch: 5 [110/590]	loss: 1.041380
# Train Epoch: 5 [120/590]	loss: 1.060464
# Train Epoch: 5 [130/590]	loss: 1.123182
# Train Epoch: 5 [140/590]	loss: 1.053260
# Train Epoch: 5 [150/590]	loss: 1.166510
# Train Epoch: 5 [160/590]	loss: 1.163843
# Train Epoch: 5 [170/590]	loss: 1.209835
# Train Epoch: 5 [180/590]	loss: 1.048623
# Train Epoch: 5 [190/590]	loss: 1.058249
# Train Epoch: 5 [200/590]	loss: 1.032864
# Train Epoch: 5 [210/590]	loss: 1.084647
# Train Epoch: 5 [220/590]	loss: 1.052886
# Train Epoch: 5 [230/590]	loss: 1.037624
# Train Epoch: 5 [240/590]	loss: 1.081076
# Train Epoch: 5 [250/590]	loss: 1.224749
# Train Epoch: 5 [260/590]	loss: 1.043962
# Train Epoch: 5 [270/590]	loss: 1.118566
# Train Epoch: 5 [280/590]	loss: 1.085860
# Train Epoch: 5 [290/590]	loss: 1.164261
# Train Epoch: 5 [300/590]	loss: 1.249997
# Train Epoch: 5 [310/590]	loss: 1.183613
# Train Epoch: 5 [320/590]	loss: 1.108779
# Train Epoch: 5 [330/590]	loss: 1.039935
# Train Epoch: 5 [340/590]	loss: 1.258935
# Train Epoch: 5 [350/590]	loss: 1.071723
# Train Epoch: 5 [360/590]	loss: 1.037837
# Train Epoch: 5 [370/590]	loss: 1.048225
# Train Epoch: 5 [380/590]	loss: 1.062948
# Train Epoch: 5 [390/590]	loss: 1.045819
# Train Epoch: 5 [400/590]	loss: 1.038006
# Train Epoch: 5 [410/590]	loss: 1.061046
# Train Epoch: 5 [420/590]	loss: 1.072627
# Train Epoch: 5 [430/590]	loss: 1.099627
# Train Epoch: 5 [440/590]	loss: 1.372878
# Train Epoch: 5 [450/590]	loss: 1.052311
# Train Epoch: 5 [460/590]	loss: 1.039424
# Train Epoch: 5 [470/590]	loss: 1.068172
# Train Epoch: 5 [480/590]	loss: 1.428823
# Train Epoch: 5 [490/590]	loss: 1.186903
# Train Epoch: 5 [500/590]	loss: 1.250021
# Train Epoch: 5 [510/590]	loss: 1.090286
# Train Epoch: 5 [520/590]	loss: 1.154602
# Train Epoch: 5 [530/590]	loss: 1.198365
# Train Epoch: 5 [540/590]	loss: 1.103772
# Train Epoch: 5 [550/590]	loss: 1.065520
# Train Epoch: 5 [560/590]	loss: 1.586447
# Train Epoch: 5 [570/590]	loss: 1.071217
# Train Epoch: 5 [580/590]	loss: 1.036516
# [5]Validation Loss: 0.2969,Accuracy: 93.9189%
# Train Epoch: 6 [0/590]	loss: 1.219429
# Train Epoch: 6 [10/590]	loss: 1.127110
# Train Epoch: 6 [20/590]	loss: 1.245709
# Train Epoch: 6 [30/590]	loss: 1.035328
# Train Epoch: 6 [40/590]	loss: 1.053079
# Train Epoch: 6 [50/590]	loss: 1.200001
# Train Epoch: 6 [60/590]	loss: 1.414753
# Train Epoch: 6 [70/590]	loss: 1.321150
# Train Epoch: 6 [80/590]	loss: 1.048680
# Train Epoch: 6 [90/590]	loss: 1.141131
# Train Epoch: 6 [100/590]	loss: 1.114222
# Train Epoch: 6 [110/590]	loss: 1.069921
# Train Epoch: 6 [120/590]	loss: 1.139700
# Train Epoch: 6 [130/590]	loss: 1.082945
# Train Epoch: 6 [140/590]	loss: 1.043495
# Train Epoch: 6 [150/590]	loss: 1.074891
# Train Epoch: 6 [160/590]	loss: 1.075143
# Train Epoch: 6 [170/590]	loss: 1.058542
# Train Epoch: 6 [180/590]	loss: 1.025136
# Train Epoch: 6 [190/590]	loss: 1.303782
# Train Epoch: 6 [200/590]	loss: 1.030719
# Train Epoch: 6 [210/590]	loss: 1.076640
# Train Epoch: 6 [220/590]	loss: 1.032607
# Train Epoch: 6 [230/590]	loss: 1.034720
# Train Epoch: 6 [240/590]	loss: 1.052874
# Train Epoch: 6 [250/590]	loss: 1.026827
# Train Epoch: 6 [260/590]	loss: 1.048412
# Train Epoch: 6 [270/590]	loss: 1.294346
# Train Epoch: 6 [280/590]	loss: 1.042020
# Train Epoch: 6 [290/590]	loss: 1.062044
# Train Epoch: 6 [300/590]	loss: 1.033843
# Train Epoch: 6 [310/590]	loss: 1.134984
# Train Epoch: 6 [320/590]	loss: 1.038213
# Train Epoch: 6 [330/590]	loss: 1.342811
# Train Epoch: 6 [340/590]	loss: 1.179375
# Train Epoch: 6 [350/590]	loss: 1.065431
# Train Epoch: 6 [360/590]	loss: 1.103810
# Train Epoch: 6 [370/590]	loss: 1.114249
# Train Epoch: 6 [380/590]	loss: 1.040964
# Train Epoch: 6 [390/590]	loss: 1.030992
# Train Epoch: 6 [400/590]	loss: 1.054725
# Train Epoch: 6 [410/590]	loss: 1.104932
# Train Epoch: 6 [420/590]	loss: 1.033670
# Train Epoch: 6 [430/590]	loss: 1.034873
# Train Epoch: 6 [440/590]	loss: 1.025372
# Train Epoch: 6 [450/590]	loss: 1.105502
# Train Epoch: 6 [460/590]	loss: 1.042971
# Train Epoch: 6 [470/590]	loss: 1.029978
# Train Epoch: 6 [480/590]	loss: 1.028427
# Train Epoch: 6 [490/590]	loss: 1.071202
# Train Epoch: 6 [500/590]	loss: 1.037420
# Train Epoch: 6 [510/590]	loss: 1.028645
# Train Epoch: 6 [520/590]	loss: 1.099015
# Train Epoch: 6 [530/590]	loss: 1.291864
# Train Epoch: 6 [540/590]	loss: 1.149575
# Train Epoch: 6 [550/590]	loss: 1.065341
# Train Epoch: 6 [560/590]	loss: 1.027210
# Train Epoch: 6 [570/590]	loss: 1.056840
# Train Epoch: 6 [580/590]	loss: 1.026779
# [6]Validation Loss: 0.2979,Accuracy: 93.5811%
# Train Epoch: 7 [0/590]	loss: 1.054253
# Train Epoch: 7 [10/590]	loss: 1.032769
# Train Epoch: 7 [20/590]	loss: 1.047828
# Train Epoch: 7 [30/590]	loss: 1.147440
# Train Epoch: 7 [40/590]	loss: 1.204749
# Train Epoch: 7 [50/590]	loss: 1.099457
# Train Epoch: 7 [60/590]	loss: 1.034440
# Train Epoch: 7 [70/590]	loss: 1.065729
# Train Epoch: 7 [80/590]	loss: 1.114500
# Train Epoch: 7 [90/590]	loss: 1.024594
# Train Epoch: 7 [100/590]	loss: 1.032949
# Train Epoch: 7 [110/590]	loss: 1.041288
# Train Epoch: 7 [120/590]	loss: 1.032565
# Train Epoch: 7 [130/590]	loss: 1.037847
# Train Epoch: 7 [140/590]	loss: 1.029789
# Train Epoch: 7 [150/590]	loss: 1.064222
# Train Epoch: 7 [160/590]	loss: 1.026473
# Train Epoch: 7 [170/590]	loss: 1.022685
# Train Epoch: 7 [180/590]	loss: 1.033231
# Train Epoch: 7 [190/590]	loss: 1.326177
# Train Epoch: 7 [200/590]	loss: 1.161489
# Train Epoch: 7 [210/590]	loss: 1.035075
# Train Epoch: 7 [220/590]	loss: 1.030239
# Train Epoch: 7 [230/590]	loss: 1.106463
# Train Epoch: 7 [240/590]	loss: 1.021577
# Train Epoch: 7 [250/590]	loss: 1.412888
# Train Epoch: 7 [260/590]	loss: 1.032869
# Train Epoch: 7 [270/590]	loss: 1.041197
# Train Epoch: 7 [280/590]	loss: 1.119032
# Train Epoch: 7 [290/590]	loss: 1.042509
# Train Epoch: 7 [300/590]	loss: 1.202954
# Train Epoch: 7 [310/590]	loss: 1.416655
# Train Epoch: 7 [320/590]	loss: 1.085968
# Train Epoch: 7 [330/590]	loss: 1.031699
# Train Epoch: 7 [340/590]	loss: 1.127427
# Train Epoch: 7 [350/590]	loss: 1.087575
# Train Epoch: 7 [360/590]	loss: 1.033966
# Train Epoch: 7 [370/590]	loss: 1.024305
# Train Epoch: 7 [380/590]	loss: 1.023701
# Train Epoch: 7 [390/590]	loss: 1.055179
# Train Epoch: 7 [400/590]	loss: 1.022151
# Train Epoch: 7 [410/590]	loss: 1.064121
# Train Epoch: 7 [420/590]	loss: 1.075781
# Train Epoch: 7 [430/590]	loss: 1.037966
# Train Epoch: 7 [440/590]	loss: 1.083526
# Train Epoch: 7 [450/590]	loss: 1.049637
# Train Epoch: 7 [460/590]	loss: 1.089404
# Train Epoch: 7 [470/590]	loss: 1.078881
# Train Epoch: 7 [480/590]	loss: 1.029389
# Train Epoch: 7 [490/590]	loss: 1.143626
# Train Epoch: 7 [500/590]	loss: 1.038168
# Train Epoch: 7 [510/590]	loss: 1.045009
# Train Epoch: 7 [520/590]	loss: 1.018224
# Train Epoch: 7 [530/590]	loss: 1.079167
# Train Epoch: 7 [540/590]	loss: 1.029420
# Train Epoch: 7 [550/590]	loss: 1.027171
# Train Epoch: 7 [560/590]	loss: 1.136876
# Train Epoch: 7 [570/590]	loss: 1.026781
# Train Epoch: 7 [580/590]	loss: 1.052959
# [7]Validation Loss: 0.2426,Accuracy: 94.5946%
# Train Epoch: 8 [0/590]	loss: 1.040262
# Train Epoch: 8 [10/590]	loss: 1.028067
# Train Epoch: 8 [20/590]	loss: 1.013041
# Train Epoch: 8 [30/590]	loss: 1.020700
# Train Epoch: 8 [40/590]	loss: 1.327879
# Train Epoch: 8 [50/590]	loss: 1.414453
# Train Epoch: 8 [60/590]	loss: 1.070953
# Train Epoch: 8 [70/590]	loss: 1.030220
# Train Epoch: 8 [80/590]	loss: 1.141277
# Train Epoch: 8 [90/590]	loss: 1.328134
# Train Epoch: 8 [100/590]	loss: 1.040526
# Train Epoch: 8 [110/590]	loss: 1.025946
# Train Epoch: 8 [120/590]	loss: 1.180866
# Train Epoch: 8 [130/590]	loss: 1.601392
# Train Epoch: 8 [140/590]	loss: 1.039069
# Train Epoch: 8 [150/590]	loss: 1.016691
# Train Epoch: 8 [160/590]	loss: 1.044888
# Train Epoch: 8 [170/590]	loss: 1.057285
# Train Epoch: 8 [180/590]	loss: 1.144879
# Train Epoch: 8 [190/590]	loss: 1.056118
# Train Epoch: 8 [200/590]	loss: 1.106614
# Train Epoch: 8 [210/590]	loss: 1.031492
# Train Epoch: 8 [220/590]	loss: 1.226152
# Train Epoch: 8 [230/590]	loss: 1.043866
# Train Epoch: 8 [240/590]	loss: 1.037838
# Train Epoch: 8 [250/590]	loss: 1.124377
# Train Epoch: 8 [260/590]	loss: 1.032600
# Train Epoch: 8 [270/590]	loss: 1.155447
# Train Epoch: 8 [280/590]	loss: 1.038441
# Train Epoch: 8 [290/590]	loss: 1.310292
# Train Epoch: 8 [300/590]	loss: 1.432777
# Train Epoch: 8 [310/590]	loss: 1.023897
# Train Epoch: 8 [320/590]	loss: 1.017626
# Train Epoch: 8 [330/590]	loss: 1.141183
# Train Epoch: 8 [340/590]	loss: 1.054391
# Train Epoch: 8 [350/590]	loss: 1.017455
# Train Epoch: 8 [360/590]	loss: 1.290220
# Train Epoch: 8 [370/590]	loss: 1.371151
# Train Epoch: 8 [380/590]	loss: 1.041404
# Train Epoch: 8 [390/590]	loss: 1.045914
# Train Epoch: 8 [400/590]	loss: 1.029419
# Train Epoch: 8 [410/590]	loss: 1.035239
# Train Epoch: 8 [420/590]	loss: 1.056057
# Train Epoch: 8 [430/590]	loss: 1.020373
# Train Epoch: 8 [440/590]	loss: 1.031256
# Train Epoch: 8 [450/590]	loss: 1.064390
# Train Epoch: 8 [460/590]	loss: 1.046008
# Train Epoch: 8 [470/590]	loss: 1.190393
# Train Epoch: 8 [480/590]	loss: 1.075198
# Train Epoch: 8 [490/590]	loss: 1.033047
# Train Epoch: 8 [500/590]	loss: 1.027516
# Train Epoch: 8 [510/590]	loss: 1.022791
# Train Epoch: 8 [520/590]	loss: 1.029123
# Train Epoch: 8 [530/590]	loss: 1.043089
# Train Epoch: 8 [540/590]	loss: 1.042315
# Train Epoch: 8 [550/590]	loss: 1.054461
# Train Epoch: 8 [560/590]	loss: 1.020972
# Train Epoch: 8 [570/590]	loss: 1.034228
# Train Epoch: 8 [580/590]	loss: 1.020798
# [8]Validation Loss: 0.2689,Accuracy: 94.9324%
# Train Epoch: 9 [0/590]	loss: 1.066764
# Train Epoch: 9 [10/590]	loss: 1.024278
# Train Epoch: 9 [20/590]	loss: 1.024049
# Train Epoch: 9 [30/590]	loss: 1.085462
# Train Epoch: 9 [40/590]	loss: 1.028669
# Train Epoch: 9 [50/590]	loss: 1.060023
# Train Epoch: 9 [60/590]	loss: 1.187680
# Train Epoch: 9 [70/590]	loss: 1.024120
# Train Epoch: 9 [80/590]	loss: 1.016390
# Train Epoch: 9 [90/590]	loss: 1.118203
# Train Epoch: 9 [100/590]	loss: 1.071099
# Train Epoch: 9 [110/590]	loss: 1.157587
# Train Epoch: 9 [120/590]	loss: 1.068306
# Train Epoch: 9 [130/590]	loss: 1.042819
# Train Epoch: 9 [140/590]	loss: 1.060367
# Train Epoch: 9 [150/590]	loss: 1.017758
# Train Epoch: 9 [160/590]	loss: 1.015890
# Train Epoch: 9 [170/590]	loss: 1.016875
# Train Epoch: 9 [180/590]	loss: 1.022265
# Train Epoch: 9 [190/590]	loss: 1.032057
# Train Epoch: 9 [200/590]	loss: 1.058396
# Train Epoch: 9 [210/590]	loss: 1.028608
# Train Epoch: 9 [220/590]	loss: 1.014158
# Train Epoch: 9 [230/590]	loss: 1.073674
# Train Epoch: 9 [240/590]	loss: 1.044512
# Train Epoch: 9 [250/590]	loss: 1.025841
# Train Epoch: 9 [260/590]	loss: 1.053770
# Train Epoch: 9 [270/590]	loss: 1.021800
# Train Epoch: 9 [280/590]	loss: 1.024902
# Train Epoch: 9 [290/590]	loss: 1.026070
# Train Epoch: 9 [300/590]	loss: 1.040198
# Train Epoch: 9 [310/590]	loss: 1.099620
# Train Epoch: 9 [320/590]	loss: 1.018010
# Train Epoch: 9 [330/590]	loss: 1.293489
# Train Epoch: 9 [340/590]	loss: 1.098467
# Train Epoch: 9 [350/590]	loss: 1.120764
# Train Epoch: 9 [360/590]	loss: 1.109864
# Train Epoch: 9 [370/590]	loss: 1.054173
# Train Epoch: 9 [380/590]	loss: 1.019860
# Train Epoch: 9 [390/590]	loss: 1.026434
# Train Epoch: 9 [400/590]	loss: 1.020383
# Train Epoch: 9 [410/590]	loss: 1.035510
# Train Epoch: 9 [420/590]	loss: 1.082919
# Train Epoch: 9 [430/590]	loss: 1.026505
# Train Epoch: 9 [440/590]	loss: 1.336165
# Train Epoch: 9 [450/590]	loss: 1.031803
# Train Epoch: 9 [460/590]	loss: 1.161260
# Train Epoch: 9 [470/590]	loss: 1.058033
# Train Epoch: 9 [480/590]	loss: 1.018436
# Train Epoch: 9 [490/590]	loss: 1.071008
# Train Epoch: 9 [500/590]	loss: 1.204230
# Train Epoch: 9 [510/590]	loss: 1.019828
# Train Epoch: 9 [520/590]	loss: 1.044920
# Train Epoch: 9 [530/590]	loss: 1.017440
# Train Epoch: 9 [540/590]	loss: 1.069790
# Train Epoch: 9 [550/590]	loss: 1.313055
# Train Epoch: 9 [560/590]	loss: 1.101636
# Train Epoch: 9 [570/590]	loss: 1.016988
# Train Epoch: 9 [580/590]	loss: 1.019608
# [9]Validation Loss: 0.3117,Accuracy: 92.9054%
# Train Epoch: 10 [0/590]	loss: 1.030602
# Train Epoch: 10 [10/590]	loss: 1.025797
# Train Epoch: 10 [20/590]	loss: 1.152823
# Train Epoch: 10 [30/590]	loss: 1.017967
# Train Epoch: 10 [40/590]	loss: 1.021821
# Train Epoch: 10 [50/590]	loss: 1.065243
# Train Epoch: 10 [60/590]	loss: 1.287449
# Train Epoch: 10 [70/590]	loss: 1.258785
# Train Epoch: 10 [80/590]	loss: 1.020518
# Train Epoch: 10 [90/590]	loss: 1.027055
# Train Epoch: 10 [100/590]	loss: 1.031785
# Train Epoch: 10 [110/590]	loss: 1.020790
# Train Epoch: 10 [120/590]	loss: 1.166646
# Train Epoch: 10 [130/590]	loss: 1.046516
# Train Epoch: 10 [140/590]	loss: 1.063498
# Train Epoch: 10 [150/590]	loss: 1.018161
# Train Epoch: 10 [160/590]	loss: 1.019425
# Train Epoch: 10 [170/590]	loss: 1.034748
# Train Epoch: 10 [180/590]	loss: 1.037919
# Train Epoch: 10 [190/590]	loss: 1.016684
# Train Epoch: 10 [200/590]	loss: 1.064995
# Train Epoch: 10 [210/590]	loss: 1.026735
# Train Epoch: 10 [220/590]	loss: 1.409653
# Train Epoch: 10 [230/590]	loss: 1.028170
# Train Epoch: 10 [240/590]	loss: 1.062036
# Train Epoch: 10 [250/590]	loss: 1.040728
# Train Epoch: 10 [260/590]	loss: 1.159000
# Train Epoch: 10 [270/590]	loss: 1.106617
# Train Epoch: 10 [280/590]	loss: 1.047739
# Train Epoch: 10 [290/590]	loss: 1.013747
# Train Epoch: 10 [300/590]	loss: 1.023522
# Train Epoch: 10 [310/590]	loss: 1.046989
# Train Epoch: 10 [320/590]	loss: 1.225561
# Train Epoch: 10 [330/590]	loss: 1.070954
# Train Epoch: 10 [340/590]	loss: 1.054106
# Train Epoch: 10 [350/590]	loss: 1.252347
# Train Epoch: 10 [360/590]	loss: 1.016738
# Train Epoch: 10 [370/590]	loss: 1.018334
# Train Epoch: 10 [380/590]	loss: 1.011320
# Train Epoch: 10 [390/590]	loss: 1.018072
# Train Epoch: 10 [400/590]	loss: 1.034637
# Train Epoch: 10 [410/590]	loss: 1.022743
# Train Epoch: 10 [420/590]	loss: 1.026501
# Train Epoch: 10 [430/590]	loss: 1.017859
# Train Epoch: 10 [440/590]	loss: 1.017298
# Train Epoch: 10 [450/590]	loss: 1.067543
# Train Epoch: 10 [460/590]	loss: 1.108654
# Train Epoch: 10 [470/590]	loss: 1.035966
# Train Epoch: 10 [480/590]	loss: 1.034366
# Train Epoch: 10 [490/590]	loss: 1.291372
# Train Epoch: 10 [500/590]	loss: 1.031480
# Train Epoch: 10 [510/590]	loss: 1.198024
# Train Epoch: 10 [520/590]	loss: 1.290758
# Train Epoch: 10 [530/590]	loss: 1.043792
# Train Epoch: 10 [540/590]	loss: 1.025289
# Train Epoch: 10 [550/590]	loss: 1.030083
# Train Epoch: 10 [560/590]	loss: 1.220706
# Train Epoch: 10 [570/590]	loss: 1.027979
# Train Epoch: 10 [580/590]	loss: 1.093871
# [10]Validation Loss: 0.2723,Accuracy: 94.2568%
# Train Epoch: 11 [0/590]	loss: 1.017956
# Train Epoch: 11 [10/590]	loss: 1.011423
# Train Epoch: 11 [20/590]	loss: 1.022867
# Train Epoch: 11 [30/590]	loss: 1.036874
# Train Epoch: 11 [40/590]	loss: 1.017999
# Train Epoch: 11 [50/590]	loss: 1.047758
# Train Epoch: 11 [60/590]	loss: 1.027580
# Train Epoch: 11 [70/590]	loss: 1.086151
# Train Epoch: 11 [80/590]	loss: 1.217622
# Train Epoch: 11 [90/590]	loss: 1.010820
# Train Epoch: 11 [100/590]	loss: 1.112596
# Train Epoch: 11 [110/590]	loss: 1.022083
# Train Epoch: 11 [120/590]	loss: 1.026652
# Train Epoch: 11 [130/590]	loss: 1.116609
# Train Epoch: 11 [140/590]	loss: 1.065597
# Train Epoch: 11 [150/590]	loss: 1.020100
# Train Epoch: 11 [160/590]	loss: 1.017422
# Train Epoch: 11 [170/590]	loss: 1.017327
# Train Epoch: 11 [180/590]	loss: 1.037436
# Train Epoch: 11 [190/590]	loss: 1.099637
# Train Epoch: 11 [200/590]	loss: 1.012366
# Train Epoch: 11 [210/590]	loss: 1.260869
# Train Epoch: 11 [220/590]	loss: 1.016576
# Train Epoch: 11 [230/590]	loss: 1.094264
# Train Epoch: 11 [240/590]	loss: 1.016631
# Train Epoch: 11 [250/590]	loss: 1.164608
# Train Epoch: 11 [260/590]	loss: 1.058463
# Train Epoch: 11 [270/590]	loss: 1.011244
# Train Epoch: 11 [280/590]	loss: 1.018113
# Train Epoch: 11 [290/590]	loss: 1.084605
# Train Epoch: 11 [300/590]	loss: 1.020517
# Train Epoch: 11 [310/590]	loss: 1.013653
# Train Epoch: 11 [320/590]	loss: 1.011916
# Train Epoch: 11 [330/590]	loss: 1.030779
# Train Epoch: 11 [340/590]	loss: 1.202012
# Train Epoch: 11 [350/590]	loss: 1.030859
# Train Epoch: 11 [360/590]	loss: 1.252133
# Train Epoch: 11 [370/590]	loss: 1.046351
# Train Epoch: 11 [380/590]	loss: 1.025720
# Train Epoch: 11 [390/590]	loss: 1.010481
# Train Epoch: 11 [400/590]	loss: 1.115087
# Train Epoch: 11 [410/590]	loss: 1.144486
# Train Epoch: 11 [420/590]	loss: 1.095516
# Train Epoch: 11 [430/590]	loss: 1.113850
# Train Epoch: 11 [440/590]	loss: 1.022577
# Train Epoch: 11 [450/590]	loss: 1.014616
# Train Epoch: 11 [460/590]	loss: 1.020637
# Train Epoch: 11 [470/590]	loss: 1.393851
# Train Epoch: 11 [480/590]	loss: 1.015093
# Train Epoch: 11 [490/590]	loss: 1.228850
# Train Epoch: 11 [500/590]	loss: 1.136956
# Train Epoch: 11 [510/590]	loss: 1.058415
# Train Epoch: 11 [520/590]	loss: 1.010514
# Train Epoch: 11 [530/590]	loss: 1.034895
# Train Epoch: 11 [540/590]	loss: 1.020171
# Train Epoch: 11 [550/590]	loss: 1.020482
# Train Epoch: 11 [560/590]	loss: 1.049571
# Train Epoch: 11 [570/590]	loss: 1.009979
# Train Epoch: 11 [580/590]	loss: 1.008822
# [11]Validation Loss: 0.2601,Accuracy: 94.9324%
# Train Epoch: 12 [0/590]	loss: 1.015000
# Train Epoch: 12 [10/590]	loss: 1.017283
# Train Epoch: 12 [20/590]	loss: 1.016434
# Train Epoch: 12 [30/590]	loss: 1.017661
# Train Epoch: 12 [40/590]	loss: 1.008825
# Train Epoch: 12 [50/590]	loss: 1.040377
# Train Epoch: 12 [60/590]	loss: 1.108293
# Train Epoch: 12 [70/590]	loss: 1.010216
# Train Epoch: 12 [80/590]	loss: 1.085192
# Train Epoch: 12 [90/590]	loss: 1.010250
# Train Epoch: 12 [100/590]	loss: 1.081104
# Train Epoch: 12 [110/590]	loss: 1.026065
# Train Epoch: 12 [120/590]	loss: 1.168669
# Train Epoch: 12 [130/590]	loss: 1.023674
# Train Epoch: 12 [140/590]	loss: 1.016394
# Train Epoch: 12 [150/590]	loss: 1.085469
# Train Epoch: 12 [160/590]	loss: 1.008926
# Train Epoch: 12 [170/590]	loss: 1.031315
# Train Epoch: 12 [180/590]	loss: 1.024525
# Train Epoch: 12 [190/590]	loss: 1.016753
# Train Epoch: 12 [200/590]	loss: 1.030009
# Train Epoch: 12 [210/590]	loss: 1.032079
# Train Epoch: 12 [220/590]	loss: 1.435418
# Train Epoch: 12 [230/590]	loss: 1.127694
# Train Epoch: 12 [240/590]	loss: 1.030958
# Train Epoch: 12 [250/590]	loss: 1.009147
# Train Epoch: 12 [260/590]	loss: 1.014183
# Train Epoch: 12 [270/590]	loss: 1.074803
# Train Epoch: 12 [280/590]	loss: 1.175336
# Train Epoch: 12 [290/590]	loss: 1.015735
# Train Epoch: 12 [300/590]	loss: 1.225425
# Train Epoch: 12 [310/590]	loss: 1.197345
# Train Epoch: 12 [320/590]	loss: 1.024032
# Train Epoch: 12 [330/590]	loss: 1.036663
# Train Epoch: 12 [340/590]	loss: 1.031662
# Train Epoch: 12 [350/590]	loss: 1.008598
# Train Epoch: 12 [360/590]	loss: 1.026574
# Train Epoch: 12 [370/590]	loss: 1.015175
# Train Epoch: 12 [380/590]	loss: 1.016043
# Train Epoch: 12 [390/590]	loss: 1.075825
# Train Epoch: 12 [400/590]	loss: 1.033897
# Train Epoch: 12 [410/590]	loss: 1.058145
# Train Epoch: 12 [420/590]	loss: 1.010990
# Train Epoch: 12 [430/590]	loss: 1.034285
# Train Epoch: 12 [440/590]	loss: 1.011044
# Train Epoch: 12 [450/590]	loss: 1.371297
# Train Epoch: 12 [460/590]	loss: 1.051496
# Train Epoch: 12 [470/590]	loss: 1.063151
# Train Epoch: 12 [480/590]	loss: 1.016895
# Train Epoch: 12 [490/590]	loss: 1.005760
# Train Epoch: 12 [500/590]	loss: 1.056387
# Train Epoch: 12 [510/590]	loss: 1.037872
# Train Epoch: 12 [520/590]	loss: 1.381606
# Train Epoch: 12 [530/590]	loss: 1.004663
# Train Epoch: 12 [540/590]	loss: 1.006090
# Train Epoch: 12 [550/590]	loss: 1.034802
# Train Epoch: 12 [560/590]	loss: 1.075899
# Train Epoch: 12 [570/590]	loss: 1.037483
# Train Epoch: 12 [580/590]	loss: 1.006923
# [12]Validation Loss: 0.2915,Accuracy: 94.2568%
# Train Epoch: 13 [0/590]	loss: 1.075342
# Train Epoch: 13 [10/590]	loss: 1.188809
# Train Epoch: 13 [20/590]	loss: 1.089401
# Train Epoch: 13 [30/590]	loss: 1.043114
# Train Epoch: 13 [40/590]	loss: 1.020772
# Train Epoch: 13 [50/590]	loss: 1.012894
# Train Epoch: 13 [60/590]	loss: 1.023938
# Train Epoch: 13 [70/590]	loss: 1.016695
# Train Epoch: 13 [80/590]	loss: 1.012923
# Train Epoch: 13 [90/590]	loss: 1.009242
# Train Epoch: 13 [100/590]	loss: 1.013473
# Train Epoch: 13 [110/590]	loss: 1.030402
# Train Epoch: 13 [120/590]	loss: 1.012186
# Train Epoch: 13 [130/590]	loss: 1.029510
# Train Epoch: 13 [140/590]	loss: 1.013971
# Train Epoch: 13 [150/590]	loss: 1.005221
# Train Epoch: 13 [160/590]	loss: 1.044301
# Train Epoch: 13 [170/590]	loss: 1.007345
# Train Epoch: 13 [180/590]	loss: 1.011512
# Train Epoch: 13 [190/590]	loss: 1.026338
# Train Epoch: 13 [200/590]	loss: 1.043068
# Train Epoch: 13 [210/590]	loss: 1.023007
# Train Epoch: 13 [220/590]	loss: 1.047558
# Train Epoch: 13 [230/590]	loss: 1.011280
# Train Epoch: 13 [240/590]	loss: 1.022981
# Train Epoch: 13 [250/590]	loss: 1.487960
# Train Epoch: 13 [260/590]	loss: 1.178286
# Train Epoch: 13 [270/590]	loss: 1.502799
# Train Epoch: 13 [280/590]	loss: 1.010667
# Train Epoch: 13 [290/590]	loss: 1.027227
# Train Epoch: 13 [300/590]	loss: 1.009978
# Train Epoch: 13 [310/590]	loss: 1.017463
# Train Epoch: 13 [320/590]	loss: 1.101676
# Train Epoch: 13 [330/590]	loss: 1.011803
# Train Epoch: 13 [340/590]	loss: 1.040093
# Train Epoch: 13 [350/590]	loss: 1.042442
# Train Epoch: 13 [360/590]	loss: 1.012516
# Train Epoch: 13 [370/590]	loss: 1.028817
# Train Epoch: 13 [380/590]	loss: 1.140235
# Train Epoch: 13 [390/590]	loss: 1.005000
# Train Epoch: 13 [400/590]	loss: 1.021298
# Train Epoch: 13 [410/590]	loss: 1.020092
# Train Epoch: 13 [420/590]	loss: 1.090814
# Train Epoch: 13 [430/590]	loss: 1.014484
# Train Epoch: 13 [440/590]	loss: 1.013166
# Train Epoch: 13 [450/590]	loss: 1.015274
# Train Epoch: 13 [460/590]	loss: 1.028350
# Train Epoch: 13 [470/590]	loss: 1.031693
# Train Epoch: 13 [480/590]	loss: 1.009420
# Train Epoch: 13 [490/590]	loss: 1.010550
# Train Epoch: 13 [500/590]	loss: 1.151613
# Train Epoch: 13 [510/590]	loss: 1.044022
# Train Epoch: 13 [520/590]	loss: 1.022688
# Train Epoch: 13 [530/590]	loss: 1.027902
# Train Epoch: 13 [540/590]	loss: 1.010097
# Train Epoch: 13 [550/590]	loss: 1.008692
# Train Epoch: 13 [560/590]	loss: 1.022778
# Train Epoch: 13 [570/590]	loss: 1.018401
# Train Epoch: 13 [580/590]	loss: 1.034168
# [13]Validation Loss: 0.2807,Accuracy: 94.9324%
# Train Epoch: 14 [0/590]	loss: 1.011319
# Train Epoch: 14 [10/590]	loss: 1.404984
# Train Epoch: 14 [20/590]	loss: 1.017437
# Train Epoch: 14 [30/590]	loss: 1.004137
# Train Epoch: 14 [40/590]	loss: 1.015428
# Train Epoch: 14 [50/590]	loss: 1.286168
# Train Epoch: 14 [60/590]	loss: 1.040741
# Train Epoch: 14 [70/590]	loss: 1.394099
# Train Epoch: 14 [80/590]	loss: 1.016339
# Train Epoch: 14 [90/590]	loss: 1.058252
# Train Epoch: 14 [100/590]	loss: 1.012786
# Train Epoch: 14 [110/590]	loss: 1.033664
# Train Epoch: 14 [120/590]	loss: 1.004357
# Train Epoch: 14 [130/590]	loss: 1.024106
# Train Epoch: 14 [140/590]	loss: 1.095482
# Train Epoch: 14 [150/590]	loss: 1.092211
# Train Epoch: 14 [160/590]	loss: 1.011630
# Train Epoch: 14 [170/590]	loss: 1.028278
# Train Epoch: 14 [180/590]	loss: 1.042987
# Train Epoch: 14 [190/590]	loss: 1.062993
# Train Epoch: 14 [200/590]	loss: 1.016037
# Train Epoch: 14 [210/590]	loss: 1.033749
# Train Epoch: 14 [220/590]	loss: 1.211572
# Train Epoch: 14 [230/590]	loss: 1.015916
# Train Epoch: 14 [240/590]	loss: 1.005714
# Train Epoch: 14 [250/590]	loss: 1.075859
# Train Epoch: 14 [260/590]	loss: 1.029916
# Train Epoch: 14 [270/590]	loss: 1.012069
# Train Epoch: 14 [280/590]	loss: 1.028914
# Train Epoch: 14 [290/590]	loss: 1.015043
# Train Epoch: 14 [300/590]	loss: 1.015660
# Train Epoch: 14 [310/590]	loss: 1.016506
# Train Epoch: 14 [320/590]	loss: 1.077394
# Train Epoch: 14 [330/590]	loss: 1.043373
# Train Epoch: 14 [340/590]	loss: 1.007282
# Train Epoch: 14 [350/590]	loss: 1.012884
# Train Epoch: 14 [360/590]	loss: 1.008083
# Train Epoch: 14 [370/590]	loss: 1.038861
# Train Epoch: 14 [380/590]	loss: 1.012894
# Train Epoch: 14 [390/590]	loss: 1.015318
# Train Epoch: 14 [400/590]	loss: 1.330171
# Train Epoch: 14 [410/590]	loss: 1.024802
# Train Epoch: 14 [420/590]	loss: 1.010327
# Train Epoch: 14 [430/590]	loss: 1.004941
# Train Epoch: 14 [440/590]	loss: 1.188452
# Train Epoch: 14 [450/590]	loss: 1.026416
# Train Epoch: 14 [460/590]	loss: 1.320332
# Train Epoch: 14 [470/590]	loss: 1.054375
# Train Epoch: 14 [480/590]	loss: 1.057245
# Train Epoch: 14 [490/590]	loss: 1.018726
# Train Epoch: 14 [500/590]	loss: 1.012755
# Train Epoch: 14 [510/590]	loss: 1.071455
# Train Epoch: 14 [520/590]	loss: 1.012921
# Train Epoch: 14 [530/590]	loss: 1.019072
# Train Epoch: 14 [540/590]	loss: 1.015049
# Train Epoch: 14 [550/590]	loss: 1.018358
# Train Epoch: 14 [560/590]	loss: 1.100749
# Train Epoch: 14 [570/590]	loss: 1.011716
# Train Epoch: 14 [580/590]	loss: 1.107822
# [14]Validation Loss: 0.3116,Accuracy: 94.2568%
# Train Epoch: 15 [0/590]	loss: 1.008108
# Train Epoch: 15 [10/590]	loss: 1.027574
# Train Epoch: 15 [20/590]	loss: 1.015777
# Train Epoch: 15 [30/590]	loss: 1.389862
# Train Epoch: 15 [40/590]	loss: 1.014792
# Train Epoch: 15 [50/590]	loss: 1.128166
# Train Epoch: 15 [60/590]	loss: 1.026877
# Train Epoch: 15 [70/590]	loss: 1.016376
# Train Epoch: 15 [80/590]	loss: 1.036697
# Train Epoch: 15 [90/590]	loss: 1.005351
# Train Epoch: 15 [100/590]	loss: 1.016829
# Train Epoch: 15 [110/590]	loss: 1.018000
# Train Epoch: 15 [120/590]	loss: 1.015277
# Train Epoch: 15 [130/590]	loss: 1.021202
# Train Epoch: 15 [140/590]	loss: 1.128303
# Train Epoch: 15 [150/590]	loss: 1.010699
# Train Epoch: 15 [160/590]	loss: 1.009420
# Train Epoch: 15 [170/590]	loss: 1.015079
# Train Epoch: 15 [180/590]	loss: 1.016411
# Train Epoch: 15 [190/590]	loss: 1.016872
# Train Epoch: 15 [200/590]	loss: 1.002048
# Train Epoch: 15 [210/590]	loss: 1.007266
# Train Epoch: 15 [220/590]	loss: 1.011288
# Train Epoch: 15 [230/590]	loss: 1.004200
# Train Epoch: 15 [240/590]	loss: 1.011001
# Train Epoch: 15 [250/590]	loss: 1.012663
# Train Epoch: 15 [260/590]	loss: 1.008208
# Train Epoch: 15 [270/590]	loss: 1.038312
# Train Epoch: 15 [280/590]	loss: 1.006024
# Train Epoch: 15 [290/590]	loss: 1.077045
# Train Epoch: 15 [300/590]	loss: 1.015635
# Train Epoch: 15 [310/590]	loss: 1.037119
# Train Epoch: 15 [320/590]	loss: 1.044560
# Train Epoch: 15 [330/590]	loss: 1.033985
# Train Epoch: 15 [340/590]	loss: 1.040000
# Train Epoch: 15 [350/590]	loss: 1.104030
# Train Epoch: 15 [360/590]	loss: 1.116835
# Train Epoch: 15 [370/590]	loss: 1.010047
# Train Epoch: 15 [380/590]	loss: 1.027043
# Train Epoch: 15 [390/590]	loss: 1.013656
# Train Epoch: 15 [400/590]	loss: 1.049408
# Train Epoch: 15 [410/590]	loss: 1.051977
# Train Epoch: 15 [420/590]	loss: 1.009426
# Train Epoch: 15 [430/590]	loss: 1.025040
# Train Epoch: 15 [440/590]	loss: 1.029576
# Train Epoch: 15 [450/590]	loss: 1.048554
# Train Epoch: 15 [460/590]	loss: 1.011474
# Train Epoch: 15 [470/590]	loss: 1.007467
# Train Epoch: 15 [480/590]	loss: 1.006615
# Train Epoch: 15 [490/590]	loss: 1.002510
# Train Epoch: 15 [500/590]	loss: 1.008120
# Train Epoch: 15 [510/590]	loss: 1.007289
# Train Epoch: 15 [520/590]	loss: 1.002880
# Train Epoch: 15 [530/590]	loss: 1.068137
# Train Epoch: 15 [540/590]	loss: 1.017641
# Train Epoch: 15 [550/590]	loss: 1.002370
# Train Epoch: 15 [560/590]	loss: 1.022104
# Train Epoch: 15 [570/590]	loss: 1.018193
# Train Epoch: 15 [580/590]	loss: 1.014993
# [15]Validation Loss: 0.3159,Accuracy: 93.5811%
# Train Epoch: 16 [0/590]	loss: 1.006953
# Train Epoch: 16 [10/590]	loss: 1.051546
# Train Epoch: 16 [20/590]	loss: 1.203372
# Train Epoch: 16 [30/590]	loss: 1.002155
# Train Epoch: 16 [40/590]	loss: 1.015478
# Train Epoch: 16 [50/590]	loss: 1.029781
# Train Epoch: 16 [60/590]	loss: 1.059316
# Train Epoch: 16 [70/590]	loss: 1.199875
# Train Epoch: 16 [80/590]	loss: 1.113588
# Train Epoch: 16 [90/590]	loss: 1.105639
# Train Epoch: 16 [100/590]	loss: 1.022269
# Train Epoch: 16 [110/590]	loss: 1.009244
# Train Epoch: 16 [120/590]	loss: 1.011391
# Train Epoch: 16 [130/590]	loss: 1.002496
# Train Epoch: 16 [140/590]	loss: 1.323091
# Train Epoch: 16 [150/590]	loss: 1.293718
# Train Epoch: 16 [160/590]	loss: 1.016217
# Train Epoch: 16 [170/590]	loss: 1.005826
# Train Epoch: 16 [180/590]	loss: 1.033939
# Train Epoch: 16 [190/590]	loss: 1.009937
# Train Epoch: 16 [200/590]	loss: 1.007808
# Train Epoch: 16 [210/590]	loss: 1.011356
# Train Epoch: 16 [220/590]	loss: 1.014487
# Train Epoch: 16 [230/590]	loss: 1.013109
# Train Epoch: 16 [240/590]	loss: 1.006325
# Train Epoch: 16 [250/590]	loss: 1.065433
# Train Epoch: 16 [260/590]	loss: 1.005853
# Train Epoch: 16 [270/590]	loss: 1.009073
# Train Epoch: 16 [280/590]	loss: 1.099737
# Train Epoch: 16 [290/590]	loss: 1.017963
# Train Epoch: 16 [300/590]	loss: 1.106902
# Train Epoch: 16 [310/590]	loss: 1.010362
# Train Epoch: 16 [320/590]	loss: 1.017581
# Train Epoch: 16 [330/590]	loss: 1.005755
# Train Epoch: 16 [340/590]	loss: 1.011170
# Train Epoch: 16 [350/590]	loss: 1.011366
# Train Epoch: 16 [360/590]	loss: 1.023557
# Train Epoch: 16 [370/590]	loss: 1.053588
# Train Epoch: 16 [380/590]	loss: 1.028119
# Train Epoch: 16 [390/590]	loss: 1.013045
# Train Epoch: 16 [400/590]	loss: 1.014279
# Train Epoch: 16 [410/590]	loss: 1.004813
# Train Epoch: 16 [420/590]	loss: 1.025051
# Train Epoch: 16 [430/590]	loss: 1.007722
# Train Epoch: 16 [440/590]	loss: 1.012009
# Train Epoch: 16 [450/590]	loss: 1.011286
# Train Epoch: 16 [460/590]	loss: 1.043994
# Train Epoch: 16 [470/590]	loss: 1.016982
# Train Epoch: 16 [480/590]	loss: 1.017880
# Train Epoch: 16 [490/590]	loss: 1.061883
# Train Epoch: 16 [500/590]	loss: 1.006826
# Train Epoch: 16 [510/590]	loss: 1.004026
# Train Epoch: 16 [520/590]	loss: 1.000651
# Train Epoch: 16 [530/590]	loss: 1.000557
# Train Epoch: 16 [540/590]	loss: 1.023454
# Train Epoch: 16 [550/590]	loss: 1.002952
# Train Epoch: 16 [560/590]	loss: 1.001899
# Train Epoch: 16 [570/590]	loss: 1.339369
# Train Epoch: 16 [580/590]	loss: 1.107865
# [16]Validation Loss: 0.2724,Accuracy: 94.9324%
# Train Epoch: 17 [0/590]	loss: 1.006717
# Train Epoch: 17 [10/590]	loss: 1.006952
# Train Epoch: 17 [20/590]	loss: 1.004336
# Train Epoch: 17 [30/590]	loss: 1.006101
# Train Epoch: 17 [40/590]	loss: 1.018393
# Train Epoch: 17 [50/590]	loss: 1.001847
# Train Epoch: 17 [60/590]	loss: 1.004780
# Train Epoch: 17 [70/590]	loss: 1.018079
# Train Epoch: 17 [80/590]	loss: 1.011097
# Train Epoch: 17 [90/590]	loss: 1.003562
# Train Epoch: 17 [100/590]	loss: 1.006449
# Train Epoch: 17 [110/590]	loss: 1.009455
# Train Epoch: 17 [120/590]	loss: 1.023951
# Train Epoch: 17 [130/590]	loss: 1.018207
# Train Epoch: 17 [140/590]	loss: 1.004931
# Train Epoch: 17 [150/590]	loss: 1.013032
# Train Epoch: 17 [160/590]	loss: 1.007936
# Train Epoch: 17 [170/590]	loss: 1.009307
# Train Epoch: 17 [180/590]	loss: 1.000148
# Train Epoch: 17 [190/590]	loss: 1.002343
# Train Epoch: 17 [200/590]	loss: 1.005797
# Train Epoch: 17 [210/590]	loss: 1.005541
# Train Epoch: 17 [220/590]	loss: 1.029047
# Train Epoch: 17 [230/590]	loss: 1.004806
# Train Epoch: 17 [240/590]	loss: 1.013493
# Train Epoch: 17 [250/590]	loss: 1.014115
# Train Epoch: 17 [260/590]	loss: 1.006003
# Train Epoch: 17 [270/590]	loss: 1.010499
# Train Epoch: 17 [280/590]	loss: 1.017603
# Train Epoch: 17 [290/590]	loss: 1.193834
# Train Epoch: 17 [300/590]	loss: 1.193833
# Train Epoch: 17 [310/590]	loss: 1.017225
# Train Epoch: 17 [320/590]	loss: 1.064024
# Train Epoch: 17 [330/590]	loss: 1.008607
# Train Epoch: 17 [340/590]	loss: 1.010860
# Train Epoch: 17 [350/590]	loss: 1.013783
# Train Epoch: 17 [360/590]	loss: 1.008874
# Train Epoch: 17 [370/590]	loss: 1.010709
# Train Epoch: 17 [380/590]	loss: 1.041225
# Train Epoch: 17 [390/590]	loss: 1.030622
# Train Epoch: 17 [400/590]	loss: 1.019906
# Train Epoch: 17 [410/590]	loss: 1.009599
# Train Epoch: 17 [420/590]	loss: 1.530473
# Train Epoch: 17 [430/590]	loss: 1.004459
# Train Epoch: 17 [440/590]	loss: 1.019119
# Train Epoch: 17 [450/590]	loss: 1.034750

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
